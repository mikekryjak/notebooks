# %%
import sys, os
import yaml
from hypnotoad import tokamak
from hypnotoad.core.mesh import BoutMesh
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

onedrive_path = onedrive_path = str(os.getcwd()).split("OneDrive")[0] + "OneDrive"
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages\sdtools"))
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages\soledge"))
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages"))

from xbout import open_boutdataset
from hermes3.grid_fields import *
import h5py

# %matplotlib qt
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %% [markdown]
# # Read only a grid

# %%
m = Mesh(r"C:\Users\mikek\Downloads\G_24843_3990_N_01_S010.nc")

# %%
# %matplotlib widget

# %%
fig, ax = plt.subplots(dpi = 300)
m.plot_rz_grid(ax = ax)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 fig, ax = plt.subplots(dpi = 300)
# ----> 2 m.plot_rz_grid(ax = ax)
#
# File c:\Users\mikek\OneDrive\Project\python-packages\sdtools\hermes3\grid_fields.py:500, in Mesh.plot_rz_grid(self, ax, xlim, ylim, linecolor, plot_region_borders)
#     498     ax.plot(self.Rxy[:,self.j2_2g], self.Zxy[:,self.j2_2g], label = "j2_2g", color = self.colors[3], alpha = 0.7)
#     499     ax.plot(self.Rxy[self.ixseps1,:], self.Zxy[self.ixseps1,:], label = "ixseps1", color = self.colors[4], alpha = 0.7, lw = 1)
# --> 500     ax.plot(self.Rxy[self.ixseps2,:], self.Zxy[self.ixseps2,:], label = "ixseps2", color = self.colors[5], alpha = 0.7, lw = 1, ls=":")
#     502 if xlim != (None,None):
#     503     ax.set_xlim(xlim)
#
# IndexError: index 68 is out of bounds for axis 0 with size 68
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Read

# %%
def plot(loc):
    
    fig, ax = plt.subplots(dpi = 140)
    ax.plot(*eq.x_points[0], "rx",)
    # mesh.plotPoints(xlow=False, ylow=False, corners=False, ax = ax, s = 2)
    mesh.plotGridCellEdges(ax = ax, lw = 0.5)
    eq.plotWall(axis = ax, linewidth = 1, alpha = 0.3)
    ax.grid(False)
    ax.legend('', frameon=False)
    
    ax.set_xlabel("R")
    ax.set_ylabel("Z")
    ax.set_aspect(1)
    
    
    ax.xaxis.set_ticks([])
    ax.yaxis.set_ticks([])
    
    ax.xaxis.label.set_visible(False)
    ax.yaxis.label.set_visible(False)
    
    ax.set_frame_on(False)
    
    if loc == "lower":
        ax.set_xlim([0.12, 1.2]); ax.set_ylim([-0.88,0.1])     # Both lower divertors
    elif loc == "lower_zoom":
        ax.set_xlim([0.25, 0.6]); ax.set_ylim([-0.9,-0.7])     # Both lower divertors zoom
    elif loc == "inner_upper":
        ax.set_xlim([0.20, 0.45]); ax.set_ylim([0.6,0.8])     # Inner upper leg
    elif loc == "omp":
        ax.set_xlim([0.62, 0.800]); ax.set_ylim([-0.08,0])     # OMP
    elif loc == "imp":
        ax.set_xlim([0.12, 0.300]); ax.set_ylim([-0.15,0.05])     # IMP
    else:
        raise ValueError("Invalid location")
    
    ## PLOT REFERENCE
    # mesh2 = Mesh(r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3e2-lores_widev2.nc")
    # kwargs = dict(s= 10, zorder = 20, c = "k")
    # slicer = mesh2.slices("core_edge")
    # ax.scatter(mesh2.mesh["Rxy"][slicer].flatten(), mesh2.mesh["Zxy"][slicer].flatten(), label = "Reference", **kwargs)
    # slicer = mesh2.slices("sol_edge")
    # ax.scatter(mesh2.mesh["Rxy"][slicer].flatten(), mesh2.mesh["Zxy"][slicer].flatten(), **kwargs)
    # mesh2.close()
    
    # plt.savefig(os.path.join(path, gridname + ".png"), dpi = 400, bbox_inches = "tight")

# %%
gridname = "g4b-fine_nonorth_xpoint_guards"
path = os.path.join(onedrive_path, r"Project\collab\tech\grid\ST40\matteo-mod")
path_yaml = os.path.join(path, f"{gridname}.yml")
path_grid = os.path.join(path, f"{gridname}.nc")


with open(path_yaml) as f:
	options = yaml.safe_load(f)

with open(os.path.join(onedrive_path, r"Project\collab\tech\grid\ST40\4-soledge_optimised\ST40_P3_eq_0015_modgeom.geqdsk"), "rt") as fh:
    eq = tokamak.read_geqdsk(fh, settings=options, nonorthogonal_settings=options)

mesh = BoutMesh(eq, options)
mesh.calculateRZ()
plot("lower")
# Out:
#   nx = 33, ny = 65
# 250
#
# Options
# =======
# Name                                              |  Value
# ================================================================================
# N_norm_prefactor                                  |  1.0             (default)
# extrapolate_profiles                              |  False           (default)
# finecontour_Nfine                                 |  100             (default)
# finecontour_atol                                  |  1e-12           (default)
# finecontour_diagnose                              |  False           (default)
# finecontour_extend_prefactor                      |  2.0             (default)
# finecontour_maxits                                |  200             (default)
# finecontour_overdamping_factor                    |  0.8             (default)
# leg_refine_atol                                   |  1e-05           (default)
# leg_refine_maxits                                 |  1000            (default)
# leg_trace_atol                                    |  2e-10           (default)
# nx_core                                           |  20
# nx_inter_sep                                      |  0               (default)
# nx_pf                                             |  20              (default)
# nx_sol                                            |  20
# nx_sol_inner                                      |  20              (default)
# nx_sol_outer                                      |  20              (default)
# ny_inner_divertor                                 |  10
# ny_inner_lower_divertor                           |  10              (default)
# ny_inner_sol                                      |  20
# ny_inner_upper_divertor                           |  10              (default)
# ny_outer_divertor                                 |  20
# ny_outer_lower_divertor                           |  20              (default)
# ny_outer_sol                                      |  20
# ny_outer_upper_divertor                           |  20              (default)
# ny_sol                                            |  8               (default)
# orthogonal                                        |  False
# poloidal_spacing_delta_psi                        |  None            (default)
# poloidal_spacing_method                           |  sqrt            (default)
# poloidalfunction_diagnose                         |  False           (default)
# psi_core                                          |  -0.0707
# psi_divide_twopi                                  |  False           (default)
# psi_interpolation_method                          |  spline          (default)
# psi_pf_lower                                      |  None            (default)
# psi_pf_upper                                      |  None            (default)
# psi_sol                                           |  None            (default)
# psi_sol_inner                                     |  None            (default)
# psi_spacing_separatrix_multiplier                 |  1.0             (default)
# psinorm_core                                      |  0.9             (default)
# psinorm_pf                                        |  0.928
# psinorm_pf_lower                                  |  0.928           (default)
# psinorm_pf_upper                                  |  0.928           (default)
# psinorm_sol                                       |  1.43
# psinorm_sol_inner                                 |  1.32
# refine_atol                                       |  2e-08           (default)
# refine_methods                                    |  ['integrate+newton', 'integrate'] (default)
# refine_timeout                                    |  10.0            (default)
# refine_width                                      |  1e-05           (default)
# reverse_Bt                                        |  True
# reverse_current                                   |  True
# sfunc_checktol                                    |  1e-13           (default)
# start_at_upper_outer                              |  False           (default)
# target_all_poloidal_spacing_length                |  1.0             (default)
# target_inner_lower_poloidal_spacing_length        |  0.2
# target_inner_upper_poloidal_spacing_length        |  0.2
# target_outer_lower_poloidal_spacing_length        |  0.2
# target_outer_upper_poloidal_spacing_length        |  0.2
# xpoint_offset                                     |  0.1             (default)
# xpoint_poloidal_spacing_length                    |  4.0             (default)
# xpoint_refine_atol                                |  1e-06           (default)
# xpoint_refine_maxits                              |  1000            (default)
# y_boundary_guards                                 |  2
#
#
# Options
# =======
# Name                                              |  Value
# ================================================================================
# nonorthogonal_radial_range_power                  |  4
# nonorthogonal_spacing_method                      |  combined        (default)
# nonorthogonal_target_all_poloidal_spacing_length  |  1.0             (default)
# nonorthogonal_target_all_poloidal_spacing_range   |  None
# nonorthogonal_target_all_poloidal_spacing_range_inner|  None            (default)
# nonorthogonal_target_all_poloidal_spacing_range_outer|  None            (default)
# nonorthogonal_target_inner_lower_poloidal_spacing_length|  1.0             (default)
# nonorthogonal_target_inner_lower_poloidal_spacing_range|  None            (default)
# nonorthogonal_target_inner_lower_poloidal_spacing_range_inner|  None            (default)
# nonorthogonal_target_inner_lower_poloidal_spacing_range_outer|  None            (default)
# nonorthogonal_target_inner_upper_poloidal_spacing_length|  1.0             (default)
# nonorthogonal_target_inner_upper_poloidal_spacing_range|  None            (default)
# nonorthogonal_target_inner_upper_poloidal_spacing_range_inner|  None            (default)
# nonorthogonal_target_inner_upper_poloidal_spacing_range_outer|  None            (default)
# nonorthogonal_target_outer_lower_poloidal_spacing_length|  1.0             (default)
# nonorthogonal_target_outer_lower_poloidal_spacing_range|  None            (default)
# nonorthogonal_target_outer_lower_poloidal_spacing_range_inner|  None            (default)
# nonorthogonal_target_outer_lower_poloidal_spacing_range_outer|  None            (default)
# nonorthogonal_target_outer_upper_poloidal_spacing_length|  1.0             (default)
# nonorthogonal_target_outer_upper_poloidal_spacing_range|  None            (default)
# nonorthogonal_target_outer_upper_poloidal_spacing_range_inner|  None            (default)
# nonorthogonal_target_outer_upper_poloidal_spacing_range_outer|  None            (default)
# nonorthogonal_xpoint_poloidal_spacing_length      |  1.5
# nonorthogonal_xpoint_poloidal_spacing_range       |  0.03            (default)
# nonorthogonal_xpoint_poloidal_spacing_range_inner |  0.15            (default)
# nonorthogonal_xpoint_poloidal_spacing_range_outer |  0.15            (default)
# Found X-point at psi = -0.018701289814695547, psi_norm = 1.0
# Found X-point at psi = -0.01870128981469555, psi_norm = 1.0
# Generating a connected double null
#
# Options
# =======
# Name                                              |  Value
# ================================================================================
# N_norm_prefactor                                  |  1.0             (default)
# cap_Bp_ylow_xpoint                                |  False           (default)
# curvature_smoothing                               |  None            (default)
# curvature_type                                    |  curl(b/B)       (default)
# finecontour_Nfine                                 |  100             (default)
# finecontour_atol                                  |  1e-12           (default)
# finecontour_diagnose                              |  False           (default)
# finecontour_extend_prefactor                      |  2.0             (default)
# finecontour_maxits                                |  200             (default)
# finecontour_overdamping_factor                    |  0.8             (default)
# follow_perpendicular_atol                         |  1e-08           (default)
# follow_perpendicular_maxits                       |  10000           (default)
# follow_perpendicular_recover                      |  False           (default)
# follow_perpendicular_rtol                         |  2e-08           (default)
# geometry_rtol                                     |  1e-10           (default)
# number_of_processors                              |  6
# orthogonal                                        |  False
# poloidal_spacing_delta_psi                        |  None            (default)
# poloidal_spacing_method                           |  sqrt            (default)
# poloidalfunction_diagnose                         |  False           (default)
# psi_interpolation_method                          |  spline          (default)
# psi_spacing_separatrix_multiplier                 |  1.0             (default)
# refine_atol                                       |  2e-08           (default)
# refine_methods                                    |  ['integrate+newton', 'integrate'] (default)
# refine_timeout                                    |  10.0            (default)
# refine_width                                      |  1e-05           (default)
# sfunc_checktol                                    |  1e-13           (default)
# shiftedmetric                                     |  True            (default)
# target_all_poloidal_spacing_length                |  1.0             (default)
# target_inner_lower_poloidal_spacing_length        |  0.2
# target_inner_upper_poloidal_spacing_length        |  0.2
# target_outer_lower_poloidal_spacing_length        |  0.2
# target_outer_upper_poloidal_spacing_length        |  0.2
# wall_point_exclude_radius                         |  0.001           (default)
# xpoint_poloidal_spacing_length                    |  4.0             (default)
# y_boundary_guards                                 |  2
#
# creating region 0 - inner_lower_divertor(0)
# creating region 1 - inner_lower_divertor(1)
# creating region 2 - inner_core(0)9 10
# creating region 3 - inner_core(1)24 26 29 32 34 35 37 40
# creating region 4 - inner_upper_divertor(0)5
# creating region 5 - inner_upper_divertor(1)
# creating region 6 - outer_upper_divertor(0)
# creating region 7 - outer_upper_divertor(1)9
# creating region 8 - outer_core(0)9 32 38 39
# creating region 9 - outer_core(1)31 33 34 36 37 39
# creating region 10 - outer_lower_divertor(0)
# creating region 11 - outer_lower_divertor(1)
# Get RZ values9endicular: 0 4 5 6 9 33 37 40

# %% [markdown]
# ## Initial gridding

# %%
# Out:
#   nx = 33, ny = 65
# 250
#
# Options
# =======
# Name                                              |  Value
# ================================================================================
# N_norm_prefactor                                  |  1.0             (default)
# extrapolate_profiles                              |  False           (default)
# finecontour_Nfine                                 |  100             (default)
# finecontour_atol                                  |  1e-12           (default)
# finecontour_diagnose                              |  False           (default)
# finecontour_extend_prefactor                      |  2.0             (default)
# finecontour_maxits                                |  200             (default)
# finecontour_overdamping_factor                    |  0.8             (default)
# leg_refine_atol                                   |  1e-05           (default)
# leg_refine_maxits                                 |  1000            (default)
# leg_trace_atol                                    |  2e-10           (default)
# nx_core                                           |  10
# nx_inter_sep                                      |  0               (default)
# nx_pf                                             |  10              (default)
# nx_sol                                            |  10
# nx_sol_inner                                      |  10              (default)
# nx_sol_outer                                      |  10              (default)
# ny_inner_divertor                                 |  5
# ny_inner_lower_divertor                           |  5               (default)
# ny_inner_sol                                      |  10
# ny_inner_upper_divertor                           |  5               (default)
# ny_outer_divertor                                 |  10
# ny_outer_lower_divertor                           |  10              (default)
# ny_outer_sol                                      |  10
# ny_outer_upper_divertor                           |  10              (default)
# ny_sol                                            |  8               (default)
# orthogonal                                        |  False
# poloidal_spacing_delta_psi                        |  None            (default)
# poloidal_spacing_method                           |  sqrt            (default)
# poloidalfunction_diagnose                         |  False           (default)
# psi_core                                          |  -0.095
# psi_divide_twopi                                  |  False           (default)
# psi_interpolation_method                          |  spline          (default)
# psi_pf_lower                                      |  None            (default)
# psi_pf_upper                                      |  None            (default)
# psi_sol                                           |  None            (default)
# psi_sol_inner                                     |  None            (default)
# psi_spacing_separatrix_multiplier                 |  1.0             (default)
# psinorm_core                                      |  0.9             (default)
# psinorm_pf                                        |  0.928
# psinorm_pf_lower                                  |  0.928           (default)
# psinorm_pf_upper                                  |  0.928           (default)
# psinorm_sol                                       |  1.65
# psinorm_sol_inner                                 |  1.32
# refine_atol                                       |  2e-08           (default)
# refine_methods                                    |  ['integrate+newton', 'integrate'] (default)
# refine_timeout                                    |  10.0            (default)
# refine_width                                      |  1e-05           (default)
# reverse_Bt                                        |  True
# reverse_current                                   |  True
# sfunc_checktol                                    |  1e-13           (default)
# start_at_upper_outer                              |  False           (default)
# target_all_poloidal_spacing_length                |  1.0             (default)
# target_inner_lower_poloidal_spacing_length        |  0.2
# target_inner_upper_poloidal_spacing_length        |  0.2
# target_outer_lower_poloidal_spacing_length        |  0.2
# target_outer_upper_poloidal_spacing_length        |  0.2
# xpoint_offset                                     |  0.1             (default)
# xpoint_poloidal_spacing_length                    |  4.0
# xpoint_refine_atol                                |  1e-06           (default)
# xpoint_refine_maxits                              |  1000            (default)
# y_boundary_guards                                 |  2
#
#
# Options
# =======
# Name                                              |  Value
# ================================================================================
# nonorthogonal_radial_range_power                  |  2
# nonorthogonal_spacing_method                      |  combined        (default)
# nonorthogonal_target_all_poloidal_spacing_length  |  1.0             (default)
# nonorthogonal_target_all_poloidal_spacing_range   |  None
# nonorthogonal_target_all_poloidal_spacing_range_inner|  None            (default)
# nonorthogonal_target_all_poloidal_spacing_range_outer|  None            (default)
# nonorthogonal_target_inner_lower_poloidal_spacing_length|  1.0             (default)
# nonorthogonal_target_inner_lower_poloidal_spacing_range|  None            (default)
# nonorthogonal_target_inner_lower_poloidal_spacing_range_inner|  None            (default)
# nonorthogonal_target_inner_lower_poloidal_spacing_range_outer|  None            (default)
# nonorthogonal_target_inner_upper_poloidal_spacing_length|  1.0             (default)
# nonorthogonal_target_inner_upper_poloidal_spacing_range|  None            (default)
# nonorthogonal_target_inner_upper_poloidal_spacing_range_inner|  None            (default)
# nonorthogonal_target_inner_upper_poloidal_spacing_range_outer|  None            (default)
# nonorthogonal_target_outer_lower_poloidal_spacing_length|  1.0             (default)
# nonorthogonal_target_outer_lower_poloidal_spacing_range|  None            (default)
# nonorthogonal_target_outer_lower_poloidal_spacing_range_inner|  None            (default)
# nonorthogonal_target_outer_lower_poloidal_spacing_range_outer|  None            (default)
# nonorthogonal_target_outer_upper_poloidal_spacing_length|  1.0             (default)
# nonorthogonal_target_outer_upper_poloidal_spacing_range|  None            (default)
# nonorthogonal_target_outer_upper_poloidal_spacing_range_inner|  None            (default)
# nonorthogonal_target_outer_upper_poloidal_spacing_range_outer|  None            (default)
# nonorthogonal_xpoint_poloidal_spacing_length      |  2.3
# nonorthogonal_xpoint_poloidal_spacing_range       |  0.03
# nonorthogonal_xpoint_poloidal_spacing_range_inner |  0.15
# nonorthogonal_xpoint_poloidal_spacing_range_outer |  0.15
#
# Found X-point at psi = -0.018701289814695547, psi_norm = 1.0
# Found X-point at psi = -0.01870128981469555, psi_norm = 1.0
# Generating a connected double null
#
# Options
# =======
# Name                                              |  Value
# ================================================================================
# N_norm_prefactor                                  |  1.0             (default)
# cap_Bp_ylow_xpoint                                |  False           (default)
# curvature_smoothing                               |  None            (default)
# curvature_type                                    |  curl(b/B)       (default)
# finecontour_Nfine                                 |  100             (default)
# finecontour_atol                                  |  1e-12           (default)
# finecontour_diagnose                              |  False           (default)
# finecontour_extend_prefactor                      |  2.0             (default)
# finecontour_maxits                                |  200             (default)
# finecontour_overdamping_factor                    |  0.8             (default)
# follow_perpendicular_atol                         |  1e-08           (default)
# follow_perpendicular_maxits                       |  500000
# follow_perpendicular_recover                      |  False
# follow_perpendicular_rtol                         |  2e-08           (default)
# geometry_rtol                                     |  1e-10           (default)
# number_of_processors                              |  8
# orthogonal                                        |  False
# poloidal_spacing_delta_psi                        |  None            (default)
# poloidal_spacing_method                           |  sqrt            (default)
# poloidalfunction_diagnose                         |  False           (default)
# psi_interpolation_method                          |  spline          (default)
# psi_spacing_separatrix_multiplier                 |  1.0             (default)
# refine_atol                                       |  2e-08           (default)
# refine_methods                                    |  ['integrate+newton', 'integrate'] (default)
# refine_timeout                                    |  10.0            (default)
# refine_width                                      |  1e-05           (default)
# sfunc_checktol                                    |  1e-13           (default)
# shiftedmetric                                     |  True            (default)
# target_all_poloidal_spacing_length                |  1.0             (default)
# target_inner_lower_poloidal_spacing_length        |  0.2
# target_inner_upper_poloidal_spacing_length        |  0.2
# target_outer_lower_poloidal_spacing_length        |  0.2
# target_outer_upper_poloidal_spacing_length        |  0.2
# wall_point_exclude_radius                         |  0.001           (default)
# xpoint_poloidal_spacing_length                    |  4.0
# y_boundary_guards                                 |  2
#
# creating region 0 - inner_lower_divertor(0)
# creating region 1 - inner_lower_divertor(1)
# creating region 2 - inner_core(0)10 20
# creating regionndicular: 0 3 - inner_core(1)
# creating region 4 - inner_upper_divertor(0)
# creating region 5 - inner_upper_divertor(1) 17 18
# creating region 6 - outer_upper_divertor(0)
# creating region 7 - outer_upper_divertor(1)
# creating regionndicular: 0 4 11 8 - outer_core(0)
# creating regionndicular: 0 9 - outer_core(1)
# creating region 10 - outer_lower_divertor(0)
# creating region 11 - outer_lower_divertor(1)
# Get RZ values0endicular: 0 4 9 11

# %% [markdown]
# ## Regrid
# - Warning: only takes into accounts new nonorthogonal parameters

# %%
with open(path_yaml) as f:
	options = yaml.safe_load(f)

mesh.redistributePoints(options)
mesh.calculateRZ()
plot("lower")
# Out:
# redistributing inner_lower_divertor(0)
# redistributing inner_lower_divertor(1)7
# redistributing inner_core(0)
# redistributing inner_core(1)
# redistributing7 17 20 inner_upper_divertor(0)
# redistributing inner_upper_divertor(1) 18
# redistributing outer_upper_divertor(0)
# redistributing outer_upper_divertor(1)
# redistributing outer_core(0)
# redistributing3 outer_core(1)
# redistributing outer_lower_divertor(0)
# redistributing4 14 18 outer_lower_divertor(1)
# Get RZ values05 12 15

# %% [markdown]
# # Save

# %%
mesh.geometry()
mesh.writeGridfile(path_grid)
# Out:
# Calculate geometry
# Distances inner_lower_divertor(0)
# Distances inner_lower_divertor(1)
# Distances inner_core(0)
# Distances inner_core(1)
# Distances inner_upper_divertor(0)
# Distances inner_upper_divertor(1)
# Distances outer_upper_divertor(0)
# Distances outer_upper_divertor(1)
# Distances outer_core(0)
# Distances outer_core(1)
# Distances outer_lower_divertor(0)
# Distances outer_lower_divertor(1)
# 1 inner_lower_divertor(0)
# 1 inner_lower_divertor(1)
# 1 inner_core(0)
# 1 inner_core(1)
# 1 inner_upper_divertor(0)
# 1 inner_upper_divertor(1)
# 1 outer_upper_divertor(0)
# 1 outer_upper_divertor(1)
# 1 outer_core(0)
# 1 outer_core(1)
# 1 outer_lower_divertor(0)
# 1 outer_lower_divertor(1)
# outer_lower_divertor(0) calcHy 2 / 211
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1374: UserWarning: need to check that this is correct for non-orthogonal grids
#   warnings.warn("need to check that this is correct for non-orthogonal grids")
# Calculate zShiftrtor(1) calcHy 20 / 21
# Calculate Metricrtor(1))ivertor(1) inner_core(1)
# outer_core(0)ivertor(1)
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1795: RuntimeWarning: divide by zero encountered in divide
#   result.xlow[1:-1, :] = (f.centre[1:, :] - f.centre[:-1, :]) / self.dx.xlow[
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1802: RuntimeWarning: divide by zero encountered in divide
#   result.xlow[0, :] = (f.centre[0, :] - f.xlow[0, :]) / (
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1807: RuntimeWarning: divide by zero encountered in divide
#   result.xlow[-1, :] = (f_outer - f.centre[-1, :]) / self.dx.xlow[-1, :]
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1818: RuntimeWarning: divide by zero encountered in divide
#   result.corners[1:-1, :] = (
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1825: RuntimeWarning: divide by zero encountered in divide
#   result.corners[0, :] = (f.ylow[0, :] - f.corners[0, :]) / (
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1830: RuntimeWarning: divide by zero encountered in divide
#   result.corners[-1, :] = (f_outer - f.ylow[-1, :]) / self.dx.corners[
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1800: RuntimeWarning: divide by zero encountered in divide
#   result.xlow[0, :] = (f.centre[0, :] - f_inner) / self.dx.xlow[0, :]
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1809: RuntimeWarning: divide by zero encountered in divide
#   result.xlow[-1, :] = (f.xlow[-1, :] - f.centre[-1, :]) / (
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1823: RuntimeWarning: divide by zero encountered in divide
#   result.corners[0, :] = (f.ylow[0, :] - f_inner) / self.dx.corners[0, :]
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1834: RuntimeWarning: divide by zero encountered in divide
#   result.corners[-1, :] = (f.corners[-1, :] - f.ylow[-1, :]) / (
# outer_lower_divertor(1)

# %%
mesh.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 mesh["Rxy"]
#
# TypeError: 'BoutMesh' object is not subscriptable

# %%
fig, ax = plt.subplots(figsize = (5,7), dpi = 140)
# eq.plotPotential(ncontours=200, axis = ax, linewidths = 0.5)
eq.plotWall(axis = ax)
ax.plot(*eq.x_points[0], "rx",)
# mesh.plotPoints(xlow=False, ylow=False, corners=False, ax = ax, s = 2)
mesh.plotGridCellEdges(ax = ax, lw = 0.5)
eq.plotWall(axis = ax)
ax.grid(False)
ax.legend('', frameon=False)
# ax.set_xlim([0.15, 0.75]); ax.set_ylim([-0.86,-0.1])     # Both lower divertors
# ax.set_xlim([0.25, 0.6]); ax.set_ylim([-0.9,-0.7])     # Both lower divertors zoom
# ax.set_xlim([0.20, 0.45]); ax.set_ylim([0.6,0.8])     # Inner upper leg
# ax.set_xlim([0.62, 0.800]); ax.set_ylim([-0.08,0])     # OMP
# ax.set_xlim([0.12, 0.300]); ax.set_ylim([-0.15,0.05])     # IMP
ax.set_xlabel("R")
ax.set_ylabel("Z")
ax.set_aspect(1)
