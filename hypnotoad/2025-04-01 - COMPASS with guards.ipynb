# %%
import sys, os
import yaml
from hypnotoad import tokamak
from hypnotoad.core.mesh import BoutMesh
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from xbout import open_boutdataset


# This comes from https://github.com/mikekryjak/sdtools
sys.path.append(os.path.join(r"C:\Users\Mike\OneDrive\Project\python-packages\sdtools"))
from hermes3.grid_fields import *

# This is notebook stuff, it auto re-imports packages 
# %matplotlib qt
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Grid generation

# %% [markdown]
# Assume grid and input file have the same name

# %% [markdown]
# # I/O
# Read settings file and equilibrium

# %%
gridname = "compass-36x48_withguards"
path = os.path.join(r"C:\Users\Mike\OneDrive\Project\collab\tech\grid\COMPASS")
path_yaml = os.path.join(path, f"{gridname}.yml")
path_grid = os.path.join(path, f"{gridname}.nc")  # This is for the grid we generate and want to save somewhere
path_eq = r"C:\Users\Mike\OneDrive\Project\collab\tech\grid\COMPASS\compass.geqdsk"

# %% [markdown]
# # Plotting equilibrium and wall

# %%
def plot(loc):
    
    fig, ax = plt.subplots(dpi = 140)
    ax.plot(*eq.x_points[0], "rx",)
    # mesh.plotPoints(xlow=False, ylow=False, corners=False, ax = ax, s = 2)
    mesh.plotGridCellEdges(ax = ax, lw = 0.5)
    eq.plotWall(axis = ax, linewidth = 1, alpha = 0.3)
    ax.grid(False)
    ax.legend('', frameon=False)
    
    ax.set_xlabel("R")
    ax.set_ylabel("Z")
    ax.set_aspect(1)
    
    
    # ax.xaxis.set_ticks([])
    # ax.yaxis.set_ticks([])
    
    # ax.xaxis.label.set_visible(False)
    # ax.yaxis.label.set_visible(False)
    
    ax.set_frame_on(False)
    
    if loc == "lower":
        ax.set_xlim([0, None]); ax.set_ylim([None,None])     # Both lower divertors
    elif loc == "lower_zoom":
        ax.set_xlim([0.25, 0.6]); ax.set_ylim([-0.9,-0.7])     # Both lower divertors zoom
    elif loc == "inner_upper":
        ax.set_xlim([0.20, 0.45]); ax.set_ylim([0.6,0.8])     # Inner upper leg
    elif loc == "omp":
        ax.set_xlim([0.62, 0.800]); ax.set_ylim([-0.08,0])     # OMP
    elif loc == "imp":
        ax.set_xlim([0.12, 0.300]); ax.set_ylim([-0.15,0.05])     # IMP
    else:
        raise ValueError("Invalid location")
    
    ## PLOT REFERENCE
    # mesh2 = Mesh(r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3e2-lores_widev2.nc")
    # kwargs = dict(s= 10, zorder = 20, c = "k")
    # slicer = mesh2.slices("core_edge")
    # ax.scatter(mesh2.mesh["Rxy"][slicer].flatten(), mesh2.mesh["Zxy"][slicer].flatten(), label = "Reference", **kwargs)
    # slicer = mesh2.slices("sol_edge")
    # ax.scatter(mesh2.mesh["Rxy"][slicer].flatten(), mesh2.mesh["Zxy"][slicer].flatten(), **kwargs)
    # mesh2.close()
    
    plt.savefig(os.path.join(path, gridname + ".png"), dpi = 400, bbox_inches = "tight")
plot("lower")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 47
#      37     ## PLOT REFERENCE
#      38     # mesh2 = Mesh(r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3e2-lores_widev2.nc")
#      39     # kwargs = dict(s= 10, zorder = 20, c = "k")
#    (...)
#      43     # ax.scatter(mesh2.mesh["Rxy"][slicer].flatten(), mesh2.mesh["Zxy"][slicer].flatten(), **kwargs)
#      44     # mesh2.close()
#      46     plt.savefig(os.path.join(path, gridname + ".png"), dpi = 400, bbox_inches = "tight")
# ---> 47 plot("lower")
#
# Cell In[3], line 4, in plot(loc)
#       1 def plot(loc):
#       3     fig, ax = plt.subplots(dpi = 140)
# ----> 4     ax.plot(*eq.x_points[0], "rx",)
#       5     # mesh.plotPoints(xlow=False, ylow=False, corners=False, ax = ax, s = 2)
#       6     mesh.plotGridCellEdges(ax = ax, lw = 0.5)
#
# NameError: name 'eq' is not defined

# %% [markdown]
# ## Generate grid

# %%
# Outer sol 4->6 Nope
# All to 10-> OK
# Reduce nx to 2,2 -> ok
# Reduce divertor to 5,5 -> ok
# Reduce divertor to 4,4 -> ok
# Reduce SOL to 8,8 ->

# %%
# Read options
with open(path_yaml) as f:
	options = yaml.safe_load(f)
 
# Read geqdsk
with open(path_eq) as fh:
    eq = tokamak.read_geqdsk(fh, settings=options, nonorthogonal_settings=options)

mesh = BoutMesh(eq, options)
mesh.calculateRZ()
plot("lower")

mesh.geometry()
mesh.writeGridfile(path_grid)
# Out:
#   nx = 256, ny = 256
#
# Options
# =======
# Name                                              |  Value
# ================================================================================
# N_norm_prefactor                                  |  1.0             (default)
# extrapolate_profiles                              |  False           (default)
# finecontour_Nfine                                 |  100             (default)
# finecontour_atol                                  |  1e-12           (default)
# finecontour_diagnose                              |  False           (default)
# finecontour_extend_prefactor                      |  2.0             (default)
# finecontour_maxits                                |  200             (default)
# finecontour_overdamping_factor                    |  0.8             (default)
# leg_refine_atol                                   |  1e-05           (default)
# leg_refine_maxits                                 |  1000            (default)
# leg_trace_atol                                    |  2e-10           (default)
# nx_core                                           |  18
# nx_inter_sep                                      |  0               (default)
# nx_pf                                             |  18              (default)
# nx_sol                                            |  18
# nx_sol_inner                                      |  18              (default)
# nx_sol_outer                                      |  18              (default)
# ny_inner_divertor                                 |  8
# ny_inner_lower_divertor                           |  8               (default)
# ny_inner_sol                                      |  16              (default)
# ny_inner_upper_divertor                           |  8               (default)
# ny_outer_divertor                                 |  8
# ny_outer_lower_divertor                           |  8               (default)
# ny_outer_sol                                      |  16              (default)
# ny_outer_upper_divertor                           |  8               (default)
# ny_sol                                            |  32
# orthogonal                                        |  True
# poloidal_spacing_delta_psi                        |  None            (default)
# poloidal_spacing_method                           |  sqrt            (default)
# poloidalfunction_diagnose                         |  False           (default)
# psi_core                                          |  None            (default)
# psi_divide_twopi                                  |  False           (default)
# psi_interpolation_method                          |  spline          (default)
# psi_pf_lower                                      |  None            (default)
# psi_pf_upper                                      |  None            (default)
# psi_sol                                           |  None            (default)
# psi_sol_inner                                     |  None            (default)
# psi_spacing_separatrix_multiplier                 |  1.0             (default)
# psinorm_core                                      |  0.9             (default)
# psinorm_pf                                        |  0.9             (default)
# psinorm_pf_lower                                  |  0.9             (default)
# psinorm_pf_upper                                  |  0.9             (default)
# psinorm_sol                                       |  1.1             (default)
# psinorm_sol_inner                                 |  1.1             (default)
# refine_atol                                       |  2e-08           (default)
# refine_methods                                    |  ['integrate+newton', 'integrate'] (default)
# refine_timeout                                    |  10.0            (default)
# refine_width                                      |  1e-05           (default)
# reverse_Bt                                        |  False           (default)
# reverse_current                                   |  False           (default)
# sfunc_checktol                                    |  1e-13           (default)
# single_region                                     |  None            (default)
# start_at_upper_outer                              |  False           (default)
# target_all_poloidal_spacing_length                |  None            (default)
# target_inner_lower_poloidal_spacing_length        |  None            (default)
# target_inner_upper_poloidal_spacing_length        |  None            (default)
# target_outer_lower_poloidal_spacing_length        |  None            (default)
# target_outer_upper_poloidal_spacing_length        |  None            (default)
# xpoint_offset                                     |  0.1             (default)
# xpoint_poloidal_spacing_length                    |  0.05            (default)
# xpoint_refine_atol                                |  1e-06           (default)
# xpoint_refine_maxits                              |  1000            (default)
# y_boundary_guards                                 |  2
#
# Found X-point at psi = 8.741168782952754e-12, psi_norm = 1.0
# c:\pyenvs\fusion312\Lib\site-packages\scipy\integrate\_ivp\common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Generating a lower single null
#
# Options
# =======
# Name                                              |  Value
# ================================================================================
# N_norm_prefactor                                  |  1.0             (default)
# cap_Bp_ylow_xpoint                                |  False           (default)
# curvature_smoothing                               |  None            (default)
# curvature_type                                    |  curl(b/B)       (default)
# finecontour_Nfine                                 |  100             (default)
# finecontour_atol                                  |  1e-12           (default)
# finecontour_diagnose                              |  False           (default)
# finecontour_extend_prefactor                      |  2.0             (default)
# finecontour_maxits                                |  200             (default)
# finecontour_overdamping_factor                    |  0.8             (default)
# follow_perpendicular_atol                         |  1e-08           (default)
# follow_perpendicular_maxits                       |  10000           (default)
# follow_perpendicular_recover                      |  False           (default)
# follow_perpendicular_rtol                         |  2e-08           (default)
# geometry_rtol                                     |  1e-10           (default)
# number_of_processors                              |  1               (default)
# orthogonal                                        |  True
# poloidal_spacing_delta_psi                        |  None            (default)
# poloidal_spacing_method                           |  sqrt            (default)
# poloidalfunction_diagnose                         |  False           (default)
# psi_interpolation_method                          |  spline          (default)
# psi_spacing_separatrix_multiplier                 |  1.0             (default)
# refine_atol                                       |  2e-08           (default)
# refine_methods                                    |  ['integrate+newton', 'integrate'] (default)
# refine_timeout                                    |  10.0            (default)
# refine_width                                      |  1e-05           (default)
# sfunc_checktol                                    |  1e-13           (default)
# shiftedmetric                                     |  True            (default)
# target_all_poloidal_spacing_length                |  None            (default)
# target_inner_lower_poloidal_spacing_length        |  None            (default)
# target_inner_upper_poloidal_spacing_length        |  None            (default)
# target_outer_lower_poloidal_spacing_length        |  None            (default)
# target_outer_upper_poloidal_spacing_length        |  None            (default)
# wall_point_exclude_radius                         |  0.001           (default)
# xpoint_poloidal_spacing_length                    |  0.05            (default)
# y_boundary_guards                                 |  2
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 2.3329264084784307e-11
#   warnings.warn(
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:1364: RuntimeWarning: divide by zero encountered in scalar divide
#   s -= fprev / dfds(s)
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:110: RuntimeWarning: invalid value encountered in scalar multiply
#   return Point2D(self.R * other, self.Z * other)
# creating region 0 - inner_lower_divertor(0)
# Following perpendicular: 0
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 7.102196001446126e-12
#   warnings.warn(
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:1346: RuntimeWarning: invalid value encountered in multiply
#   return psi(*(p + s * tangent)) - self.psival
# Following perpendicular: 5
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 1.1262985986568164e-11
#   warnings.warn(
# creating region 1 - inner_lower_divertor(1)
# Following perpendicular: 9
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 7.323035840917091e-12
#   warnings.warn(
# creating region 2 - core(0)
# creating region 3 - core(1)
# Following perpendicular: 65
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 4.783599379240208e-10
#   warnings.warn(
# creating region 4 - outer_lower_divertor(0)
# Following perpendicular: 0
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 1.9331081559711277e-10
#   warnings.warn(
# Following perpendicular: 1
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 1.697275693471681e-10
#   warnings.warn(
# creating region 5 - outer_lower_divertor(1)
# Get RZ valuespendicular: 21
# Calculate geometry
# Distances inner_lower_divertor(0)
# Distances inner_lower_divertor(1)
# Calculating contour distances: 1
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 1.3554017934055973e-11
#   warnings.warn(
# Calculating contour distances: 2
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 4.125473183555495e-12
#   warnings.warn(
# Distances core(0)ur distances: 37
# Distances core(1)ur distances: 37
# Distances outer_lower_divertor(0)
# Distances outer_lower_divertor(1)
# Calculating contour distances: 1
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 1.3773042732354024e-10
#   warnings.warn(
# Calculating contour distances: 2
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 5.018704278113989e-11
#   warnings.warn(
# 1 inner_lower_divertor(0)nces: 37
# 1 inner_lower_divertor(1)
# 1 core(0)
# 1 core(1)
# 1 outer_lower_divertor(0)
# 1 outer_lower_divertor(1)
# Calculate zShiftrtor(1) calcHy 36 / 37
# Calculate Metricrtor(1)divertor(1)
# inner_lower_divertor(1)
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1814: RuntimeWarning: divide by zero encountered in divide
#   result.xlow[1:-1, :] = (f.centre[1:, :] - f.centre[:-1, :]) / self.dx.xlow[
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1821: RuntimeWarning: divide by zero encountered in divide
#   result.xlow[0, :] = (f.centre[0, :] - f.xlow[0, :]) / (
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1826: RuntimeWarning: divide by zero encountered in divide
#   result.xlow[-1, :] = (f_outer - f.centre[-1, :]) / self.dx.xlow[-1, :]
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1837: RuntimeWarning: divide by zero encountered in divide
#   result.corners[1:-1, :] = (
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1844: RuntimeWarning: divide by zero encountered in divide
#   result.corners[0, :] = (f.ylow[0, :] - f.corners[0, :]) / (
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1849: RuntimeWarning: divide by zero encountered in divide
#   result.corners[-1, :] = (f_outer - f.ylow[-1, :]) / self.dx.corners[
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1819: RuntimeWarning: divide by zero encountered in divide
#   result.xlow[0, :] = (f.centre[0, :] - f_inner) / self.dx.xlow[0, :]
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1828: RuntimeWarning: divide by zero encountered in divide
#   result.xlow[-1, :] = (f.xlow[-1, :] - f.centre[-1, :]) / (
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1842: RuntimeWarning: divide by zero encountered in divide
#   result.corners[0, :] = (f.ylow[0, :] - f_inner) / self.dx.corners[0, :]
# C:\Users\Mike\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1853: RuntimeWarning: divide by zero encountered in divide
#   result.corners[-1, :] = (f.corners[-1, :] - f.ylow[-1, :]) / (
# outer_lower_divertor(1)

# %% [markdown]
# Plot grid

# %%
fig, ax = plt.subplots()
eq.plotPotential(axis = ax, ncontours = 100)
# eq.plotSeparatrix(axis = ax)
eq.plotWall(axis = ax)
mesh.plotGridCellEdges(ax = ax)
ax.set_aspect("equal")

# Both lower divertors
plt.xlim([0, 1.2])
plt.ylim([-2.0,-0.8])
# Out:
# (-2.0, -0.8)

# %% [markdown]
# # Save

# %%
mesh.geometry()
mesh.writeGridfile(path_grid)
# Out:
# Calculate geometry
# Distances inner_lower_divertor(0)
# Distances inner_lower_divertor(1)
# Distances inner_core(0)tances: 5
# Calculating contour distances: 3
# ---------------------------------------------------------------------------
# SolutionError                             Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 mesh.geometry()
#       2 mesh.writeGridfile(path_grid)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:3576, in BoutMesh.geometry(self)
#    3574 def geometry(self):
#    3575     # Call geometry() method of base class
# -> 3576     super().geometry()
#    3578     def addFromRegions(name, *, all_corners=False):
#    3579         # Collect a 2d field from the regions
#    3580         self.fields_to_output.append(name)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:2844, in Mesh.geometry(self)
#    2842 for region in self.regions.values():
#    2843     print("Distances", region.name, flush=True)
# -> 2844     region.calcDistances()
#    2845 for region in self.regions.values():
#    2846     print("1", region.name, flush=True)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:826, in MeshRegion.calcDistances(self)
#     821 """
#     822 Calculate the distances for all PsiContours in the region
#     823 """
#     824 if self.user_options.orthogonal:
#     825     # Distances already calculated in non-orthogonal case
# --> 826     self.contours = self.parallel_map(
#     827         _calc_contour_distance, enumerate(self.contours)
#     828     )
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\utils\parallel_map.py:80, in ParallelMap.__call__(self, function, args_list, **kwargs)
#      77 def __call__(self, function, args_list, **kwargs):
#      78     if self.workers is None:
#      79         return [
# ---> 80             function(
#      81                 *args,
#      82                 equilibrium=self.equilibrium,
#      83                 psi=self.psi,
#      84                 f_R=self.f_R,
#      85                 f_Z=self.f_Z,
#      86                 **kwargs,
#      87             )
#      88             for args in args_list
#      89         ]
#      91     args_list = tuple(args_list)
#      92     n_tasks = len(args_list)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:2350, in _calc_contour_distance(i, c, psi, **kwargs)
#    2344 def _calc_contour_distance(i, c, *, psi, **kwargs):
#    2345     print(
#    2346         f"Calculating contour distances: {i + 1}",
#    2347         end="\r",
#    2348         flush=True,
#    2349     )
# -> 2350     c.get_distance(psi=psi)
#    2351     return c
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:1173, in PsiContour.get_distance(self, psi)
#    1171 def get_distance(self, *, psi):
#    1172     if self._distance is None:
# -> 1173         fine_contour = self.get_fine_contour(psi=psi)
#    1174         self._distance = [fine_contour.getDistance(p) for p in self]
#    1175         d = numpy.array(self._distance)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:1166, in PsiContour.get_fine_contour(self, psi)
#    1164 if psi is None:
#    1165     raise ValueError("Poloidal flux psi needed to create FineContour")
# -> 1166 self._fine_contour = FineContour(self, dict(self.user_options), psi=psi)
#    1167 # Ensure that the fine contour is long enough
#    1168 self.checkFineContourExtend(psi=psi)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:564, in FineContour.__init__(self, parentContour, settings, psi)
#     557 self.positions[self.startInd] = self.parentContour[
#     558     self.parentContour.startInd
#     559 ].as_ndarray()
#     560 self.positions[self.endInd] = self.parentContour[
#     561     self.parentContour.endInd
#     562 ].as_ndarray()
# --> 564 self.equaliseSpacing(psi=psi)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:687, in FineContour.equaliseSpacing(self, psi, reallocate)
#     651 def equaliseSpacing(self, *, psi, reallocate=False):
#     652     """
#     653     Adjust the positions of points in this :class:`FineContour
#     654     <hypnotoad.core.equilibrium.FineContour>` so they have a constant distance
#    (...)
#     684     produce some more output which may help diagnose them.
#     685     """
# --> 687     self.refine(psi=psi, skip_endpoints=True)
#     689     self.calcDistance(reallocate=reallocate)
#     691     ds = self.distance[1:] - self.distance[:-1]
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:894, in FineContour.refine(self, psi, skip_endpoints, **kwargs)
#     888     self.positions = result
#     890 if self.user_options.refine_timeout is not None:
#     891     # Using func_timeout.func_timeout rather than the
#     892     # @func_timeout.func_set_timeout decorator on the refine method so that we
#     893     # can use self.user_options to set the length of the timeout.
# --> 894     func_timeout.func_timeout(
#     895         self.user_options.refine_timeout,
#     896         refine,
#     897         [self],
#     898         kwargs={"skip_endpoints": skip_endpoints},
#     899     )
#     900 else:
#     901     refine(self, skip_endpoints=skip_endpoints)
#
# File c:\pyenvs\fusion312\Lib\site-packages\func_timeout\dafunc.py:108, in func_timeout(timeout, func, args, kwargs)
#     105     thread.join(.5)
#     107 if exception:
# --> 108     raise_exception(exception)
#     110 if ret:
#     111     return ret[0]
#
# File c:\pyenvs\fusion312\Lib\site-packages\func_timeout\py3_raise.py:7, in raise_exception(exception)
#       6 def raise_exception(exception):
# ----> 7     raise exception[0] from None
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:875, in FineContour.refine.<locals>.refine(self, skip_endpoints)
#     873     p = self.positions[i, :]
#     874     tangent = self.positions[i + 1, :] - self.positions[i - 1, :]
# --> 875     result[i, :] = self.parentContour.refinePoint(
#     876         Point2D(*p), Point2D(*tangent), psi=psi
#     877     ).as_ndarray()
#     878 p = self.positions[-1, :]
#     879 tangent = self.positions[-1, :] - self.positions[-2, :]
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:1558, in PsiContour.refinePoint(self, p, tangent, psi, width, atol, methods, **kwargs)
#    1554         pass
#    1556 # All methods failed. If the user wants to continue anyway,
#    1557 # the last method in the methods list can be set to "none"
# -> 1558 raise SolutionError(f"refinePoint failed to converge with methods: {methods}")
#
# SolutionError: refinePoint failed to converge with methods: ['line']
