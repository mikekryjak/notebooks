# %%
import sys, os
import yaml
from hypnotoad import tokamak
from hypnotoad.core.mesh import BoutMesh
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

onedrive_path = onedrive_path = str(os.getcwd()).split("OneDrive")[0] + "OneDrive"
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages\sdtools"))
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages\soledge"))
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages"))

from gridtools.hypnotoad_tools import *
from gridtools.b2_tools import *
# import solps_python_scripts.setup
# from solps_python_scripts.plot_solps       import plot_mesh, plot_wall_loads
# from solps_python_scripts import *
from xbout import open_boutdataset
import h5py

# %matplotlib qt
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from routines.h5_routines 				import h5_read

soledge_path = os.path.join(onedrive_path, r"Project\collab\tech\compare_data\soledge_cases\copy_wallMike_bra_nocore_D")

# Extract geom and make triangulation
if_tri	 = h5py.File(os.path.join(soledge_path,"triangles.h5"), "r")
TriKnots = h5_read(if_tri,"triangles/tri_knots")
TriKnots = TriKnots - 1 										#Matlab/Fortan to python indexes
R		 = h5_read(if_tri,"knots/R")*0.01
Z		 = h5_read(if_tri,"knots/Z")*0.01

# %%
# %matplotlib inline

# %%
gridname = "g4a1-soledge_style"
path = os.path.join(onedrive_path, r"Project\collab\tech\grid\ST40\4-soledge_optimised")

path_yaml = os.path.join(path, f"{gridname}.yml")
path_grid = os.path.join(path, f"{gridname}.nc")

options = Options(path_yaml).yml


# options["psi_core"] = -0.0707
# options["psinorm_sol"] = 1.43



with open(os.path.join(onedrive_path, r"Project\collab\tech\grid\ST40\4-soledge_optimised\ST40_P3_eq_0015_modgeom.geqdsk"), "rt") as fh:
    eq = tokamak.read_geqdsk(fh, settings=options, nonorthogonal_settings=options)


mesh = BoutMesh(eq, options)
# mesh.redistributePoints(options)

mesh.calculateRZ()

fig, ax = plt.subplots(figsize = (5,7), dpi = 140)
# eq.plotPotential(ncontours=200, axis = ax, linewidths = 0.5)
eq.plotWall(axis = ax)
ax.plot(*eq.x_points[0], "rx",)
mesh.plotPoints(xlow=False, ylow=False, corners=False, ax = ax, s = 2)
eq.plotWall(axis = ax)

ax.grid()
ax.legend('', frameon=False)
ax.set_xlim([0.15, 0.65]); ax.set_ylim([-0.86,-0.2])     # Both lower divertors
# ax.set_xlim([0.20, 0.45]); ax.set_ylim([0.6,0.8])     # Inner upper leg
# ax.set_xlim([0.62, 0.800]); ax.set_ylim([-0.08,0])     # OMP
# ax.set_xlim([0.12, 0.300]); ax.set_ylim([-0.15,0.05])     # IMP

ax.set_xlabel("R")
ax.set_ylabel("Z")
ax.set_aspect(1)

fig.show()



try:
    ax.scatter(R, Z, s = 8, c = "black", marker = "o", edgecolor = "k", alpha = 1, linewidths = 0.2)
except:
    print("Couldn't plot b2")
# Out:
#   nx = 33, ny = 65
# 250
#
# Options
# =======
# Name                                              |  Value
# ================================================================================
# N_norm_prefactor                                  |  1.0             (default)
# extrapolate_profiles                              |  False           (default)
# finecontour_Nfine                                 |  100             (default)
# finecontour_atol                                  |  1e-12           (default)
# finecontour_diagnose                              |  False           (default)
# finecontour_extend_prefactor                      |  2.0             (default)
# finecontour_maxits                                |  200             (default)
# finecontour_overdamping_factor                    |  0.8             (default)
# leg_refine_atol                                   |  1e-05           (default)
# leg_refine_maxits                                 |  1000            (default)
# leg_trace_atol                                    |  2e-10           (default)
# nx_core                                           |  20
# nx_inter_sep                                      |  0               (default)
# nx_pf                                             |  20              (default)
# nx_sol                                            |  20
# nx_sol_inner                                      |  20              (default)
# nx_sol_outer                                      |  20              (default)
# ny_inner_divertor                                 |  10
# ny_inner_lower_divertor                           |  10              (default)
# ny_inner_sol                                      |  20
# ny_inner_upper_divertor                           |  10              (default)
# ny_outer_divertor                                 |  20
# ny_outer_lower_divertor                           |  20              (default)
# ny_outer_sol                                      |  20
# ny_outer_upper_divertor                           |  20              (default)
# ny_sol                                            |  8               (default)
# orthogonal                                        |  True
# poloidal_spacing_delta_psi                        |  None            (default)
# poloidal_spacing_method                           |  sqrt            (default)
# poloidalfunction_diagnose                         |  False           (default)
# psi_core                                          |  -0.0707
# psi_interpolation_method                          |  spline          (default)
# psi_pf_lower                                      |  None            (default)
# psi_pf_upper                                      |  None            (default)
# psi_sol                                           |  None            (default)
# psi_sol_inner                                     |  None            (default)
# psi_spacing_separatrix_multiplier                 |  1.0             (default)
# psinorm_core                                      |  0.9             (default)
# psinorm_pf                                        |  0.928
# psinorm_pf_lower                                  |  0.928           (default)
# psinorm_pf_upper                                  |  0.928           (default)
# psinorm_sol                                       |  1.43
# psinorm_sol_inner                                 |  1.32
# refine_atol                                       |  2e-08           (default)
# refine_methods                                    |  ['integrate+newton', 'integrate'] (default)
# refine_timeout                                    |  10.0            (default)
# refine_width                                      |  1e-05           (default)
# reverse_Bt                                        |  True
# reverse_current                                   |  True
# sfunc_checktol                                    |  1e-13           (default)
# start_at_upper_outer                              |  False           (default)
# target_all_poloidal_spacing_length                |  None            (default)
# target_inner_lower_poloidal_spacing_length        |  None            (default)
# target_inner_upper_poloidal_spacing_length        |  None            (default)
# target_outer_lower_poloidal_spacing_length        |  0.2
# target_outer_upper_poloidal_spacing_length        |  0.2
# xpoint_offset                                     |  0.1             (default)
# xpoint_poloidal_spacing_length                    |  0.2
# xpoint_refine_atol                                |  1e-06           (default)
# xpoint_refine_maxits                              |  1000            (default)
# y_boundary_guards                                 |  2
#
# Generating a connected double null
#
# Options
# =======
# Name                                              |  Value
# ================================================================================
# N_norm_prefactor                                  |  1.0             (default)
# cap_Bp_ylow_xpoint                                |  False           (default)
# curvature_smoothing                               |  None            (default)
# curvature_type                                    |  curl(b/B)       (default)
# finecontour_Nfine                                 |  100             (default)
# finecontour_atol                                  |  1e-12           (default)
# finecontour_diagnose                              |  False           (default)
# finecontour_extend_prefactor                      |  2.0             (default)
# finecontour_maxits                                |  200             (default)
# finecontour_overdamping_factor                    |  0.8             (default)
# follow_perpendicular_atol                         |  1e-08           (default)
# follow_perpendicular_rtol                         |  2e-08           (default)
# geometry_rtol                                     |  1e-10           (default)
# number_of_processors                              |  1               (default)
# orthogonal                                        |  True
# poloidal_spacing_delta_psi                        |  None            (default)
# poloidal_spacing_method                           |  sqrt            (default)
# poloidalfunction_diagnose                         |  False           (default)
# psi_interpolation_method                          |  spline          (default)
# psi_spacing_separatrix_multiplier                 |  1.0             (default)
# refine_atol                                       |  2e-08           (default)
# refine_methods                                    |  ['integrate+newton', 'integrate'] (default)
# refine_timeout                                    |  10.0            (default)
# refine_width                                      |  1e-05           (default)
# sfunc_checktol                                    |  1e-13           (default)
# shiftedmetric                                     |  True            (default)
# target_all_poloidal_spacing_length                |  None            (default)
# target_inner_lower_poloidal_spacing_length        |  None            (default)
# target_inner_upper_poloidal_spacing_length        |  None            (default)
# target_outer_lower_poloidal_spacing_length        |  0.2
# target_outer_upper_poloidal_spacing_length        |  0.2
# wall_point_exclude_radius                         |  0.001           (default)
# xpoint_poloidal_spacing_length                    |  0.2
# y_boundary_guards                                 |  2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 19
#      15 with open(os.path.join(onedrive_path, r"Project\collab\tech\grid\ST40\4-soledge_optimised\ST40_P3_eq_0015_modgeom.geqdsk"), "rt") as fh:
#      16     eq = tokamak.read_geqdsk(fh, settings=options, nonorthogonal_settings=options)
# ---> 19 mesh = BoutMesh(eq, options)
#      20 # mesh.redistributePoints(options)
#      22 mesh.calculateRZ()
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:3242, in BoutMesh.__init__(self, equilibrium, settings)
#    3241 def __init__(self, equilibrium, settings):
# -> 3242     super().__init__(equilibrium, settings)
#    3244     # nx, ny both include boundary guard cells
#    3245     eq_region0 = next(iter(self.equilibrium.regions.values()))
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:2618, in Mesh.__init__(self, equilibrium, settings)
#    2611             self.connections[region_id][key] = None
#    2613 parallel_map = ParallelMap(
#    2614     self.user_options.number_of_processors,
#    2615     equilibrium=self.equilibrium,
#    2616 )
# -> 2618 self.makeRegions(parallel_map)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:2624, in Mesh.makeRegions(self, parallel_map)
#    2622     for i in range(eq_region.nSegments):
#    2623         region_id = self.region_lookup[(eq_region.name, i)]
# -> 2624         eq_region_with_boundaries = eq_region.getRegridded(
#    2625             radialIndex=i,
#    2626             psi=self.equilibrium.psi,
#    2627             width=self.user_options.refine_width,
#    2628         )
#    2629         self.regions[region_id] = MeshRegion(
#    2630             self,
#    2631             region_id,
#    (...)
#    2636             parallel_map,
#    2637         )
#    2639 # create groups that connect in x
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:2698, in EquilibriumRegion.getRegridded(self, radialIndex, psi, **kwargs)
#    2696     extend_upper = 0
#    2697 distance = self.get_distance(psi=psi)
# -> 2698 sfunc = self.getSfuncFixedSpacing(
#    2699     2 * self.ny_noguards + 1,
#    2700     distance[self.endInd] - distance[self.startInd],
#    2701 )
#    2702 return self.newRegionFromPsiContour(
#    2703     super().getRegridded(
#    2704         2 * self.ny_noguards + 1,
#    (...)
#    2710     )
#    2711 )
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:2760, in EquilibriumRegion.getSfuncFixedSpacing(self, npoints, distance, method, spacing_lower, spacing_upper)
#    2758         print("a_upper =", spacings["sqrt_a_upper"])
#    2759         print("b_upper =", spacings["sqrt_b_upper"])
# -> 2760     sfunc = self.getSqrtPoloidalDistanceFunc(
#    2761         distance,
#    2762         npoints - 1,
#    2763         self.user_options.N_norm_prefactor * self.ny_total,
#    2764         b_lower=spacings["sqrt_b_lower"],
#    2765         a_lower=spacings["sqrt_a_lower"],
#    2766         b_upper=spacings["sqrt_b_upper"],
#    2767         a_upper=spacings["sqrt_a_upper"],
#    2768     )
#    2769     self._checkMonotonic([(sfunc, "sqrt")], total_distance=distance)
#    2770 elif method == "monotonic":
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:3497, in EquilibriumRegion.getSqrtPoloidalDistanceFunc(self, length, N, N_norm, b_lower, a_lower, b_upper, a_upper)
#    3493 # check function is monotonic: gradients at beginning and end should both be
#    3494 # positive.
#    3495 # lower boundary:
#    3496 if b / (2.0 * numpy.sqrt(N / N_norm)) + d <= 0.0:
# -> 3497     raise ValueError("gradient at start should be positive")
#    3498 # upper boundary:
#    3499 if b < 0.0:
#
# ValueError: gradient at start should be positive

# %%
fig, ax = plt.subplots(figsize = (4,8), dpi = 120)
eq.plotPotential(ncontours=200, axis = ax, linewidths = 0.5)
eq.plotWall(axis = ax)
ax.plot(*eq.x_points[0], "rx",)
mesh.plotPoints(xlow=False, ylow=False, corners=False, ax = ax, s = 2)
eq.plotWall(axis = ax)
ax.set_aspect("equal")

# %%
mesh.geometry()
mesh.writeGridfile(path_grid)
# Out:
# Calculate geometry
# Distances inner_lower_divertor(0)
# Distances inner_lower_divertor(1)
# Calculating contour distances: 1
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 5.549923368097787e-12
#   warnings.warn(
# Calculating contour distances: 3
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 4.22004835590184e-12
#   warnings.warn(
# Distances core(0)ur distances: 201
# Distances core(1)ur distances: 73
# Calculating contour distances: 154
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.010664617204321589
#   warnings.warn(
# Calculating contour distances: 155
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.005871337243059497
#   warnings.warn(
# Calculating contour distances: 156
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.00010195230406648617
#   warnings.warn(
# Calculating contour distances: 157
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.02061483386094425
#   warnings.warn(
# Calculating contour distances: 158
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.025232545955988193
#   warnings.warn(
# Calculating contour distances: 159
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.029811473629806396
#   warnings.warn(
# Calculating contour distances: 160
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.03402069154744354
#   warnings.warn(
# Calculating contour distances: 161
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.03794437727750931
#   warnings.warn(
# Calculating contour distances: 162
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.04164534975077014
#   warnings.warn(
# Calculating contour distances: 163
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.045137058405568545
#   warnings.warn(
# Calculating contour distances: 164
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.048489110602851465
#   warnings.warn(
# Calculating contour distances: 165
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.05168627308573244
#   warnings.warn(
# Calculating contour distances: 166
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.05476356982740151
#   warnings.warn(
# Calculating contour distances: 167
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.05771925299229495
#   warnings.warn(
# Calculating contour distances: 168
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.060560097567260204
#   warnings.warn(
# Calculating contour distances: 169
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.06334870049913681
#   warnings.warn(
# Calculating contour distances: 170
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.06606392185598436
#   warnings.warn(
# Calculating contour distances: 171
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.06870416332233215
#   warnings.warn(
# Calculating contour distances: 172
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.07126342934779292
#   warnings.warn(
# Calculating contour distances: 173
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.07376939818161157
#   warnings.warn(
# Calculating contour distances: 174
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.07622893084939701
#   warnings.warn(
# Calculating contour distances: 175
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.07863503608076805
#   warnings.warn(
# Calculating contour distances: 176
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.08103700415517298
#   warnings.warn(
# Calculating contour distances: 177
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.08338222005844906
#   warnings.warn(
# Calculating contour distances: 178
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.08568011374149669
#   warnings.warn(
# Calculating contour distances: 179
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.08794018955630925
#   warnings.warn(
# Calculating contour distances: 180
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.09015870523314572
#   warnings.warn(
# Calculating contour distances: 181
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.06521634969132933
#   warnings.warn(
# Calculating contour distances: 182
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.06657843664014801
#   warnings.warn(
# Calculating contour distances: 183
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.06794284231678253
#   warnings.warn(
# Calculating contour distances: 184
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.06931808302443468
#   warnings.warn(
# Calculating contour distances: 185
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.07061128234808178
#   warnings.warn(
# Calculating contour distances: 186
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.07162038321320333
#   warnings.warn(
# Calculating contour distances: 187
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.07275728394069973
#   warnings.warn(
# Calculating contour distances: 188
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.07395224618592028
#   warnings.warn(
# Calculating contour distances: 189
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.07520865717685733
#   warnings.warn(
# Calculating contour distances: 190
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.07651497843806303
#   warnings.warn(
# Calculating contour distances: 191
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.07786709844053628
#   warnings.warn(
# Calculating contour distances: 192
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.0792498546232679
#   warnings.warn(
# Calculating contour distances: 193
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.08065612944513409
#   warnings.warn(
# Calculating contour distances: 194
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.08205512653692212
#   warnings.warn(
# Calculating contour distances: 195
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.08346554514505429
#   warnings.warn(
# Calculating contour distances: 196
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.08491896358245181
#   warnings.warn(
# Calculating contour distances: 197
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.05172450904646127
#   warnings.warn(
# Calculating contour distances: 198
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.05517813319670775
#   warnings.warn(
# Calculating contour distances: 199
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.05803410013226039
#   warnings.warn(
# Calculating contour distances: 200
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.05936226529618682
#   warnings.warn(
# Calculating contour distances: 201
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.060428657140386685
#   warnings.warn(
# Distances outer_lower_divertor(0)
# Calculating contour distances: 4
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.061414952676829775
#   warnings.warn(
# Distances outer_lower_divertor(1)
# Calculating contour distances: 1
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 2.9554480932870997e-11
#   warnings.warn(
# Calculating contour distances: 3
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 3.833989213348349e-11
#   warnings.warn(
# 1 inner_lower_divertor(0)nces: 201
# 1 inner_lower_divertor(1)
# 1 core(0)
# 1 core(1)
# 1 outer_lower_divertor(0)
# 1 outer_lower_divertor(1)
# Calculate zShiftrtor(1) calcHy 200 / 201
# Calculate Metricrtor(1)divertor(1)
# inner_lower_divertor(1)
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1708: RuntimeWarning: divide by zero encountered in true_divide
#   result.xlow[1:-1, :] = (f.centre[1:, :] - f.centre[:-1, :]) / self.dx.xlow[
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1715: RuntimeWarning: divide by zero encountered in true_divide
#   result.xlow[0, :] = (f.centre[0, :] - f.xlow[0, :]) / (
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1720: RuntimeWarning: divide by zero encountered in true_divide
#   result.xlow[-1, :] = (f_outer - f.centre[-1, :]) / self.dx.xlow[-1, :]
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1731: RuntimeWarning: divide by zero encountered in true_divide
#   result.corners[1:-1, :] = (
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1738: RuntimeWarning: divide by zero encountered in true_divide
#   result.corners[0, :] = (f.ylow[0, :] - f.corners[0, :]) / (
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1743: RuntimeWarning: divide by zero encountered in true_divide
#   result.corners[-1, :] = (f_outer - f.ylow[-1, :]) / self.dx.corners[
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1713: RuntimeWarning: divide by zero encountered in true_divide
#   result.xlow[0, :] = (f.centre[0, :] - f_inner) / self.dx.xlow[0, :]
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1722: RuntimeWarning: divide by zero encountered in true_divide
#   result.xlow[-1, :] = (f.xlow[-1, :] - f.centre[-1, :]) / (
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1736: RuntimeWarning: divide by zero encountered in true_divide
#   result.corners[0, :] = (f.ylow[0, :] - f_inner) / self.dx.corners[0, :]
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:1747: RuntimeWarning: divide by zero encountered in true_divide
#   result.corners[-1, :] = (f.corners[-1, :] - f.ylow[-1, :]) / (
# outer_lower_divertor(1)

# %%
from boututils.datafile import DataFile

path = r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3b1-lores_newhypno.nc"
# path = r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3a5-fatter.nc"

m = DataFile(path)
# with DataFile(path) as m:
    # print(m.keys())

# %%
import gridtools.gridue_to_bout
gridue = gridtools.gridue_to_bout.importGridue(r"C:\Users\mikek\OneDrive\Project\python-packages\gridtools\UEDGE_102x36")
r_u, z_u = gridtools.gridue_to_bout.plot(gridue)
# Out:
# (104, 38, 5)
# C:\Users\mikek\OneDrive\Project\python-packages\gridtools\gridue_to_bout.py:161: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   np.concatenate((r[i][j][idx], z[i][j][idx])).reshape(2, 5).T,

# %% [markdown]
# ## UEDGE point order test

# %%
fig, ax = plt.subplots()

s = 70

id = 10
ax.scatter(r_u[id,id,0], z_u[id,id,0], s = s, label = "Center")
ax.scatter(r_u[id,id,1], z_u[id,id,1], s = s, label = "Lower left")
ax.scatter(r_u[id,id,2], z_u[id,id,2], s = s, label = "Lower right")
ax.scatter(r_u[id,id,3], z_u[id,id,3], s = s, label = "Upper left")
ax.scatter(r_u[id,id,4], z_u[id,id,4], s = s, label = "Upper right")

ax.legend()

# %% [markdown]
# ## Hypnotoad point order test

# %%
fig, ax = plt.subplots()

s = 70

id = 12
ax.scatter(r[id,id,0], z[id,id,0], s = s, label = "Center")
ax.scatter(r[id,id,1], z[id,id,1], s = s, label = "Lower left")
ax.scatter(r[id,id,2], z[id,id,2], s = s, label = "Lower right")
ax.scatter(r[id,id,3], z[id,id,3], s = s, label = "Upper left")
ax.scatter(r[id,id,4], z[id,id,4], s = s, label = "Upper right")

ax.legend()

# %%
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30836\2983690941.py in <module>
# ----> 1 mesh.writeGridfile(path_grid)
#
# ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py in writeGridfile(self, filename)
#    3465         from boututils.datafile import DataFile
#    3466
# -> 3467         with DataFile(filename, create=True, format="NETCDF4") as f:
#    3468             # Save unique ID for grid file
#    3469             import uuid
#
# c:\Users\mikek\anaconda3\lib\site-packages\boututils\datafile.py in __init__(self, filename, write, create, format, **kwargs)
#      99                 )
#     100             else:
# --> 101                 self.impl = DataFile_netCDF(
#     102                     filename=filename,
#     103                     write=write,
#
# c:\Users\mikek\anaconda3\lib\site-packages\boututils\datafile.py in __init__(self, filename, write, create, format, **kwargs)
#     378             raise ImportError(message)
#     379         if filename is not None:
# --> 380             self.open(filename, write=write, create=create, format=format)
#     381         self._attributes_cache = {}
#     382
#
# c:\Users\mikek\anaconda3\lib\site-packages\boututils\datafile.py in open(self, filename, write, create, format)
#     354             self.handle = Dataset(filename, "r")
#     355         elif create:
# --> 356             self.handle = Dataset(filename, "w", format=format)
#     357         else:
#     358             self.handle = Dataset(filename, "a")
#
# src\netCDF4\_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# src\netCDF4\_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# PermissionError: [Errno 13] Permission denied: b'C:\\Users\\mikek\\OneDrive\\Project\\collab\\tech\\grid\\ST40\\matteo-mod\\g3b1-lores_newhypno.nc'

# %%
# %matplotlib inline
# %matplotlib qt

# %%
def make_colors(number, cmap):
    """make_colors(number of colours, matplotlib colormap function)"""
    colors = []
    idx = np.linspace(0,255,number)
    
    for i in range(number):
        colors.append(cmap(int(idx[i])))
                    
    return colors
import matplotlib as mpl
make_colors(10, plt.get_cmap("jet"))
# Out:
# [(0.0, 0.0, 0.5, 1.0),
#  (0.0, 0.0, 0.999108734402852, 1.0),
#  (0.0, 0.3784313725490196, 1.0, 1.0),
#  (0.0, 0.8333333333333334, 1.0, 1.0),
#  (0.30044275774826057, 1.0, 0.6672991777356103, 1.0),
#  (0.6546489563567361, 1.0, 0.31309297912713474, 1.0),
#  (1.0, 0.9012345679012348, 0.0, 1.0),
#  (1.0, 0.4945533769063183, 0.0, 1.0),
#  (1.0, 0.08787218591140178, 0.0, 1.0),
#  (0.5, 0.0, 0.0, 1.0)]

# %%
fig, ax = plt.subplots(figsize = (8,4), dpi = 200)
eq.plotPotential(ncontours=40, axis = ax, linewidths = 0.5)
eq.plotWall(axis = ax)
ax.plot(*eq.x_points[0], "rx",)
# mesh.plotPoints(xlow=False, ylow=False, corners=False, ax = ax, s = 1,  plot_types = ["poloidal", "radial"], linewidths = 0.1)
mesh.plotPoints(xlow=False, ylow=False, corners=False, ax = ax, s = 5,  plot_types = ["scatter"], linewidths = 1)
eq.plotWall(axis = ax)

ax.grid()
ax.legend('', frameon=False)
ax.set_xlim([0.15, 0.65]); ax.set_ylim([-0.86,-0.5])     # Both lower divertors

ax.set_xlabel("R")
ax.set_ylabel("Z")
ax.set_aspect(1)

# ax.scatter(mesh.Rxy, mesh.Zxy, s = 5, c = "k", edgecolor = "k", alpha = 1, linewidths = 0.2)
# ax.scatter(b2.x, b2.y, s = 5, c = "magenta", edgecolor = "k", alpha = 1, linewidths = 0.2)

# fig.show()

# %%
fig, ax = plt.subplots(figsize = (8,4), dpi = 120)
eq.plotPotential(ncontours=40, axis = ax, linewidths = 0.5)
eq.plotWall(axis = ax)
ax.plot(*eq.x_points[0], "rx",)
mesh.plotPoints(xlow=False, ylow=False, corners=False, ax = ax, s = 2)
eq.plotWall(axis = ax)

ax.grid()
ax.legend('', frameon=False)
ax.set_xlim([0.15, 0.65]); ax.set_ylim([-0.86,-0.5])     # Both lower divertors

ax.set_xlabel("R")
ax.set_ylabel("Z")
ax.set_aspect(1)

fig.show()

ax.scatter(b2.x, b2.y, s = 3, c = "magenta", edgecolor = "k", alpha = 1, linewidths = 0.2)

# %%
mesh.x_groups[0]
# Out:
# [<hypnotoad.core.mesh.MeshRegion at 0x257c22e54c0>,
#  <hypnotoad.core.mesh.MeshRegion at 0x257c22f13a0>]

# %% [markdown]
# # Run Mesh piecewise

# %%
from hypnotoad.utils.parallel_map import ParallelMap
from hypnotoad.core.mesh import MeshRegion

# %%
self = mesh


parallel_map = ParallelMap(
            self.user_options.number_of_processors,
            equilibrium=self.equilibrium,
        )

# %%
region_id = self.region_lookup[("outer_upper_divertor", 1)]
region_id
# Out:
# 7

# %%
eq_region = self.equilibrium.regions['outer_upper_divertor']

i = 0

region_id = self.region_lookup[(eq_region.name, i)]

eq_region_with_boundaries = eq_region.getRegridded(
                    radialIndex=i,
                    psi=self.equilibrium.psi,
                    width=self.user_options.refine_width,
                )

mesh = MeshRegion(
                    self,
                    region_id,
                    eq_region_with_boundaries,
                    self.connections[region_id],
                    i,
                    self.user_options,
                    parallel_map,
                )
# Out:
# [0.         0.00333527 0.00667048 0.01000573]
# [0.         0.00333515 0.00667042 0.01000563]
# [0.         0.00333519 0.00667034 0.01000561]
# [0.         0.00333523 0.00667042 0.01000557]
# [0.         0.00333527 0.0066705  0.01000569]
# [0.         0.00333531 0.00667058 0.01000581]
# [0.         0.00333535 0.00667066 0.01000593]
# [0.         0.00333539 0.00667074 0.01000605]
# [0.         0.00333527 0.0066705  0.01000569]
# [0.         0.00333531 0.00667058 0.01000581]
# [0.         0.00333535 0.00667066 0.01000593]
# [0.         0.00333539 0.00667074 0.01000605]
# [0.         0.00333545 0.00667084 0.01000619]
# [0.         0.00333551 0.00667096 0.01000635]
# [0.         0.0033356  0.00667112 0.01000656]
# [0.         0.00333572 0.00667132 0.01000684]
# [0.         0.00333589 0.00667161 0.01000721]
# [0.         0.00333613 0.00667201 0.01000774]
# [0.         0.00333648 0.00667261 0.01000849]
# [-0.14945711 -0.14612063 -0.14278451 -0.13944862 -0.1361129  -0.1327773
#  -0.12944178 -0.12610634 -0.12277094 -0.11943559 -0.11610028 -0.11276501
#  -0.10942978 -0.10609459 -0.10275944 -0.09942417 -0.09608896 -0.09275372
#  -0.08941805 -0.08608262 -0.08274725 -0.07941193 -0.07607665 -0.07274145
#  -0.06940628 -0.06607114 -0.06273601 -0.05940086 -0.05606573 -0.05273059
#  -0.04939543 -0.04606025 -0.04272501 -0.0393897  -0.03605429 -0.0327191
#  -0.02938379 -0.02604844 -0.0227134  -0.01937855 -0.01604365 -0.01270876
#  -0.00937389 -0.00603924 -0.00270464  0.          0.00062991  0.0039644
#   0.00729887]
# [-0.00239848  0.          0.00093685  0.00427208  0.00760727]
# creating region 6 - outer_upper_divertor(0)
# [0. 0. 0. 0.]pendicular: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\first-test\gridgen.ipynb Cell 12 in <cell line: 13>()
#       <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=4'>5</a> region_id = self.region_lookup[(eq_region.name, i)]
#       <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=6'>7</a> eq_region_with_boundaries = eq_region.getRegridded(
#       <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=7'>8</a>                     radialIndex=i,
#       <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=8'>9</a>                     psi=self.equilibrium.psi,
#      <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=9'>10</a>                     width=self.user_options.refine_width,
#      <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=10'>11</a>                 )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=12'>13</a> mesh = MeshRegion(
#      <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=13'>14</a>                     self,
#      <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=14'>15</a>                     region_id,
#      <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=15'>16</a>                     eq_region_with_boundaries,
#      <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=16'>17</a>                     self.connections[region_id],
#      <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=17'>18</a>                     i,
#      <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=18'>19</a>                     self.user_options,
#      <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=19'>20</a>                     parallel_map,
#      <a href='vscode-notebook-cell:/c%3A/Users/mikek/OneDrive/Project/collab/tech/grid/ST40/first-test/gridgen.ipynb#X33sZmlsZQ%3D%3D?line=20'>21</a>                 )
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:264, in MeshRegion.__init__(self, meshParent, myID, equilibriumRegion, connections, radialIndex, settings, parallel_map)
#     256 self.equilibriumRegion.gradPsiSurfaceAtEnd = (
#     257     vec_points[1].as_ndarray() - vec_points[0].as_ndarray()
#     258 )
#     260 # Calculate the angles for perp_d_lower/perp_d_upper corresponding to
#     261 # d_lower/d_upper on the separatrix contour
#     262 # Use self.equilibriumRegion.fine_contour for the vector along the separatrix
#     263 # because then the vector will not change when the grid resolution changes
# --> 264 fine_contour = self.equilibriumRegion.get_fine_contour(
#     265     psi=self.equilibriumRegion.psi
#     266 )
#     267 if self.equilibriumRegion.wallSurfaceAtStart is None:
#     268     # lower end
#     269     unit_vec_separatrix = (
#     270         fine_contour.positions[fine_contour.startInd + 1, :]
#     271         - fine_contour.positions[fine_contour.startInd, :]
#     272     )
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:1089, in PsiContour.get_fine_contour(self, psi)
#    1087 def get_fine_contour(self, *, psi):
#    1088     if self._fine_contour is None:
# -> 1089         self._fine_contour = FineContour(self, dict(self.user_options), psi=psi)
#    1090         # Ensure that the fine contour is long enough
#    1091         self.checkFineContourExtend(psi=psi)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:527, in FineContour.__init__(self, parentContour, settings, psi)
#     522 # Initial guess from interpolation of psiContour, iterate to a more accurate
#     523 # version below.
#     524 # Extend a copy of parentContour to make the extrapolation more stable.
#     525 # This makes parentCopy have twice the extra points as parentContour has.
#     526 parentCopy = self.parentContour.newContourFromSelf()
# --> 527 parentCopy.temporaryExtend(
#     528     psi=psi,
#     529     extend_lower=self.parentContour.extend_lower,
#     530     extend_upper=self.parentContour.extend_upper,
#     531     ds_lower=calc_distance(parentCopy[0], parentCopy[1]),
#     532     ds_upper=calc_distance(parentCopy[-1], parentCopy[-2]),
#     533 )
#     534 interp_input, distance_estimate = parentCopy._coarseInterp()
#     536 sfine = distance_estimate[parentCopy.endInd] / (Nfine - 1) * self.indices_fine
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:1828, in PsiContour.temporaryExtend(self, psi, extend_lower, extend_upper, ds_lower, ds_upper)
#    1826     ds = ds_lower
#    1827 for i in range(extend_lower):
# -> 1828     extrap = self._coarseExtrapLower(0)
#    1829     new_point = extrap(-ds)
#    1830     if notInRange(new_point):
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:1548, in PsiContour._coarseExtrapLower(self, reference_ind, kind)
#    1544 Z = numpy.array(numpy.float64([p.Z for p in self.points[:npoints]]))
#    1546 print(distance)
# -> 1548 interpR = interpolate.interp1d(
#    1549     distance, R, kind=kind, assume_sorted=True, fill_value="extrapolate"
#    1550 )
#    1551 interpZ = interpolate.interp1d(
#    1552     distance, Z, kind=kind, assume_sorted=True, fill_value="extrapolate"
#    1553 )
#    1554 return lambda s: Point2D(interpR(s), interpZ(s))
#
# File c:\Apps\anaconda3\envs\hypno\lib\site-packages\scipy\interpolate\_interpolate.py:571, in interp1d.__init__(***failed resolving arguments***)
#     568         yy = np.ones_like(self._y)
#     569         rewrite_nan = True
# --> 571 self._spline = make_interp_spline(xx, yy, k=order,
#     572                                   check_finite=False)
#     573 if rewrite_nan:
#     574     self._call = self.__class__._call_nan_spline
#
# File c:\Apps\anaconda3\envs\hypno\lib\site-packages\scipy\interpolate\_bsplines.py:1295, in make_interp_spline(x, y, k, t, bc_type, axis, check_finite)
#    1293     raise ValueError("Expect x to be a 1-D sorted array_like.")
#    1294 if np.any(x[1:] == x[:-1]):
# -> 1295     raise ValueError("Expect x to not have duplicates")
#    1296 if k < 0:
#    1297     raise ValueError("Expect non-negative k.")
#
# ValueError: Expect x to not have duplicates

# %%
print(self.equilibrium.regions['outer_upper_divertor'].nSegments)
# Out:
# 2

# %%
fig, ax = plt.subplots(figsize = (6,6), dpi = 120)
eq.plotPotential(ncontours=40, axis = ax, linewidths = 0.5)
eq.plotWall(axis = ax)
ax.plot(*eq.x_points[0], "rx",)
mesh.plotPoints(xlow=True, ylow=True, corners=True, ax = ax, s = 0.5)
eq.plotWall(axis = ax)

ax.grid()
ax.legend('', frameon=False)
ax.set_xlim([0.2, 0.65])
ax.set_ylim([-1,-0.6])
ax.set_xlabel("R")
ax.set_ylabel("Z")

fig.show()

# %% [markdown]
# # Use hypnotoad

# %%
self = Options("a1-orthogonal.yml")
self.opts["ny_inner_divertor"] = 8
self.opts["ny_outer_divertor"] = 8
self.opts["ny_inner_sol"] = 24
self.opts["ny_outer_sol"] = 40
self.NXPE = 2
opts.check_nxpe()
# Out:
# NYPE: 21.447721179624665
# LocalNx (number of points per core): 15.013404825737265
# LocalNy (number of points per core): 5.31525
# Number of cores in ny_inner_divertor: 2.2576548610131226
# Number of cores in ny_outer_divertor: 2.2576548610131226
# Number of cores in ny_inner_sol: 4.515309722026245
# Number of cores in ny_outer_sol: 7.901792013545929

# %%
opts = read_yaml("a1-orthogonal.yml")

double_null = True
if double_null:
    div_mult = 2
else:
    div_mult = 1

test = dict()

# Domain split (NXPE=2, NYPE=12) into domains (localNx=14, localNy=8)

opts["ny_inner_divertor"] = 12
opts["ny_outer_divertor"] = 12
opts["ny_inner_sol"] = 24
opts["ny_outer_sol"] = 42

NXPE = 1.865
NPES = 40
NYPE = NPES/NXPE

ny = opts["ny_inner_divertor"]*div_mult + opts["ny_outer_divertor"]*div_mult + opts["ny_inner_sol"] + opts["ny_outer_sol"]
nx = opts["nx_core"] + opts["nx_sol"]

localNy = ny/NYPE
localNx = (nx-4)/NXPE

if NPES % NXPE == 0:
    test["NPES"] = True
else:
    test["NPES"] = False

if nx % NXPE == 0:
    test["localNx"] = True
else:
    test["localNx"] = False

if ny % NYPE == 0:
    test["localNy"] = True
else:
    test["localNy"] = False

print(f"NYPE: {NYPE}")
print(f"LocalNx (number of points per core): {localNx}")
print(f"LocalNy (number of points per core): {localNy}")

for x in ["ny_inner_divertor", "ny_outer_divertor", "ny_inner_sol", "ny_outer_sol"]:
    
    if opts[x] % localNy == 0:
        test[x] = True
    else:
        test[x] = False
    print(f"Number of cores in {x}: {opts[x] / localNy}")

print("")
# for name in test.keys():
    # print(f'Success in {name}: {test[name]}')
# Out:
# NYPE: 21.447721179624665
# LocalNx (number of points per core): 15.013404825737265
# LocalNy (number of points per core): 5.31525
# Number of cores in ny_inner_divertor: 2.2576548610131226
# Number of cores in ny_outer_divertor: 2.2576548610131226
# Number of cores in ny_inner_sol: 4.515309722026245
# Number of cores in ny_outer_sol: 7.901792013545929

# %%
abs(np.sqrt(NPES * (nx-4) / ny) - NXPE)
# Out:
# 1.8655843601224849

# %%
# fig, ax = plt.subplots()
mesh.calculateRZ()

ax = eq.plotPotential(ncontours=40)
ax.plot(*eq.x_points[0], "rx")
mesh.plotPoints(
    xlow=options.get("plot_xlow", True),
    ylow=options.get("plot_ylow", True),
    corners=options.get("plot_corners", True),
    ax=ax,
)
# Out:
# Get RZ values
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# # Plot grid cells

# %%
fig, ax = plt.subplots(figsize = (3,6))
import matplotlib as mpl

def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

cmap = plt.get_cmap("gist_ncar")

color = self.fpsi[:,:,0] / (2*np.pi /self.crx[:,:,0]) 

bounds = np.linspace(0,0.1,100)
norm = mpl.colors.BoundaryNorm(bounds, cmap.N, extend='both')

plt.scatter(
    self.crx[:,:,0].flatten(),
    self.cry[:,:,0].flatten(), 
    c = color, s = 5,
    cmap = cmap, norm = norm)

ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(0.2))
ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(0.25))
ax.set_xlim(0.15, 1.0)
ax.set_ylim(-1,1)
ax.grid(c = "k", zorder = 0)



cbar = fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap),orientation='vertical')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
