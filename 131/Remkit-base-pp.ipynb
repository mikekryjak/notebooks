# %%
from boututils.datafile import DataFile
from boutdata.collect import collect
from boutdata.data import BoutData
import os, sys
import matplotlib
# matplotlib.use('Qt5Agg',force=True)
# matplotlib.use("TKAgg",force=True)
# matplotlib.use("widget",force=True)
import matplotlib.pyplot as plt
import xbout
import pandas as pd
import numpy as np
import pickle as pkl
import xarray as xr

from boutdata.restart import addvar
import glob
import shutil

sys.path.append(r"/ssd_scratch/scripts/sdtools")


from hermes3.case_db import *
from hermes3.load import *
from hermes3.named_selections import *
from hermes3.plotting import *
from hermes3.grid_fields import *
from hermes3.accessors import *
from hermes3.utils import *
# from code_comparison.code_comparison import *


# %load_ext autoreload
# %autoreload 2
# Out:
# /ssd_scratch/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
ds_orig = Load.case_1D(r"/ssd_scratch/cases/remkit-comp/rk1a-base").ds
ds_diff = Load.case_1D(r"/ssd_scratch/cases/remkit-comp/rk1b-add_diffusion").ds

# %%
ds = ds_orig.isel(t=-1, pos = slice(1,-1))  # Take out guard cells

fig, ax = plt.subplots()
ds["Td+"].plot(ax = ax, label = "Ti", ls = "-", c = "r")
ds["Te"].plot(ax = ax, label = "Te", ls = "-", c = "b")
ds["Td"].plot(ax = ax, label = "Td", ls = "-", c = "k")

ax2 = ax.twinx()
# ds["Fdd+_cx"].plot(ax = ax2, label = "Fcx", ls = "-", lw = 3, c = "deeppink")
ds["Vd"].plot(ax = ax2, label = "Fcx", ls = "-", lw = 3, c = "deeppink")

# ax2.set_yscale("log")
ax.legend()
ax.set_xlabel("Position [m]")
ax.set_ylabel("Temperature [eV]")
ax.set_title("Temperature")
ax.grid()

# %%
ds = ds_diff.isel(t=-1, pos = slice(1,-1))  # Take out guard cells

fig, ax = plt.subplots()
ds["Td+"].plot(ax = ax, label = "Ti", ls = "-", c = "r")
ds["Te"].plot(ax = ax, label = "Te", ls = "-", c = "b")
ds["Td"].plot(ax = ax, label = "Td", ls = "-", c = "k")

ax2 = ax.twinx()
# ds["Fdd+_cx"].plot(ax = ax2, label = "Fcx", ls = "-", lw = 3, c = "deeppink")
ds["Vd"].plot(ax = ax2, label = "Fcx", ls = "-", lw = 3, c = "deeppink")

# ax2.set_yscale("log")
ax.legend()
ax.set_xlabel("Position [m]")
ax.set_ylabel("Temperature [eV]")
ax.set_title("Temperature")
ax.grid()

# %%
ds.data_vars
# Out:
# Data variables:
#     Bxy                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Ed+_iz              (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Ed+_rec             (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Ed_target_recycle   (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Ed_target_refl      (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Edd+_cx             (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Fd+_iz              (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Fd+_rec             (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Fdd+_cx             (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     G1                  (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     G2                  (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     G3                  (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     J                   (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     NVd                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     NVd+                (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Nd                  (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Nd+                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Ne                  (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Pd                  (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Pd+                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Pd+_src             (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Pd_src              (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Pe                  (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Pe_src              (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Rd+_ex              (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Rd+_rec             (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     SNVd                (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     SNVd+               (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     SNd                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     SNd+                (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     SPd                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     SPd+                (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     SPe                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Sd+_iz              (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Sd+_rec             (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Sd+_src             (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Sd_src              (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Sd_target_recycle   (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Td                  (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Td+                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Te                  (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Vd                  (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Vd+                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     Ve                  (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     cvode_last_order    int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_last_step     float64 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_nfevals       int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_nliters       int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_nniters       int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_nonlin_fails  int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_npevals       int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_nsteps        int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_num_fails     int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_stab_lims     int32 dask.array<chunksize=(), meta=np.ndarray>
#     ddt(NVd)            (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     ddt(NVd+)           (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     ddt(Nd)             (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     ddt(Nd+)            (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     ddt(Pd)             (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     ddt(Pd+)            (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     ddt(Pe)             (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     g11                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     g12                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     g13                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     g22                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     g23                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     g33                 (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     g_11                (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     g_12                (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     g_13                (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     g_22                (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     g_23                (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     g_33                (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     kappa_par_d         (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     kappa_par_d+        (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     kappa_par_e         (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>
#     t_array             float64 dask.array<chunksize=(), meta=np.ndarray>
#     ncalls              int32 dask.array<chunksize=(), meta=np.ndarray>
#     ncalls_e            int32 dask.array<chunksize=(), meta=np.ndarray>
#     ncalls_i            int32 dask.array<chunksize=(), meta=np.ndarray>
#     wall_time           float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime               float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_comms         float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_invert        float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_io            float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_per_rhs       float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_per_rhs_e     float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_per_rhs_i     float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_rhs           float64 dask.array<chunksize=(), meta=np.ndarray>
#     da                  (pos, y) float64 dask.array<chunksize=(257, 258), meta=np.ndarray>
#     dv                  (pos) float64 dask.array<chunksize=(257,), meta=np.ndarray>

# %%
ds["Ed_target_refl"].plot()
