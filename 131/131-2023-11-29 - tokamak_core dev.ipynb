# %%
from boututils.datafile import DataFile
from boutdata.collect import collect
from boutdata.data import BoutData
import os, sys
import matplotlib
# matplotlib.use('Qt5Agg',force=True)
# matplotlib.use("TKAgg",force=True)
# matplotlib.use("widget",force=True)
import matplotlib.pyplot as plt
import xbout
import pandas as pd
import numpy as np
import pickle as pkl
import xarray as xr

from boutdata.restart import addvar
import glob
import shutil

import scipy

sys.path.append(r"/ssd_scratch/scripts/sdtools")


from hermes3.case_db import *
from hermes3.load import *
from hermes3.named_selections import *
from hermes3.plotting import *
from hermes3.grid_fields import *
from hermes3.accessors import *
from hermes3.utils import *
# from code_comparison.code_comparison import *


# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Testing version E

# %%
casestore = dict()

# %%
db = CaseDB(
    case_dir = r"/ssd_scratch/hcases",
    grid_dir = r"/ssd_scratch/hcases"
    )

toload = [
    dict(name="base", id="tcor1-base", grid="g3b1-lores_newhypno.nc", unnormalise_geom = True), 
    dict(name="test", id="tcor2-test", grid="g3b1-lores_newhypno.nc", unnormalise_geom = True), 
    dict(name="src", id="tcor3-gridsrc", grid="g3b1-lores_newhypno.nc", unnormalise_geom = True),  
    # dict(name="form2", id="xeq1c-form2", grid="g3b1-lores_newhypno.nc", unnormalise_geom = True),  
    # dict(name="form3", id="xeq1d-form3", grid="g3b1-lores_newhypno.nc", unnormalise_geom = True),  
    # dict(name="form4", id="xeq1b-form4", grid="g3b1-lores_newhypno.nc", unnormalise_geom = True),  

]


for case in toload:
    casestore[case["name"]] = Load.case_2D(db.casepaths[case["id"]], gridfilepath = db.gridpaths[case["grid"]],
                                            unnormalise_geom = case["unnormalise_geom"])

# %% [markdown]
# ## Fresh check

# %%
print("Test case")
ds = casestore["test"].ds
m = ds.metadata
if "t" in ds.dims.keys(): ds = ds.isel(t=-1)

psrc = ds["Sd+_core_src"] * m["Omega_ci"] * m["Nnorm"]

particles = (psrc * ds["dv"]).sum()
print(f"Particles : {particles.values:.3e}")

if "Ed+_core_src" in ds.data_vars:
    hsrc = ds["Ed+_core_src"] * m["Tnorm"]*constants("q_e") * m["Omega_ci"] * m["Nnorm"]

    power = (hsrc * ds["dv"]).sum()
    print(f"Power : {power.values:.3e}")

print("\nGridsrc case")
ds = casestore["src"].ds
m = ds.metadata
if "t" in ds.dims.keys(): ds = ds.isel(t=-1)

psrc = ds["Sd+_src"] 
particles = (psrc * ds["dv"]).sum()
print(f"Particles : {particles.values:.3e}")
# Out:
# Test case
# Particles : 5.020e+20
#
# Gridsrc case
# Particles : 5.020e+20

# %%
lineplot(
    {
        "base":casestore["base"].ds.isel(t=-1),
        "test":casestore["test"].ds, #.isel(t=-1),
        "src":casestore["src"].ds.isel(t=-1),
    },
    clean_guards = True,
    params = ["Td+", "Te", "Td", "Ne", "Nd"],
    regions = ["omp", "outer_lower", "field_line"],
)

# %% [markdown]
# # Find fluxes coming from the core

# %%
for name in casestore:
    casestore[name].ds = calculate_radial_fluxes(casestore[name].ds, new_afn = False)
    casestore[name].ds = reverse_pfr_fluxes(casestore[name].ds)
    # casestore[name].ds = calculate_target_fluxes(casestore[name].ds)

# %%
print("\n************************")
print("base")
print("************************")

ds = casestore["base"].ds
core = ds.hermesm.select_region("core_edge")
pflow = core["pf_perp_diff_L_d+"].sum("theta").squeeze()
hflow_i = core["hf_perp_diff_L_d+"].sum("theta").squeeze()
hflow_e = core["hf_perp_diff_L_e"].sum("theta").squeeze()
print(f"Total particle flow: {pflow[-1]:.2e} s^-1")
print(f"Total ion heat flow: {hflow_i[-1]:.2e} W")
print(f"Total electron heat flow: {hflow_e[-1]:.2e} W")

print("\n************************")
print("test")
print("************************")

ds = casestore["test"].ds
core = ds.hermesm.select_region("core_edge")
pflow = core["pf_perp_diff_R_d+"].sum("theta").squeeze()
hflow_i = core["hf_perp_diff_R_d+"].sum("theta").squeeze()
hflow_e = core["hf_perp_diff_R_e"].sum("theta").squeeze()
print()
print(f"Total particle flow:     {pflow[-1]:.2e} s^-1")
print(f"Reference particle flow: 5.02e+20 s^-1")
print()
print(f"Total ion heat flow:     {hflow_i[-1]:.2e} W")
print(f"Reference ion heat flow: 2.20e+04 W")
print()
print(f"Total electron heat flow:     {hflow_e[-1]:.2e} W")
print(f"Reference electron heat flow: 2.65e+04 W")

print("\n************************")
print("src")
print("************************")

ds = casestore["src"].ds
core = ds.hermesm.select_region("core_edge")
pflow = core["pf_perp_diff_R_d+"].sum("theta").squeeze()
hflow_i = core["hf_perp_diff_R_d+"].sum("theta").squeeze()
hflow_e = core["hf_perp_diff_R_e"].sum("theta").squeeze()
print()
print(f"Total particle flow:     {pflow[-1]:.2e} s^-1")
print(f"Reference particle flow: 5.02e+20 s^-1")
# print()
# print(f"Total ion heat flow:     {hflow_i[-1]:.2e} W")
# print(f"Reference ion heat flow: 2.20e+04 W")
# print()
# print(f"Total electron heat flow:     {hflow_e[-1]:.2e} W")
# print(f"Reference electron heat flow: 2.65e+04 W")
# hflow.plot()
# Out:
# ************************
# base
# ************************
# Total particle flow: 3.53e+20 s^-1
# Total ion heat flow: 2.34e+04 W
# Total electron heat flow: 2.66e+04 W
#
# ************************
# test
# ************************
#
# Total particle flow:     6.84e+20 s^-1
# Reference particle flow: 5.02e+20 s^-1
#
# Total ion heat flow:     1.94e+04 W
# Reference ion heat flow: 2.20e+04 W
#
# Total electron heat flow:     2.21e+04 W
# Reference electron heat flow: 2.65e+04 W
#
# ************************
# src
# ************************
#
# Total particle flow:     4.37e+20 s^-1
# Reference particle flow: 5.02e+20 s^-1

# %%
fig, ax = plt.subplots()

ds = casestore["test"].ds 
core = ds.hermesm.select_region("core_edge")
pflow = core["pf_perp_diff_R_d+"].sum("theta").squeeze()
pflow.plot(ax = ax, label = "test")

ds = casestore["src"].ds 
core = ds.hermesm.select_region("core_edge")
pflow = core["pf_perp_diff_R_d+"].sum("theta").squeeze()
pflow.plot(ax = ax, label = "src")

# %%
ds = casestore["base"].ds.isel(t=-1)
core2 = ds.hermesm.select_custom_core_ring(0)
core2["ParticleFlow_d+_xlow"].sum().values

fig, ax = plt.subplots()
omp = ds.hermesm.select_region("outer_midplane_a")
omp["ParticleFlow_d+_xlow"].plot(ax=ax, label = "code", marker = "o")
omp["pf_perp_diff_L_d+"].plot(ax=ax, label = "calc", marker = "o")
ax.legend()

# %% [markdown]
# # Check sources from tokamak_core

# %%
ds["Sd+"]
# Out:
# Data variables:
#     Bxy                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Dnnd                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Ed+_iz                (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Ed+_rec               (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Ed_target_recycle     (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Edd+_cx               (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     EnergyFlow_d+_xlow    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     EnergyFlow_d+_ylow    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     EnergyFlow_e_xlow     (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     EnergyFlow_e_ylow     (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Fd+_iz                (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Fd+_rec               (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Fdd+_cx               (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     G1                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     G2                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     G3                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     J                     (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Kdd+_cx               (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     MomentumFlow_d+_xlow  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     NVd                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     NVd+                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Nd                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Nd+                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Ne                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     ParticleFlow_d+_xlow  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     ParticleFlow_d+_ylow  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Pd                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Pd+                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Pd+_src               (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Pd_src                (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Pe                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Pe_src                (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Rd+_ex                (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Rd+_rec               (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     SNVd                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     SNVd+                 (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     SNd                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     SNd+                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     SPd                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     SPd+                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     SPe                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Sd+_core_src          (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Sd+_iz                (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Sd+_rec               (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Sd+_src               (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Sd_src                (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Sd_target_recycle     (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Td                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Td+                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Te                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Vd+                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     Ve                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     anomalous_Chi_d+      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     anomalous_Chi_e       (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     anomalous_D_d+        (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     anomalous_D_e         (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     anomalous_nu_d+       (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     anomalous_nu_e        (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     cvode_last_order      int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_last_step       float64 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_nfevals         int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_nliters         int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_nniters         int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_nonlin_fails    int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_npevals         int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_nsteps          int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_num_fails       int32 dask.array<chunksize=(), meta=np.ndarray>
#     cvode_stab_lims       int32 dask.array<chunksize=(), meta=np.ndarray>
#     ddt(NVd)              (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     ddt(NVd+)             (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     ddt(Nd)               (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     ddt(Nd+)              (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     ddt(Pd)               (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     ddt(Pd+)              (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     ddt(Pe)               (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     g11                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     g12                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     g13                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     g22                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     g23                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     g33                   (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     g_11                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     g_12                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     g_13                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     g_22                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     g_23                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     g_33                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     kappa_par_d+          (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     kappa_par_e           (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     t_array               float64 dask.array<chunksize=(), meta=np.ndarray>
#     ncalls                int32 dask.array<chunksize=(), meta=np.ndarray>
#     ncalls_e              int32 dask.array<chunksize=(), meta=np.ndarray>
#     ncalls_i              int32 dask.array<chunksize=(), meta=np.ndarray>
#     wall_time             float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime                 float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_comms           float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_invert          float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_io              float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_per_rhs         float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_per_rhs_e       float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_per_rhs_i       float64 dask.array<chunksize=(), meta=np.ndarray>
#     wtime_rhs             float64 dask.array<chunksize=(), meta=np.ndarray>
#     Bpxy                  (x, theta) float64 0.5635 0.5599 ... 0.6329 0.6506
#     Brxy                  (x, theta) float64 0.5409 0.5376 ... 0.1912 0.1962
#     Bzxy                  (x, theta) float64 -0.1578 -0.1566 ... -0.6033 -0.6203
#     x_idx                 (x, theta) int64 0 0 0 0 0 0 0 ... 19 19 19 19 19 19
#     y_idx                 (x, theta) int64 0 1 2 3 4 5 6 ... 52 53 54 55 56 57
#     dv                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     dr                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hthe                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     dl                    (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     dtor                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     dpol                  (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_diff_L_d+     (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_diff_R_d+     (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_conv_L_d+     (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_conv_R_d+     (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_tot_L_d+      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_tot_R_d+      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_diff_L_e      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_diff_R_e      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_conv_L_e      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_conv_R_e      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_tot_L_e       (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_tot_R_e       (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_conv_L_d      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_conv_R_d      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_diff_L_d      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_diff_R_d      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_tot_L_d       (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     hf_perp_tot_R_d       (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     pf_perp_diff_L_d+     (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     pf_perp_diff_R_d+     (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     pf_perp_diff_L_e      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     pf_perp_diff_R_e      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     pf_perp_diff_L_d      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>
#     pf_perp_diff_R_d      (x, theta) float64 dask.array<chunksize=(20, 7), meta=np.ndarray>

# %%
ds = casestore["test"].ds
if "t" in ds.dims.keys():
    ds = ds.isel(t=-1)
m = ds.metadata
hfnorm = m["Nnorm"] * m["Tnorm"] * constants("q_e") * m["Omega_ci"]
pfnorm = m["Nnorm"] * m["Omega_ci"]
volnorm = m["rho_s0"]**3

core = ds.hermesm.select_region("core_edge")
vol = core["dv"].sum().values / volnorm



# power_in = 2.20e-02 * 1e6 / (m["Tnorm"] * constants("q_e") * m["Omega_ci"])
# psrc_calc = power_in / vol
# psrc_code = core["Ed+_core_src"].squeeze().values[0]
# ptot_code = (ds["Ed+_core_src"]  * ds["dv"]).sum().values * (m["Tnorm"] * constants("q_e") * m["Omega_ci"] / m["rho_s0"]**3)

particles_in = 5.02e+20 / m["Omega_ci"]
particle_src_calc = particles_in / vol
particle_src_code = core["Sd+_core_src"].squeeze().values[0]
particle_tot_code = (ds["Sd+_core_src"] * ds["dv"]).sum().values * (m["Omega_ci"] / m["rho_s0"]**3)

# print(f"Power source calc: {psrc_calc:.2e} [-]")
# print(f"Power source code: {psrc_code:.2e} [-]")
# print(f"Total power input: {ptot_code:.2e} [W]")
print("\n")
print(f"Particle source calc: {particle_src_calc:.2e} [-]")
print(f"Particle source code: {particle_src_code:.2e} [-]")
print(f"Total particle input: {particle_tot_code:.2e} [s^-1]")
# print(vol)
# power_i = (ds["Ed+_core_src"] * hfnorm * ds["dv"]).sum().values 
# pflux_i = (ds["Sd+_core_src"] * pfnorm * ds["dv"]).sum().values
# print(pflux_i)
# Out:
# Particle source calc: 5.15e+04 [-]
# Particle source code: 5.15e+04 [-]
# Total particle input: 5.02e+20 [s^-1]

# %%
fig, axes = plt.subplots(1, 2, figsize = (8,6))
(casestore["base"].ds["Te"]).hermesm.clean_guards().bout.polygon(ax = axes[0], vmax = 100, cmap = "Spectral_r", antialias = True)
(casestore["test"].ds["Te"]).hermesm.clean_guards().bout.polygon(ax = axes[1], vmax = 100, cmap = "Spectral_r", antialias = True)

fig, axes = plt.subplots(1, 2, figsize = (8,6))
(casestore["base"].ds["Ne"]).hermesm.clean_guards().bout.polygon(ax = axes[0], vmax = 5e18, cmap = "Spectral_r", antialias = True)
(casestore["test"].ds["Ne"]).hermesm.clean_guards().bout.polygon(ax = axes[1], vmax = 5e18, cmap = "Spectral_r", antialias = True)

# %%
fig, ax = plt.subplots(dpi = 100)

for case in ["base", "test"]:
    ds = casestore["base"].ds
    omp = ds.hermesm.select_region("outer_midplane_b").isel(x=slice(2,-2))
    omp.isel(t=-1)["Ne"].plot(ax = ax, label = case)
ax.set_title("Density")
ax.set_yscale("log")
ax.legend()

fig, ax = plt.subplots(dpi = 100)

for case in ["base", "test"]:
    ds = casestore[case].ds
    omp = ds.hermesm.select_region("outer_midplane_b").isel(x=slice(2,-2))
    omp.isel(t=-1)["Te"].plot(ax = ax, label = case)
ax.set_title("Temperature")

ax.set_yscale("log")
ax.legend()
# omp.isel(t=0)["Te"].plot(ax = ax, label = "Before")
# omp.isel(t=1)["Ne"].plot(ax = ax, label = "After")

# %% [markdown]
# # Put sources in grid

# %%
from hermes3.grid_fields import *

impose_fields(
    source = r"/ssd_scratch/hcases/g3b1-lores_newhypno.nc",
    destination = r"/ssd_scratch/hcases/g3c1-tokamcore_test.nc",
    Ni_src_core = 5.02e+20,
)
# Out:
# WARNING: Puff is suppressed
# Defining dimension z of size 1
# >>> Field Nd+_src already exists in /ssd_scratch/hcases/g3c1-tokamcore_test.nc, it will be overwritten
# -> Wrote field Nd+_src to /ssd_scratch/hcases/g3c1-tokamcore_test.nc
# >>> Field Pd+_src already exists in /ssd_scratch/hcases/g3c1-tokamcore_test.nc, it will be overwritten
# -> Wrote field Pd+_src to /ssd_scratch/hcases/g3c1-tokamcore_test.nc
# >>> Field Pe_src already exists in /ssd_scratch/hcases/g3c1-tokamcore_test.nc, it will be overwritten
# -> Wrote field Pe_src to /ssd_scratch/hcases/g3c1-tokamcore_test.nc
# >>> Field D_d+ already exists in /ssd_scratch/hcases/g3c1-tokamcore_test.nc, it will be overwritten
# -> Wrote field D_d+ to /ssd_scratch/hcases/g3c1-tokamcore_test.nc
# >>> Field D_e already exists in /ssd_scratch/hcases/g3c1-tokamcore_test.nc, it will be overwritten
# -> Wrote field D_e to /ssd_scratch/hcases/g3c1-tokamcore_test.nc
# >>> Field chi_d+ already exists in /ssd_scratch/hcases/g3c1-tokamcore_test.nc, it will be overwritten
# -> Wrote field chi_d+ to /ssd_scratch/hcases/g3c1-tokamcore_test.nc
# >>> Field chi_e already exists in /ssd_scratch/hcases/g3c1-tokamcore_test.nc, it will be overwritten
# -> Wrote field chi_e to /ssd_scratch/hcases/g3c1-tokamcore_test.nc
# Mesh file /ssd_scratch/hcases/g3c1-tokamcore_test.nc closed
