# %%
from boutdata.data import BoutOptionsFile
from pathlib import Path

# %load_ext autoreload
# %autoreload 2

# %%
# cwd = Path.cwd()
cwd = Path(r"/home/mike/work/hermes3v/builds/newbuild/tests/integrated/dmplex")
case_path = cwd / "data"
datafile_path = case_path / "BOUT.dmp.*.nc"
inputfile_path = case_path / "BOUT.inp"
exec_path = cwd.parents[2] / "bout-particle-push"
dmplex_path = cwd / "hypnotoad_dmplex_mesh_output.h5"
logfile_path = cwd / "run.log"

gridzipfile = cwd / "Hypnotoad_examples.zip"
gridurl = "https://zenodo.org/records/17966926/files/Hypnotoad_examples.zip"

# %%
f = BoutOptionsFile(inputfile_path, gridfilename = "/home/mike/work/hermes3v/builds/newbuild/tests/integrated/dmplex/example_cdn.grd.nc")

# %%
f.y
# Out:
# array([[[-0.39269908],
#         [-0.13089969],
#         [ 0.13089969],
#         [ 0.39269908],
#         [ 0.65449847],
#         [ 0.91629786],
#         [ 1.17809725],
#         [ 1.43989663],
#         [ 1.70169602],
#         [ 1.96349541],
#         [ 2.2252948 ],
#         [ 2.48709418],
#         [ 2.74889357],
#         [ 3.01069296],
#         [ 3.27249235],
#         [ 3.53429174],
#         [ 3.79609112],
#         [ 4.05789051],
#         [ 4.3196899 ],
#         [ 4.58148929],
#         [ 4.84328867],
#         [ 5.10508806],
#         [ 5.36688745],
#         [ 5.62868684],
#         [ 5.89048623],
#         [ 6.15228561],
#         [ 6.414085  ],
#         [ 6.67588439]]])

# %%
f["mesh"].evaluate_scalar("nx")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 f["mesh"].evaluate_scalar("nx")
#
# File ~/work/boutdata/src/boutdata/data.py:531, in BoutOptions.evaluate_scalar(self, name)
#     527 def evaluate_scalar(self, name):
#     528     """
#     529     Evaluate (recursively) scalar expressions
#     530     """
# --> 531     expression = self._substitute_expressions(name)
#     533     # replace ^ with ** so that Python evaluates exponentiation
#     534     expression = expression.replace("^", "**")
#
# File ~/work/boutdata/src/boutdata/data.py:539, in BoutOptions._substitute_expressions(self, name)
#     538 def _substitute_expressions(self, name):
# --> 539     expression = str(self[name]).lower()
#     540     expression = self._evaluate_section(expression, "")
#     541     parent = self._parent
#
# File ~/work/boutdata/src/boutdata/data.py:167, in BoutOptions.__getitem__(self, key)
#     164     return self._sections[key]
#     166 if key not in self._keys:
# --> 167     raise KeyError(f"Key '{key}' not in section '{self.path()}'")
#     168 return self._keys[key]
#
# KeyError: "Key 'nx' not in section 'root:mesh'"
