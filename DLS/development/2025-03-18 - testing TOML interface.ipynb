# %%
from pathlib import Path
from freeqdsk import geqdsk
from fusiondls import read_geqdsk
import matplotlib.pyplot as plt

# %%
equilibria = dict(
    compass = r"C:\Users\Mike\OneDrive\Project\collab\tech\grid\COMPASS\compass.geqdsk",
    mastu = r"C:\Users\Mike\OneDrive\Project\collab\tech\grid\MAST-U\D moulton super X\qian_exp45460_new.eqdsk",
    mastu2 = r"C:\Users\Mike\OneDrive\Project\collab\tech\grid\MAST-U\46860\sxd_46860_equ_450ms.symm.x4.crop.equ",
    st40 = r"C:\Users\Mike\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\ST40_P3_eq_0015_modgeom.geqdsk",
    step = r"C:\Users\Mike\OneDrive\Project\DLS\SPR45details\AH_PI4_P5-LATEST.geqdsk",
    step2 = r"C:\Users\Mike\OneDrive\Project\DLS\STEP_SPR038\drsep0mm\STEP_eqref.eqdsk",
)

# %%
def plot_field_lines(path: Path):
    # Get field lines
    # Automatic COCOS identification is not always reliable.
    # In the single-null case, we have to assert the COCOS manually.
    cocos = 11 if "single" in path.name else None
    geometries = read_geqdsk(path, cocos=cocos)
    # Geometries is a dictionary with the following keys:
    # - "ou" : outboard upper
    # - "ol" : outboard lower
    # - "iu" : inboard upper
    # - "il" : inboard lower
    # For the single null, only "ol" and "il" are present
    for leg in ("ol", "il", "ou", "iu"):
        if geometries[leg] is None:
            continue
        plt.plot(geometries[leg].R, geometries[leg].Z, label=leg)
    plt.legend()
    
plot_field_lines(Path(equilibria["step"]))
# Out:
# c:\pyenvs\fusion312\Lib\site-packages\freeqdsk\geqdsk.py:592: UserWarning: The value of 'simagx' should be duplicated. Found values 6.27547229 and 1.509819835
#   warnings.warn(
# c:\pyenvs\fusion312\Lib\site-packages\freeqdsk\geqdsk.py:592: UserWarning: The value of 'sibdry' should be duplicated. Found values 1.509819835 and 6.27547229
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 19
#      16         plt.plot(geometries[leg].R, geometries[leg].Z, label=leg)
#      17     plt.legend()
# ---> 19 plot_field_lines(Path(equilibria["step"]))
#
# Cell In[6], line 6, in plot_field_lines(path)
#       1 def plot_field_lines(path: Path):
#       2     # Get field lines
#       3     # Automatic COCOS identification is not always reliable.
#       4     # In the single-null case, we have to assert the COCOS manually.
#       5     cocos = 11 if "single" in path.name else None
# ----> 6     geometries = read_geqdsk(path, cocos=cocos)
#       7     # Geometries is a dictionary with the following keys:
#       8     # - "ou" : outboard upper
#       9     # - "ol" : outboard lower
#      10     # - "iu" : inboard upper
#      11     # - "il" : inboard lower
#      12     # For the single null, only "ol" and "il" are present
#      13     for leg in ("ol", "il", "ou", "iu"):
#
# File ~\OneDrive\Project\DLS\DLS-git\src\fusiondls\geqdsk.py:358, in read_geqdsk(path, wall, solwidth, npoints, cocos, clockwise_phi)
#     356         err = f"Could not calculate field line for leg '{leg}'."
#     357         if exc.args[0] != err:
# --> 358             raise exc
#     359         results[leg] = None
#     360 return results
#
# File ~\OneDrive\Project\DLS\DLS-git\src\fusiondls\geqdsk.py:354, in read_geqdsk(path, wall, solwidth, npoints, cocos, clockwise_phi)
#     352 for leg in ["ol", "ou", "il", "iu"]:
#     353     try:
# --> 354         results[leg] = reader.trace_field_line(leg, solwidth, npoints)
#     355     except ValueError as exc:
#     356         err = f"Could not calculate field line for leg '{leg}'."
#
# File ~\OneDrive\Project\DLS\DLS-git\src\fusiondls\geqdsk.py:234, in GeqdskReader.trace_field_line(self, leg, solwidth, npoints)
#     232     xpoint = max(self.xpoints, key=lambda x: x[1])
#     233 else:
# --> 234     xpoint = min(self.xpoints, key=lambda x: x[1])
#     236 r0, z0, psi0 = self.opoint
#     237 psi_bdry = self.eq.psi_bndry
#
# ValueError: min() iterable argument is empty
