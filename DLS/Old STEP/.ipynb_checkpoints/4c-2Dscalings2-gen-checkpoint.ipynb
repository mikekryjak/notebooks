# %%
from netCDF4 import Dataset
import pandas as pd
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt
from AnalyticCoolingCurves import *
from unpackConfigurations import unpackConfiguration
from unpackConfigurationsMK import unpackConfigurationMK
import ThermalFrontFormulation as TF
from matplotlib.collections import LineCollection
import os
import pickle as pkl
from LRBv2 import LRBv2
import matplotlib as mpl
import copy
from LengyelReinkeFormulation import *
import ThermalFrontFormulation as TF
import colorcet as cc
from scipy import interpolate
from matplotlib.ticker import FormatStrFormatter, StrMethodFormatter, MultipleLocator, FormatStrFormatter, AutoMinorLocator

from DLScommonTools import *

# %load_ext autoreload
# %autoreload 2

set_matplotlib_defaults()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # IO

# %%
file_paths = {
    "V10" : r"C:\Users\Mike\OneDrive\Project\DLS\STEPv10\drsep0mm\balance_v10.nc",
     "V10X" : r"C:\Users\Mike\OneDrive\Project\DLS\from_sarah\V10Xgluedgrid_balance\balance.nc",
     "SPR38" : r"C:\Users\Mike\OneDrive\Project\DLS\STEP_SPR038\drsep0mm\balance_SPR038.nc"}

designs = file_paths.keys()
sepadd = 2
eqb = dict()

for side in ["iu", "ou"]:
    eqb[side] = dict()
    
    for design in designs:    
        eqb[side][design] = unpackConfigurationMK(File = file_paths[design], Type = side, sepadd=sepadd, resolution = 500)

# %%
#set switches
radios_default = {
    "ionisation": False,  # in development
    "upstreamGrid": True, #if true, source of divertor heat flux comes from radial transport upstream, and Tu is at the midplane. If false, heat flux simply enters at the x point as qi, and Tu is located at the x point. 
    "fluxlim": False,  # if true, turns on a flux limiter with coefficient alpha
}

#set general run parameters
constants_default = {
    "gamma_sheath": 7, #sheath transmittion coefficient for virtual target. Choice does not matter if Tt is low
    "qpllu0": 1e9, # heat flux density at the x point
    "nu" : 1e20, #upstream density
    "nu0" : 1e20,
    "cz0" : 0.05,
    "kappa0" : 2500,
    "mi": 3*10**(-27),
    "echarge": 1.60*10**(-19), 
    "Tt": 0.5, # requested virtual target temp. Aim for low (sub 1eV) Tt
    "Lfunc": LfuncAr, #impurity cooling function
    "alpha": 1000, #flux limiting alpha. Only matters if fluxlim is true
}

# %% [markdown]
# # KallenbachAr

# %% [markdown]
# # Density

# %%
ne_kAr = dict()
store = ne_kAr

design = "V10"

list_BxBt_scales = np.append(np.linspace(0.5, 1.0, 5), np.linspace(1.0, 2.0, 5)[1:])
list_Lc_scales = np.append(np.linspace(0.5, 1.0, 5), np.linspace(1.0, 2.0, 5)[1:])

for side in ["iu", "ou"]:
    print("Running side: {}".format(side))
    result_array = []
    
    for i, BxBt_scale in enumerate(list_BxBt_scales):
        print("Running BxBt scale factor: {:.2f} -- ".format(BxBt_scale), end="")
        result_row = []
        
        for j, Lc_scale in enumerate(list_Lc_scales):
            print("Running Lc scale factor: {:.2f} -- ".format(Lc_scale), end="")
                
            d = copy.deepcopy(eqb[side][design])
            constants = constants_default.copy()
            radios = radios_default.copy()
                              
            d["Btot"] = scale_BxBt(d["Btot"], d["Xpoint"], scale_factor = BxBt_scale)
            d["S"], d["Spol"] = scale_Lc(d["S"], d["Spol"], d["Xpoint"], scale_factor = Lc_scale)
                              
            radios["upstreamGrid"] = True
            constants["XpointIndex"] = d["Xpoint"], # Index of Xpoint
            constants["cz0"] = 0.085
            
            # SPR38:
            # 0.11: failed at 0.50/0.50
            # 0.1: failed at 0.50/0.88
            # 0.09: failed at 0.50/0.88
            # 0.085: failed at 0.50/0.50
            # 0.02: failed at 0.50/0.50
            # 0.001: failed at 0.50/0.50
            
            # V10:
            # 0.06: failed at 0.5:0.50
            # 0.07: failed at 0.5:0.50
            # 0.08: failed at 1.5/0.62
            # 0.085: SUCCESS
            # 0.09: failed at 1.0/1.25 x2
            # 0.10: failed at 1.25/0.62
            # 0.11: failed at 1.25/0.62
            
            constants["B"] = interpolate.interp1d(d["S"], d["Btot"], kind='cubic') # Continuous function for B

            # SparRange = np.linspace(0, d["S"][d["Xpoint"]-1], 3)
            # indexRange = [np.argmin(abs(d["S"] - x)) for x in SparRange]
            indexRange = [0, d["Xpoint"]-1]
            
            constants["Lfunc"] = LfuncKallenbachAr        
            out = LRBv2(constants,radios,d["S"],indexRange, 
                                                Ctol = 1e-3, Ttol = 1e-3, URF = 0.9, acceleration = 0, verbosity = 0,
                                                control_variable = "density")

            out["SpolPlot"] = [d["Spol"][x] for x in indexRange]
            result_row.append(out)

        result_array.append(result_row)
                              
    store[side] = result_array
# Out:
# Running side: iu
# Running BxBt scale factor: 0.50 -- Running Lc scale factor: 0.50 -- Solving...0...54...Complete in 5.9 seconds
# Running Lc scale factor: 0.62 -- Solving...0...54...Complete in 6.6 seconds
# Running Lc scale factor: 0.75 -- Solving...0...54...Complete in 6.4 seconds
# Running Lc scale factor: 0.88 -- Solving...0...54...Complete in 4.8 seconds
# Running Lc scale factor: 1.00 -- Solving...0...54...Complete in 5.3 seconds
# Running Lc scale factor: 1.25 -- Solving...0...54...Complete in 5.5 seconds
# Running Lc scale factor: 1.50 -- Solving...0...54...Complete in 7.1 seconds
# Running Lc scale factor: 1.75 -- Solving...0...54...Complete in 6.3 seconds
# Running Lc scale factor: 2.00 -- Solving...0...54...Complete in 7.1 seconds
# Running BxBt scale factor: 0.62 -- Running Lc scale factor: 0.50 -- Solving...0...54...Complete in 5.9 seconds
# Running Lc scale factor: 0.62 -- Solving...0...54...Complete in 6.0 seconds
# Running Lc scale factor: 0.75 -- Solving...0...54...Complete in 5.8 seconds
# Running Lc scale factor: 0.88 -- Solving...0...54...Complete in 5.5 seconds
# Running Lc scale factor: 1.00 -- Solving...0...54...Complete in 5.6 seconds
# Running Lc scale factor: 1.25 -- Solving...0...54...Complete in 5.5 seconds
# Running Lc scale factor: 1.50 -- Solving...0...54...Complete in 8.0 seconds
# Running Lc scale factor: 1.75 -- Solving...0...54...Complete in 7.4 seconds
# Running Lc scale factor: 2.00 -- Solving...0...54...Complete in 6.4 seconds
# Running BxBt scale factor: 0.75 -- Running Lc scale factor: 0.50 -- Solving...0...54...Complete in 5.8 seconds
# Running Lc scale factor: 0.62 -- Solving...0...54...Complete in 5.3 seconds
# Running Lc scale factor: 0.75 -- Solving...0...54...Complete in 5.6 seconds
# Running Lc scale factor: 0.88 -- Solving...0...54...Complete in 4.6 seconds
# Running Lc scale factor: 1.00 -- Solving...0...54...Complete in 5.2 seconds
# Running Lc scale factor: 1.25 -- Solving...0...54...Complete in 5.4 seconds
# Running Lc scale factor: 1.50 -- Solving...0...54...Complete in 6.4 seconds
# Running Lc scale factor: 1.75 -- Solving...0...54...Complete in 6.4 seconds
# Running Lc scale factor: 2.00 -- Solving...0...54...Complete in 6.2 seconds
# Running BxBt scale factor: 0.88 -- Running Lc scale factor: 0.50 -- Solving...0...54...Complete in 5.2 seconds
# Running Lc scale factor: 0.62 -- Solving...0...54...Complete in 4.7 seconds
# Running Lc scale factor: 0.75 -- Solving...0...54...Complete in 5.3 seconds
# Running Lc scale factor: 0.88 -- Solving...0...54...Complete in 5.5 seconds
# Running Lc scale factor: 1.00 -- Solving...0...54...Complete in 4.9 seconds
# Running Lc scale factor: 1.25 -- Solving...0...54...Complete in 4.7 seconds
# Running Lc scale factor: 1.50 -- Solving...0...54...Complete in 6.5 seconds
# Running Lc scale factor: 1.75 -- Solving...0...54...Complete in 6.7 seconds
# Running Lc scale factor: 2.00 -- Solving...0...54...Complete in 6.7 seconds
# Running BxBt scale factor: 1.00 -- Running Lc scale factor: 0.50 -- Solving...0...54...Complete in 5.7 seconds
# Running Lc scale factor: 0.62 -- Solving...0...54...Complete in 5.5 seconds
# Running Lc scale factor: 0.75 -- Solving...0...54...Complete in 5.8 seconds
# Running Lc scale factor: 0.88 -- Solving...0...54...Complete in 5.1 seconds
# Running Lc scale factor: 1.00 -- Solving...0...54...Complete in 4.5 seconds
# Running Lc scale factor: 1.25 -- Solving...0...54...Complete in 5.3 seconds
# Running Lc scale factor: 1.50 -- Solving...0...54...Complete in 6.7 seconds
# Running Lc scale factor: 1.75 -- Solving...0...54...Complete in 6.9 seconds
# Running Lc scale factor: 2.00 -- Solving...0...54...Complete in 7.9 seconds
# Running BxBt scale factor: 1.25 -- Running Lc scale factor: 0.50 -- Solving...0...54...Complete in 5.5 seconds
# Running Lc scale factor: 0.62 -- Solving...0...54...Complete in 5.1 seconds
# Running Lc scale factor: 0.75 -- Solving...0...54...Complete in 5.2 seconds
# Running Lc scale factor: 0.88 -- Solving...0...******OUTER TIMEOUT! Loosen Ttol or reduce under-relaxation factor. Set verbosity = 2!*******
# 54...Complete in 37.4 seconds
# Running Lc scale factor: 1.00 -- Solving...0...******OUTER TIMEOUT! Loosen Ttol or reduce under-relaxation factor. Set verbosity = 2!*******
# 54...
# C:\Users\Mike\OneDrive\Project\DLS\DLS-model-main\LRBv2.py:392: RuntimeWarning: divide by zero encountered in double_scalars
#   Qrad.append(((cvar**2*Tu**2)/Tf**2)*cz0*Lfunc(Tf))
# C:\Users\Mike\OneDrive\Project\DLS\DLS-model-main\LRBv2.py:392: RuntimeWarning: invalid value encountered in double_scalars
#   Qrad.append(((cvar**2*Tu**2)/Tf**2)*cz0*Lfunc(Tf))
# Complete in 42.6 seconds
# Running Lc scale factor: 1.25 -- Solving...0...54...Complete in 5.1 seconds
# Running Lc scale factor: 1.50 -- Solving...0...54...Complete in 6.8 seconds
# Running Lc scale factor: 1.75 -- Solving...0...54...Complete in 7.1 seconds
# Running Lc scale factor: 2.00 -- Solving...0...54...Complete in 6.9 seconds
# Running BxBt scale factor: 1.50 -- Running Lc scale factor: 0.50 -- Solving...0...******OUTER TIMEOUT! Loosen Ttol or reduce under-relaxation factor. Set verbosity = 2!*******
# 54...Complete in 41.7 seconds
# Running Lc scale factor: 0.62 -- Solving...0...******OUTER TIMEOUT! Loosen Ttol or reduce under-relaxation factor. Set verbosity = 2!*******
# 54...Complete in 37.0 seconds
# Running Lc scale factor: 0.75 -- Solving...0...54...Complete in 6.2 seconds
# Running Lc scale factor: 0.88 -- Solving...0...54...Complete in 5.8 seconds
# Running Lc scale factor: 1.00 -- Solving...0...54...Complete in 5.1 seconds
# Running Lc scale factor: 1.25 -- Solving...0...54...Complete in 5.1 seconds
# Running Lc scale factor: 1.50 -- Solving...0...54...Complete in 7.6 seconds
# Running Lc scale factor: 1.75 -- Solving...0...54...Complete in 6.2 seconds
# Running Lc scale factor: 2.00 -- Solving...0...54...Complete in 6.6 seconds
# Running BxBt scale factor: 1.75 -- Running Lc scale factor: 0.50 -- Solving...0...54...Complete in 18.6 seconds
# Running Lc scale factor: 0.62 -- Solving...0...54...Complete in 4.1 seconds
# Running Lc scale factor: 0.75 -- Solving...0...54...Complete in 3.9 seconds
# Running Lc scale factor: 0.88 -- Solving...0...54...Complete in 5.4 seconds
# Running Lc scale factor: 1.00 -- Solving...0...54...Complete in 5.6 seconds
# Running Lc scale factor: 1.25 -- Solving...0...54...Complete in 5.1 seconds
# Running Lc scale factor: 1.50 -- Solving...0...54...Complete in 7.2 seconds
# Running Lc scale factor: 1.75 -- Solving...0...54...Complete in 7.3 seconds
# Running Lc scale factor: 2.00 -- Solving...0...54...Complete in 8.0 seconds
# Running BxBt scale factor: 2.00 -- Running Lc scale factor: 0.50 -- Solving...0...54...Complete in 5.1 seconds
# Running Lc scale factor: 0.62 -- Solving...0...54...Complete in 5.4 seconds
# Running Lc scale factor: 0.75 -- Solving...0...54...Complete in 4.6 seconds
# Running Lc scale factor: 0.88 -- Solving...0...54...Complete in 4.2 seconds
# Running Lc scale factor: 1.00 -- Solving...0...54...Complete in 4.1 seconds
# Running Lc scale factor: 1.25 -- Solving...0...54...Complete in 5.0 seconds
# Running Lc scale factor: 1.50 -- Solving...0...54...Complete in 6.8 seconds
# Running Lc scale factor: 1.75 -- Solving...0...54...Complete in 6.7 seconds
# Running Lc scale factor: 2.00 -- Solving...0...54...Complete in 7.0 seconds
# Running side: ou
# Running BxBt scale factor: 0.50 -- Running Lc scale factor: 0.50 -- Solving...0...182...Complete in 4.2 seconds
# Running Lc scale factor: 0.62 -- Solving...0...182...Complete in 3.8 seconds
# Running Lc scale factor: 0.75 -- Solving...0...182...Complete in 4.7 seconds
# Running Lc scale factor: 0.88 -- Solving...0...182...Complete in 4.6 seconds
# Running Lc scale factor: 1.00 -- Solving...0...182...Complete in 4.9 seconds
# Running Lc scale factor: 1.25 -- Solving...0...182...Complete in 4.8 seconds
# Running Lc scale factor: 1.50 -- Solving...0...182...Complete in 5.5 seconds
# Running Lc scale factor: 1.75 -- Solving...0...182...Complete in 5.2 seconds
# Running Lc scale factor: 2.00 -- Solving...0...182...Complete in 4.7 seconds
# Running BxBt scale factor: 0.62 -- Running Lc scale factor: 0.50 -- Solving...0...182...Complete in 4.9 seconds
# Running Lc scale factor: 0.62 -- Solving...0...182...Complete in 3.6 seconds
# Running Lc scale factor: 0.75 -- Solving...0...182...Complete in 4.7 seconds
# Running Lc scale factor: 0.88 -- Solving...0...182...Complete in 5.0 seconds
# Running Lc scale factor: 1.00 -- Solving...0...182...Complete in 5.0 seconds
# Running Lc scale factor: 1.25 -- Solving...0...182...Complete in 5.9 seconds
# Running Lc scale factor: 1.50 -- Solving...0...182...Complete in 5.7 seconds
# Running Lc scale factor: 1.75 -- Solving...0...182...Complete in 6.0 seconds
# Running Lc scale factor: 2.00 -- Solving...0...182...Complete in 5.5 seconds
# Running BxBt scale factor: 0.75 -- Running Lc scale factor: 0.50 -- Solving...0...182...Complete in 4.6 seconds
# Running Lc scale factor: 0.62 -- Solving...0...182...Complete in 3.8 seconds
# Running Lc scale factor: 0.75 -- Solving...0...182...Complete in 4.5 seconds
# Running Lc scale factor: 0.88 -- Solving...0...182...Complete in 4.8 seconds
# Running Lc scale factor: 1.00 -- Solving...0...182...Complete in 4.7 seconds
# Running Lc scale factor: 1.25 -- Solving...0...182...Complete in 4.5 seconds
# Running Lc scale factor: 1.50 -- Solving...0...182...Complete in 5.5 seconds
# Running Lc scale factor: 1.75 -- Solving...0...182...Complete in 5.6 seconds
# Running Lc scale factor: 2.00 -- Solving...0...182...Complete in 5.6 seconds
# Running BxBt scale factor: 0.88 -- Running Lc scale factor: 0.50 -- Solving...0...182...Complete in 4.8 seconds
# Running Lc scale factor: 0.62 -- Solving...0...182...Complete in 3.2 seconds
# Running Lc scale factor: 0.75 -- Solving...0...182...Complete in 4.7 seconds
# Running Lc scale factor: 0.88 -- Solving...0...182...Complete in 4.3 seconds
# Running Lc scale factor: 1.00 -- Solving...0...182...Complete in 4.3 seconds
# Running Lc scale factor: 1.25 -- Solving...0...182...Complete in 4.8 seconds
# Running Lc scale factor: 1.50 -- Solving...0...182...Complete in 5.8 seconds
# Running Lc scale factor: 1.75 -- Solving...0...182...Complete in 5.5 seconds
# Running Lc scale factor: 2.00 -- Solving...0...182...Complete in 5.5 seconds
# Running BxBt scale factor: 1.00 -- Running Lc scale factor: 0.50 -- Solving...0...182...Complete in 4.6 seconds
# Running Lc scale factor: 0.62 -- Solving...0...182...Complete in 3.2 seconds
# Running Lc scale factor: 0.75 -- Solving...0...182...Complete in 5.2 seconds
# Running Lc scale factor: 0.88 -- Solving...0...182...Complete in 5.5 seconds
# Running Lc scale factor: 1.00 -- Solving...0...182...Complete in 5.2 seconds
# Running Lc scale factor: 1.25 -- Solving...0...182...Complete in 4.7 seconds
# Running Lc scale factor: 1.50 -- Solving...0...182...Complete in 6.2 seconds
# Running Lc scale factor: 1.75 -- Solving...0...182...Complete in 6.3 seconds
# Running Lc scale factor: 2.00 -- Solving...0...182...Complete in 11.5 seconds
# Running BxBt scale factor: 1.25 -- Running Lc scale factor: 0.50 -- Solving...0...182...Complete in 5.8 seconds
# Running Lc scale factor: 0.62 -- Solving...0...182...Complete in 4.5 seconds
# Running Lc scale factor: 0.75 -- Solving...0...182...Complete in 4.4 seconds
# Running Lc scale factor: 0.88 -- Solving...0...182...Complete in 5.0 seconds
# Running Lc scale factor: 1.00 -- Solving...0...182...Complete in 4.4 seconds
# Running Lc scale factor: 1.25 -- Solving...0...182...Complete in 5.0 seconds
# Running Lc scale factor: 1.50 -- Solving...0...182...Complete in 5.5 seconds
# Running Lc scale factor: 1.75 -- Solving...0...182...Complete in 5.6 seconds
# Running Lc scale factor: 2.00 -- Solving...0...182...Complete in 5.4 seconds
# Running BxBt scale factor: 1.50 -- Running Lc scale factor: 0.50 -- Solving...0...182...Complete in 4.5 seconds
# Running Lc scale factor: 0.62 -- Solving...0...182...Complete in 3.8 seconds
# Running Lc scale factor: 0.75 -- Solving...0...182...Complete in 4.7 seconds
# Running Lc scale factor: 0.88 -- Solving...0...182...Complete in 5.1 seconds
# Running Lc scale factor: 1.00 -- Solving...0...182...Complete in 5.1 seconds
# Running Lc scale factor: 1.25 -- Solving...0...182...Complete in 4.9 seconds
# Running Lc scale factor: 1.50 -- Solving...0...182...Complete in 6.7 seconds
# Running Lc scale factor: 1.75 -- Solving...0...182...Complete in 6.1 seconds
# Running Lc scale factor: 2.00 -- Solving...0...182...Complete in 7.0 seconds
# Running BxBt scale factor: 1.75 -- Running Lc scale factor: 0.50 -- Solving...0...182...Complete in 5.3 seconds
# Running Lc scale factor: 0.62 -- Solving...0...182...Complete in 3.9 seconds
# Running Lc scale factor: 0.75 -- Solving...0...182...Complete in 5.0 seconds
# Running Lc scale factor: 0.88 -- Solving...0...182...Complete in 4.9 seconds
# Running Lc scale factor: 1.00 -- Solving...0...182...Complete in 4.9 seconds
# Running Lc scale factor: 1.25 -- Solving...0...182...Complete in 4.8 seconds
# Running Lc scale factor: 1.50 -- Solving...0...182...Complete in 5.9 seconds
# Running Lc scale factor: 1.75 -- Solving...0...182...Complete in 5.3 seconds
# Running Lc scale factor: 2.00 -- Solving...0...182...Complete in 6.1 seconds
# Running BxBt scale factor: 2.00 -- Running Lc scale factor: 0.50 -- Solving...0...182...Complete in 5.1 seconds
# Running Lc scale factor: 0.62 -- Solving...0...182...Complete in 3.6 seconds
# Running Lc scale factor: 0.75 -- Solving...0...182...Complete in 4.6 seconds
# Running Lc scale factor: 0.88 -- Solving...0...182...Complete in 4.8 seconds
# Running Lc scale factor: 1.00 -- Solving...0...182...Complete in 4.6 seconds
# Running Lc scale factor: 1.25 -- Solving...0...182...Complete in 5.2 seconds
# Running Lc scale factor: 1.50 -- Solving...0...182...Complete in 6.0 seconds
# Running Lc scale factor: 1.75 -- Solving...0...182...Complete in 5.5 seconds
# Running Lc scale factor: 2.00 -- Solving...0...182...Complete in 5.9 seconds

# %%
d["Xpoint"]
# Out:
# 31

# %%
arr = dict()
arr["ou"] = make_arrays(ne_kAr["ou"], list_BxBt_scales, list_Lc_scales)
arr["iu"] = make_arrays(ne_kAr["iu"], list_BxBt_scales, list_Lc_scales)


fig, axes = plt.subplots(1,2, figsize = (16,8))
fig.tight_layout(pad=5)

cmap = copy.copy(plt.get_cmap("jet"))

# levels = np.linspace(0, 3.0e19,22)
# levels = np.arange(-0.5, 0.55, 0.05)

ax = axes[0]

levels = np.linspace(1, 5, 22)
cs = ax.contourf(list_Lc_scales-1, list_BxBt_scales-1, arr["ou"]["window_ratio"], levels = levels, cmap = cmap, zorder = 0, vmin = 1.2)
cb = fig.colorbar(cs, ax=ax)
cb.set_label(label = "Detachment window $n_{u}\ /\ n_{u0}$", size = 15)
cb.ax.set_yticklabels(["{:.1f}".format(i) for i in cb.get_ticks()]) 
ax.set_title("Outer divertor", fontsize = 15)

ax = axes[1]
levels = np.linspace(1, 1.8, 22)
cs = ax.contourf(list_Lc_scales-1, list_BxBt_scales-1, patch_array(arr["iu"]["window_ratio"], percentile_threshold = 90), levels = levels, cmap = cmap, zorder = 0, vmin = 1)
# cs = ax.contourf(list_Lc_scales-1, list_BxBt_scales-1, patch_array(arr["iu"]["window"],percentile_threshold = 94), levels = 22, cmap = cmap, zorder = 0, vmin = 1)
cb = fig.colorbar(cs, ax=ax)
cb.set_label(label = "Detachment window $n_{u}\ /\ n_{u0}$", size = 15)
cb.ax.set_yticklabels(["{:.1f}".format(i) for i in cb.get_ticks()]) 
ax.set_title("Inner divertor", fontsize = 15)


for ax in axes:

    ax.set_xlim(-0.5,1.0)
    ax.set_ylim(-0.5,1.0)
    ax.scatter(0,0, marker = "o", s = 200, facecolor = "black", linewidth = 3, color = "black")
    ax.hlines(0, -0.5, 1, color = "black", zorder = 2)
    ax.vlines(0, -0.5, 1, color = "black", zorder = 2)
    ax.grid(color = "black", alpha = 0.3)
    ax.set_xlabel("Connection length change", fontsize = 15)
    ax.set_ylabel("Flux expansion change", fontsize = 15)
    ax.yaxis.set_major_formatter(StrMethodFormatter("{x:.0%}"))
    ax.xaxis.set_major_formatter(StrMethodFormatter("{x:.0%}"))

# %%
def patch_array(array, percentile_threshold = 95):
    # Take 2D numpy array
    # Take out values above threshold and replace with interpolated ones
    # https://stackoverflow.com/questions/37662180/interpolate-missing-values-2d-python

    original = array.copy()
    x = list_BxBt_scales
    y = list_Lc_scales

    # original[original > threshold] = np.nan
    original[original > np.percentile(original, percentile_threshold)] = np.nan
    print("Eliminated {} values.".format(len([original > np.percentile(original, percentile_threshold)])))
    
    
    original = np.ma.masked_invalid(original)
    xx, yy = np.meshgrid(x,y)

    x1 = xx[~original.mask]
    y1 = yy[~original.mask]

    new = original[~original.mask]

    filled = interpolate.griddata((x1, y1), new.ravel(), (xx,yy), method = "cubic")
    return filled

# %%
patch_array(arr["iu"]["window_ratio"], percentile_threshold = 90)
# Out:
# Test
# Eliminated 1 values.
# array([[0.70442129, 0.7163189 , 0.72925693, 0.74471767, 0.76009207,
#         0.79049986, 0.81378719, 0.84316652, 0.87032777],
#        [0.76540152, 0.77830027, 0.79367262, 0.80947144, 0.82598925,
#         0.85799003, 0.88307252, 0.91347514, 0.94289481],
#        [0.82500473, 0.84005993, 0.85610363, 0.87282646, 0.89147991,
#         0.92644807, 0.95180093, 0.98443379, 1.01535133],
#        [0.88369956, 0.90082255, 0.91848198, 0.93707733, 0.95546   ,
#         0.99422847, 1.01986072, 1.05432535, 1.08609983],
#        [0.94120375, 0.96062156, 0.98075288, 0.99997873, 1.02003058,
#         1.05992102, 1.08834365, 1.12262193, 1.15645571],
#        [1.05299481, 1.07718935, 1.10031722, 1.12445148, 1.14870072,
#         1.19160801, 1.22280301, 1.25985247, 1.29807108],
#        [1.1597696 , 1.19209707, 1.21746403, 1.24590532, 1.27162812,
#         1.3191616 , 1.35552371, 1.3980161 , 1.43725071],
#        [1.26082551, 1.3039027 , 1.34094466, 1.36046757, 1.39027307,
#         1.44632009, 1.48474423, 1.53120849, 1.57422928],
#        [1.3576075 , 1.40261084, 1.4447434 , 1.48359426, 1.51942634,
#         1.56936937,        nan,        nan,        nan]])

# %%
np.percentile(arr["iu"]["window"], 95)
# Out:
# 5.5985260009765626e+19

# %% [markdown]
# # Density wider scan

# %%
list_BxBt_scales
# Out:
# array([0.5  , 0.625, 0.75 , 0.875, 1.   , 1.25 , 1.5  , 1.75 , 2.   ])

# %%
np.append(np.linspace(0.25, 1.0, 7), np.linspace(1.0, 2.5, 7)[1:])
# Out:
# array([0.25 , 0.375, 0.5  , 0.625, 0.75 , 0.875, 1.   , 1.25 , 1.5  ,
#        1.75 , 2.   , 2.25 , 2.5  ])

# %%
ne_kAr_wide = dict()
store = ne_kAr_wide

design = "V10"

list_BxBt_scales2 = np.append(np.linspace(0.25, 1.0, 7), np.linspace(1.0, 2.5, 7)[1:])
list_Lc_scales2 = np.append(np.linspace(0.25, 1.0, 7), np.linspace(1.0, 2.5, 7)[1:])

for side in ["iu", "ou"]:
    print("Running side: {}".format(side))
    result_array = []
    
    for i, BxBt_scale in enumerate(list_BxBt_scales2):
        print("Running BxBt scale factor: {:.2f} -- ".format(BxBt_scale), end="")
        result_row = []
        
        for j, Lc_scale in enumerate(list_Lc_scales2):
            print("Running Lc scale factor: {:.2f} -- ".format(Lc_scale), end="")
                
            d = copy.deepcopy(eqb[side][design])
            constants = constants_default.copy()
            radios = radios_default.copy()
                              
            d["Btot"] = scale_BxBt(d["Btot"], d["Xpoint"], scale_factor = BxBt_scale)
            d["S"], d["Spol"] = scale_Lc(d["S"], d["Spol"], d["Xpoint"], scale_factor = Lc_scale)
                              
            radios["upstreamGrid"] = True
            constants["XpointIndex"] = d["Xpoint"], # Index of Xpoint
            constants["cz0"] = 0.085
            # 0.06: failed at 0.5:0.50
            # 0.07: failed at 0.5:0.50
            # 0.08: failed at 1.5/0.62
            # 0.085: SUCCESS
            # 0.09: failed at 1.0/1.25 x2
            # 0.10: failed at 1.25/0.62
            # 0.11: failed at 1.25/0.62
            
            constants["B"] = interpolate.interp1d(d["S"], d["Btot"], kind='cubic') # Continuous function for B

            # SparRange = np.linspace(0, d["S"][d["Xpoint"]-1], 3)
            # indexRange = [np.argmin(abs(d["S"] - x)) for x in SparRange]
            indexRange = [0, d["Xpoint"]-1]
            
            constants["Lfunc"] = LfuncKallenbachAr100  
            out = LRBv2(constants,radios,d["S"],indexRange, 
                                                Ctol = 1e-3, Ttol = 1e-3, URF = 0.9, acceleration = 0, verbosity = 0,
                                                control_variable = "density")

            out["SpolPlot"] = [d["Spol"][x] for x in indexRange]
            result_row.append(out)

        result_array.append(result_row)
                              
    store[side] = result_array
# Out:
# Running side: iu
# Running BxBt scale factor: 0.25 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 5.7 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 4.4 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 5.3 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 5.4 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 7.9 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 8.4 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 8.2 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 8.9 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 8.2 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 9.3 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 8.0 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 7.2 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 8.7 seconds
# Running BxBt scale factor: 0.38 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 5.6 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 5.7 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 5.3 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 4.3 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 5.1 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 6.3 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 6.6 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 6.6 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 6.6 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 7.8 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 7.6 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 8.9 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 8.1 seconds
# Running BxBt scale factor: 0.50 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 5.6 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 5.7 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 4.9 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 4.8 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 6.1 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 6.5 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 5.7 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 5.8 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 6.5 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 6.9 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 5.8 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 5.8 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 6.1 seconds
# Running BxBt scale factor: 0.62 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 5.4 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 6.0 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 4.9 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 5.1 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 5.7 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 6.1 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 6.6 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 6.0 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 6.6 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 6.3 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 5.3 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 7.0 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 6.0 seconds
# Running BxBt scale factor: 0.75 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 4.8 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 4.5 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 5.2 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 5.5 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 7.4 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 5.5 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 5.2 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 6.0 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 6.8 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 6.4 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 7.3 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 7.3 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 6.2 seconds
# Running BxBt scale factor: 0.88 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 4.7 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 5.1 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 5.4 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 4.7 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 7.0 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 7.4 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 6.7 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 5.8 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 5.7 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 6.6 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 5.7 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 5.9 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 6.2 seconds
# Running BxBt scale factor: 1.00 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 4.9 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 4.0 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 5.0 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 5.1 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 5.1 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 6.0 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 5.8 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 5.8 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 6.1 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 5.9 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 5.6 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 6.3 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 5.9 seconds
# Running BxBt scale factor: 1.25 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 5.0 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 4.8 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 4.7 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 4.8 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 6.3 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 6.2 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 5.9 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 5.7 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 6.2 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 5.9 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 5.6 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 5.6 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 6.0 seconds
# Running BxBt scale factor: 1.50 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 5.1 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 5.3 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 5.3 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 5.0 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 6.8 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 6.2 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 6.2 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 8.0 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 7.1 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 5.7 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 7.1 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 7.1 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 6.6 seconds
# Running BxBt scale factor: 1.75 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 5.8 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 4.8 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 4.9 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 4.8 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 6.2 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 6.7 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 7.0 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 6.0 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 6.2 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 7.2 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 6.7 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 6.4 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 5.3 seconds
# Running BxBt scale factor: 2.00 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 5.7 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 5.5 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 6.0 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 5.3 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 6.2 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 6.4 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 7.1 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 7.1 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 7.3 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 7.5 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 4.7 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 4.9 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 4.8 seconds
# Running BxBt scale factor: 2.25 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 22.4 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 5.1 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 5.4 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 5.0 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 5.1 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 6.3 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 6.5 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 6.1 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 5.7 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 5.0 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 5.1 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 4.6 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 5.3 seconds
# Running BxBt scale factor: 2.50 -- Running Lc scale factor: 0.25 -- Solving...0...32...Complete in 5.3 seconds
# Running Lc scale factor: 0.38 -- Solving...0...32...Complete in 5.3 seconds
# Running Lc scale factor: 0.50 -- Solving...0...32...Complete in 5.1 seconds
# Running Lc scale factor: 0.62 -- Solving...0...32...Complete in 4.8 seconds
# Running Lc scale factor: 0.75 -- Solving...0...32...Complete in 6.8 seconds
# Running Lc scale factor: 0.88 -- Solving...0...32...Complete in 5.8 seconds
# Running Lc scale factor: 1.00 -- Solving...0...32...Complete in 6.0 seconds
# Running Lc scale factor: 1.25 -- Solving...0...32...Complete in 6.4 seconds
# Running Lc scale factor: 1.50 -- Solving...0...32...Complete in 5.2 seconds
# Running Lc scale factor: 1.75 -- Solving...0...32...Complete in 4.2 seconds
# Running Lc scale factor: 2.00 -- Solving...0...32...Complete in 5.1 seconds
# Running Lc scale factor: 2.25 -- Solving...0...32...Complete in 4.4 seconds
# Running Lc scale factor: 2.50 -- Solving...0...32...Complete in 5.2 seconds
# Running side: ou
# Running BxBt scale factor: 0.25 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 2.2 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 4.1 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 4.2 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 4.4 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 3.6 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 3.6 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 4.8 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 5.2 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 5.0 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 4.7 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 5.0 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 4.5 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 4.7 seconds
# Running BxBt scale factor: 0.38 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 3.2 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 4.2 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 3.2 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 3.0 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 3.0 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 3.9 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 4.7 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 4.4 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 5.4 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 4.7 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 5.1 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 5.0 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 5.1 seconds
# Running BxBt scale factor: 0.50 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 3.4 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 4.9 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 3.8 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 4.5 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 4.4 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 4.3 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 5.0 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 3.9 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 4.0 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 3.9 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 4.1 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 3.8 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 4.0 seconds
# Running BxBt scale factor: 0.62 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 3.0 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 4.2 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 3.8 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 3.9 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 4.2 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 4.0 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 5.4 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 5.4 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 5.1 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 5.1 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 5.2 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 4.9 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 5.1 seconds
# Running BxBt scale factor: 0.75 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 3.5 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 4.4 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 4.3 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 4.0 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 4.0 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 3.5 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 5.5 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 5.3 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 5.3 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 4.6 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 5.3 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 5.0 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 4.6 seconds
# Running BxBt scale factor: 0.88 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 3.4 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 4.3 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 4.1 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 4.2 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 4.0 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 3.6 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 4.5 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 5.3 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 5.3 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 4.9 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 5.2 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 5.7 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 5.7 seconds
# Running BxBt scale factor: 1.00 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 4.1 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 4.8 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 4.4 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 4.3 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 4.6 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 5.5 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 6.1 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 5.6 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 5.3 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 5.5 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 5.8 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 5.2 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 6.1 seconds
# Running BxBt scale factor: 1.25 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 4.3 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 5.0 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 4.7 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 4.5 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 4.2 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 5.3 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 5.4 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 5.4 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 5.1 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 5.9 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 4.7 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 5.5 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 5.4 seconds
# Running BxBt scale factor: 1.50 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 3.5 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 4.0 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 4.9 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 4.5 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 4.1 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 4.7 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 4.2 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 5.5 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 5.7 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 5.2 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 5.0 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 7.3 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 6.0 seconds
# Running BxBt scale factor: 1.75 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 3.8 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 4.2 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 4.6 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 4.6 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 4.5 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 4.0 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 5.4 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 5.5 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 5.5 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 5.6 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 4.9 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 5.9 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 5.7 seconds
# Running BxBt scale factor: 2.00 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 3.8 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 4.7 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 4.8 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 4.7 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 4.1 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 4.1 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 5.3 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 5.2 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 5.4 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 6.2 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 6.1 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 5.1 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 5.9 seconds
# Running BxBt scale factor: 2.25 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 3.8 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 4.4 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 4.3 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 4.2 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 4.1 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 4.6 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 5.7 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 5.6 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 5.5 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 5.0 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 5.0 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 5.1 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 5.5 seconds
# Running BxBt scale factor: 2.50 -- Running Lc scale factor: 0.25 -- Solving...0...108...Complete in 3.7 seconds
# Running Lc scale factor: 0.38 -- Solving...0...108...Complete in 4.4 seconds
# Running Lc scale factor: 0.50 -- Solving...0...108...Complete in 4.5 seconds
# Running Lc scale factor: 0.62 -- Solving...0...108...Complete in 4.3 seconds
# Running Lc scale factor: 0.75 -- Solving...0...108...Complete in 4.4 seconds
# Running Lc scale factor: 0.88 -- Solving...0...108...Complete in 4.5 seconds
# Running Lc scale factor: 1.00 -- Solving...0...108...Complete in 5.4 seconds
# Running Lc scale factor: 1.25 -- Solving...0...108...Complete in 5.5 seconds
# Running Lc scale factor: 1.50 -- Solving...0...108...Complete in 5.5 seconds
# Running Lc scale factor: 1.75 -- Solving...0...108...Complete in 5.9 seconds
# Running Lc scale factor: 2.00 -- Solving...0...108...Complete in 4.9 seconds
# Running Lc scale factor: 2.25 -- Solving...0...108...Complete in 4.9 seconds
# Running Lc scale factor: 2.50 -- Solving...0...108...Complete in 5.9 seconds

# %%
arr = make_arrays(ne_kAr_wide["ou"], list_BxBt_scales2, list_Lc_scales2)

fig, ax = plt.subplots(figsize = (8,8))

cmap = copy.copy(plt.get_cmap("jet"))

# levels = np.linspace(0, 3.0e19,22)
# levels = np.arange(-0.5, 0.55, 0.05)

cs = ax.contourf(list_Lc_scales2-1, list_BxBt_scales2-1, arr["window_ratio"], levels = 22, cmap = cmap, zorder = 0)
ax.grid(color = "black", alpha = 0.3)
ax.set_xlim(-0.25,1.5)
ax.set_ylim(-0.25,1.5)

ax.scatter(0,0, marker = "o", s = 300, facecolor = "None", linewidth = 2, color = "black")

cb = fig.colorbar(cs, ax=ax)
cb.set_label(label = "Relative density window ($m^{-3}$)", size = 15)
cb.ax.set_yticklabels(["{:.1f}".format(i) for i in cb.get_ticks()]) 

ax.hlines(0, -0.5, 1, color = "black", zorder = 2)
ax.vlines(0, -0.5, 1, color = "black", zorder = 2)
# ax.hlines(0, -0.5, 1, color = "white", linewidth = 2, zorder = 1)
# ax.vlines(0, -0.5, 1, color = "white", linewidth = 2, zorder = 1)

ax.set_xlabel("Connection length change", fontsize = 15)
ax.set_ylabel("Flux expansion change", fontsize = 15)
ax.yaxis.set_major_formatter(StrMethodFormatter("{x:.0%}"))
ax.xaxis.set_major_formatter(StrMethodFormatter("{x:.0%}"))
ax.set_title("Outer divertor power window", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Outer divertor power window')
