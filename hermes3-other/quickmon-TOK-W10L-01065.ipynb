# %%
from boututils.datafile import DataFile
from boutdata.collect import collect
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys, pathlib
import platform
import traceback
import xarray
import xbout
import scipy
import re

onedrive_path = onedrive_path = str(os.getcwd()).split("OneDrive")[0] + "OneDrive"
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages\sdtools"))
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages\soledge"))
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages"))

from hermes3.utils import *
# from gridtools.hypnotoad_tools import *
from gridtools.b2_tools import *
from gridtools.utils import *

from hermes3.fluxes import *
from hermes3.case_db import *
from hermes3.load import *
from hermes3.named_selections import *
from hermes3.plotting import *
from hermes3.grid_fields import *
from hermes3.accessors import *

from code_comparison.code_comparison import *
from code_comparison.viewer_2d import *


# %load_ext autoreload
# %autoreload 2


print("Done")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Done

# %%
casestore = dict()

# %%
db = CaseDB(
    case_dir = os.path.join(onedrive_path, r"Project\collab\tech\cases\st40"),
    grid_dir = os.path.join(onedrive_path, r"Project\collab\tech\grid")
)

toload = [
    dict(name="base", id="d11c-d10d_3e19", grid="g3b2-fatter_newhypno.nc", unnormalise_geom = True),
]

for case in toload:
    casestore[case["name"]] = Load.case_2D(db.casepaths[case["id"]], gridfilepath = db.gridpaths[case["grid"]],
                                           double_load = False, keep_xboundaries = True, keep_yboundaries = True,
                                           unnormalise_geom = case["unnormalise_geom"])
# Out:
# CHECK: Total domain volume is 1.942E+00 [m3]

# %%
plt.close("all")
# %matplotlib inline

# %%
for casename in casestore.keys():
    print(casename)
    Monitor(casestore[casename], [["avg_density", "avg_temp", "target_temp","radiation"], ["sep_ne", "sep_te"]])
# Out:
# base

# %%
cases = dict()

cases["t=0"] = casestore["base"].ds.isel(t=0, x = slice(2,-2))
cases["t=-1"] = casestore["base"].ds.isel(t=-1, x = slice(2,-2))

lineplot(
    cases = cases,
    clean_guards = False,
    regions = ["omp", "field_line", "outer_lower"],
    params = ["Td+", "Te", "Td", "Ne", "Nd", "kappa_par_e"],
    # params = ["Pd+", "Pe", "Pd", "NVd+", "NVd"],
    dpi = 90
)

# %%
v = viewer_2d(
    "Te",
    {
        "2e19"  : {"code":"hermes", "ds" : casestore["base"].ds.isel(t=0)},
        "now"  : {"code":"hermes", "ds" : casestore["base"].ds.isel(t=-1)},

    },
    logscale = False,
    # vmin = 10,
    # vmax = 2000,
    # vmin = 1e17,
    # vmax = 5e17,
    dpi = 160,
    ylim = (-0.9,0.3),
    xlim = (0.12, 1.0),
    wspace = 0.0,
    cmap = "Spectral_r"
)
# Out:
# 2e19
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 v = viewer_2d(
#       2     "Te",
#       3     {
#       4         "2e19"  : {"code":"hermes", "ds" : casestore["base"].ds.isel(t=0)},
#       5         "now"  : {"code":"hermes", "ds" : casestore["base"].ds.isel(t=-1)},
#       6
#       7     },
#       8     logscale = False,
#       9     # vmin = 10,
#      10     # vmax = 2000,
#      11     # vmin = 1e17,
#      12     # vmax = 5e17,
#      13     dpi = 160,
#      14     ylim = (-0.9,0.3),
#      15     xlim = (0.12, 1.0),
#      16     wspace = 0.0,
#      17     cmap = "Spectral_r"
#      18 )
#
# File c:\Users\mikek\OneDrive\Project\python-packages\sdtools\code_comparison\viewer_2d.py:59, in viewer_2d.__init__(self, param, cases, vmin, vmax, xlim, ylim, logscale, dpi, wspace, cmap)
#      57 for case in cases:
# ...
