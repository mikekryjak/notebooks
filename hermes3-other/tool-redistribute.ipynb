# %%
import boutdata

# %%
from boutdata.restart import redistribute
casepath = r"/home/mike/work/cases/2025-updateST40/d42acb-with_guards"
newpath = r"/home/mike/work/cases/2025-updateST40/upst10c-2e19_clim_1.0_maxmfp_1_hires"

# casepath = r"/ssd_scratch/hcases/balances1d/spr45_nD_linPow_3x_fimp-6-0-2-3"
# newpath = rf"{casepath}_redist"
# loadfilepath = os.path.join(casepath, "BOUT.dmp.*.nc")
# inputfilepath = os.path.join(casepath, "BOUT.inp")
# squashfilepath = os.path.join(casepath, "BOUT.squash.nc") # Squashoutput hardcoded to this filename

redistribute(10, path = casepath, nxpe = 1, output = newpath)
# Out:
# Grid sizes:  36 100 1
# True

# %%
nsep.values
# Out:
# array([], shape=(0, 1), dtype=float64)

# %%
len(nsep)
# Out:
# 1058

# %%
omp = int((ds.metadata["jyseps2_2"] - ds.metadata["jyseps1_2"])/2 + ds.metadata["jyseps1_2"])
nsep = ds["Ne"].isel(y = omp, x=ds.metadata["ixseps1"], t = slice(None,-2))

fig, ax = plt.subplots()
ax.plot(range(len(nsep)),nsep)

# %%
create?
# Out:
# Signature:
# create(
#     averagelast=1,
#     final=-1,
#     path='data',
#     output='./',
#     informat='nc',
#     outformat=None,
# )
# Docstring:
# Create restart files from data (dmp) files.
#
# Parameters
# ----------
# averagelast : int, optional
#     Number of time points (counting from `final`, inclusive) to
#     average over (default is 1 i.e. just take last time-point)
# final : int, optional
#     The last time point to use (default is last, -1)
# path : str, optional
#     Path to original restart files (default: "data")
# output : str, optional
#     Path to write new restart files (default: current directory)
# informat : str, optional
#     File extension of original files (default: "nc")
# outformat : str, optional
#     File extension of new files (default: use the same as `informat`)
# File:      /ssd_scratch/anaconda3/lib/python3.9/site-packages/boutdata/restart.py
# Type:      function

# %%
from boutdata.restart import create

create(
    final = 400,
    path = r"/ssd_scratch/hcases/xpoint_heat/xph1-base_master",
    output = r"/ssd_scratch/hcases/xpoint_heat/xph1-base_master_restart"
    
)
# Out:
# ('Number of data files: ', 10)
# ('/ssd_scratch/hcases/xpoint_heat/xph1-base_master/BOUT.dmp.0.nc', ' -> ', '/ssd_scratch/hcases/xpoint_heat/xph1-base_master_restart/BOUT.restart.0.nc')
# ('hist_hi = ', 100)
# ('tt = ', 4299850.0)
# ('NXPE = ', BoutArray(1, dtype=int32), ' NYPE = ', BoutArray(10, dtype=int32))
# (' -> ', 'Dnnd')
# (20, 9, 1)
# (' -> ', 'Ed+_iz')
# (20, 9, 1)
# (' -> ', 'Ed+_rec')
# (20, 9, 1)
# (' -> ', 'Ed_pump')
# (20, 9, 1)
# (' -> ', 'Ed_target_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_target_refl')
# (20, 9, 1)
# (' -> ', 'Ed_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_wall_refl')
# (20, 9, 1)
# (' -> ', 'Edd+_cx')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_ylow')
# (20, 9, 1)
# (' -> ', 'Fd+_iz')
# (20, 9, 1)
# (' -> ', 'Fd+_rec')
# (20, 9, 1)
# (' -> ', 'Fdd+_cx')
# (20, 9, 1)
# (' -> ', 'Kd+d+_coll')
# (20, 9, 1)
# (' -> ', 'Kd+e_coll')
# (20, 9, 1)
# (' -> ', 'Kdd+_cx')
# (20, 9, 1)
# (' -> ', 'Ked+_coll')
# (20, 9, 1)
# (' -> ', 'Kee_coll')
# (20, 9, 1)
# (' -> ', 'MomentumFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'NVd')
# (20, 9, 1)
# (' -> ', 'NVd+')
# (20, 9, 1)
# (' -> ', 'Nd')
# (20, 9, 1)
# (' -> ', 'Nd+')
# (20, 9, 1)
# (' -> ', 'Ne')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'Pd')
# (20, 9, 1)
# (' -> ', 'Pd+')
# (20, 9, 1)
# (' -> ', 'Pd+_src')
# (20, 9, 1)
# (' -> ', 'Pd_src')
# (20, 9, 1)
# (' -> ', 'Pe')
# (20, 9, 1)
# (' -> ', 'Pe_src')
# (20, 9, 1)
# (' -> ', 'Rd+_ex')
# (20, 9, 1)
# (' -> ', 'Rd+_rec')
# (20, 9, 1)
# (' -> ', 'SNVd')
# (20, 9, 1)
# (' -> ', 'SNVd+')
# (20, 9, 1)
# (' -> ', 'SNd')
# (20, 9, 1)
# (' -> ', 'SNd+')
# (20, 9, 1)
# (' -> ', 'SPd')
# (20, 9, 1)
# (' -> ', 'SPd+')
# (20, 9, 1)
# (' -> ', 'SPe')
# (20, 9, 1)
# (' -> ', 'Sd+_iz')
# (20, 9, 1)
# (' -> ', 'Sd+_rec')
# (20, 9, 1)
# (' -> ', 'Sd+_src')
# (20, 9, 1)
# (' -> ', 'Sd_pump')
# (20, 9, 1)
# (' -> ', 'Sd_src')
# (20, 9, 1)
# (' -> ', 'Sd_target_recycle')
# (20, 9, 1)
# (' -> ', 'Sd_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Td')
# (20, 9, 1)
# (' -> ', 'Td+')
# (20, 9, 1)
# (' -> ', 'Te')
# (20, 9, 1)
# (' -> ', 'Vd+')
# (20, 9, 1)
# (' -> ', 'Ve')
# (20, 9, 1)
# (' -> ', 'ddt(NVd)')
# (20, 9, 1)
# (' -> ', 'ddt(NVd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pe)')
# (20, 9, 1)
# (' -> ', 'kappa_par_d+')
# (20, 9, 1)
# (' -> ', 'kappa_par_e')
# (20, 9, 1)
# ('/ssd_scratch/hcases/xpoint_heat/xph1-base_master/BOUT.dmp.1.nc', ' -> ', '/ssd_scratch/hcases/xpoint_heat/xph1-base_master_restart/BOUT.restart.1.nc')
# ('hist_hi = ', 100)
# ('tt = ', 4299850.0)
# ('NXPE = ', BoutArray(1, dtype=int32), ' NYPE = ', BoutArray(10, dtype=int32))
# (' -> ', 'Dnnd')
# (20, 9, 1)
# (' -> ', 'Ed+_iz')
# (20, 9, 1)
# (' -> ', 'Ed+_rec')
# (20, 9, 1)
# (' -> ', 'Ed_pump')
# (20, 9, 1)
# (' -> ', 'Ed_target_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_target_refl')
# (20, 9, 1)
# (' -> ', 'Ed_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_wall_refl')
# (20, 9, 1)
# (' -> ', 'Edd+_cx')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_ylow')
# (20, 9, 1)
# (' -> ', 'Fd+_iz')
# (20, 9, 1)
# (' -> ', 'Fd+_rec')
# (20, 9, 1)
# (' -> ', 'Fdd+_cx')
# (20, 9, 1)
# (' -> ', 'Kd+d+_coll')
# (20, 9, 1)
# (' -> ', 'Kd+e_coll')
# (20, 9, 1)
# (' -> ', 'Kdd+_cx')
# (20, 9, 1)
# (' -> ', 'Ked+_coll')
# (20, 9, 1)
# (' -> ', 'Kee_coll')
# (20, 9, 1)
# (' -> ', 'MomentumFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'NVd')
# (20, 9, 1)
# (' -> ', 'NVd+')
# (20, 9, 1)
# (' -> ', 'Nd')
# (20, 9, 1)
# (' -> ', 'Nd+')
# (20, 9, 1)
# (' -> ', 'Ne')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'Pd')
# (20, 9, 1)
# (' -> ', 'Pd+')
# (20, 9, 1)
# (' -> ', 'Pd+_src')
# (20, 9, 1)
# (' -> ', 'Pd_src')
# (20, 9, 1)
# (' -> ', 'Pe')
# (20, 9, 1)
# (' -> ', 'Pe_src')
# (20, 9, 1)
# (' -> ', 'Rd+_ex')
# (20, 9, 1)
# (' -> ', 'Rd+_rec')
# (20, 9, 1)
# (' -> ', 'SNVd')
# (20, 9, 1)
# (' -> ', 'SNVd+')
# (20, 9, 1)
# (' -> ', 'SNd')
# (20, 9, 1)
# (' -> ', 'SNd+')
# (20, 9, 1)
# (' -> ', 'SPd')
# (20, 9, 1)
# (' -> ', 'SPd+')
# (20, 9, 1)
# (' -> ', 'SPe')
# (20, 9, 1)
# (' -> ', 'Sd+_iz')
# (20, 9, 1)
# (' -> ', 'Sd+_rec')
# (20, 9, 1)
# (' -> ', 'Sd+_src')
# (20, 9, 1)
# (' -> ', 'Sd_pump')
# (20, 9, 1)
# (' -> ', 'Sd_src')
# (20, 9, 1)
# (' -> ', 'Sd_target_recycle')
# (20, 9, 1)
# (' -> ', 'Sd_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Td')
# (20, 9, 1)
# (' -> ', 'Td+')
# (20, 9, 1)
# (' -> ', 'Te')
# (20, 9, 1)
# (' -> ', 'Vd+')
# (20, 9, 1)
# (' -> ', 'Ve')
# (20, 9, 1)
# (' -> ', 'ddt(NVd)')
# (20, 9, 1)
# (' -> ', 'ddt(NVd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pe)')
# (20, 9, 1)
# (' -> ', 'kappa_par_d+')
# (20, 9, 1)
# (' -> ', 'kappa_par_e')
# (20, 9, 1)
# ('/ssd_scratch/hcases/xpoint_heat/xph1-base_master/BOUT.dmp.2.nc', ' -> ', '/ssd_scratch/hcases/xpoint_heat/xph1-base_master_restart/BOUT.restart.2.nc')
# ('hist_hi = ', 100)
# ('tt = ', 4299850.0)
# ('NXPE = ', BoutArray(1, dtype=int32), ' NYPE = ', BoutArray(10, dtype=int32))
# (' -> ', 'Dnnd')
# (20, 9, 1)
# (' -> ', 'Ed+_iz')
# (20, 9, 1)
# (' -> ', 'Ed+_rec')
# (20, 9, 1)
# (' -> ', 'Ed_pump')
# (20, 9, 1)
# (' -> ', 'Ed_target_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_target_refl')
# (20, 9, 1)
# (' -> ', 'Ed_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_wall_refl')
# (20, 9, 1)
# (' -> ', 'Edd+_cx')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_ylow')
# (20, 9, 1)
# (' -> ', 'Fd+_iz')
# (20, 9, 1)
# (' -> ', 'Fd+_rec')
# (20, 9, 1)
# (' -> ', 'Fdd+_cx')
# (20, 9, 1)
# (' -> ', 'Kd+d+_coll')
# (20, 9, 1)
# (' -> ', 'Kd+e_coll')
# (20, 9, 1)
# (' -> ', 'Kdd+_cx')
# (20, 9, 1)
# (' -> ', 'Ked+_coll')
# (20, 9, 1)
# (' -> ', 'Kee_coll')
# (20, 9, 1)
# (' -> ', 'MomentumFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'NVd')
# (20, 9, 1)
# (' -> ', 'NVd+')
# (20, 9, 1)
# (' -> ', 'Nd')
# (20, 9, 1)
# (' -> ', 'Nd+')
# (20, 9, 1)
# (' -> ', 'Ne')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'Pd')
# (20, 9, 1)
# (' -> ', 'Pd+')
# (20, 9, 1)
# (' -> ', 'Pd+_src')
# (20, 9, 1)
# (' -> ', 'Pd_src')
# (20, 9, 1)
# (' -> ', 'Pe')
# (20, 9, 1)
# (' -> ', 'Pe_src')
# (20, 9, 1)
# (' -> ', 'Rd+_ex')
# (20, 9, 1)
# (' -> ', 'Rd+_rec')
# (20, 9, 1)
# (' -> ', 'SNVd')
# (20, 9, 1)
# (' -> ', 'SNVd+')
# (20, 9, 1)
# (' -> ', 'SNd')
# (20, 9, 1)
# (' -> ', 'SNd+')
# (20, 9, 1)
# (' -> ', 'SPd')
# (20, 9, 1)
# (' -> ', 'SPd+')
# (20, 9, 1)
# (' -> ', 'SPe')
# (20, 9, 1)
# (' -> ', 'Sd+_iz')
# (20, 9, 1)
# (' -> ', 'Sd+_rec')
# (20, 9, 1)
# (' -> ', 'Sd+_src')
# (20, 9, 1)
# (' -> ', 'Sd_pump')
# (20, 9, 1)
# (' -> ', 'Sd_src')
# (20, 9, 1)
# (' -> ', 'Sd_target_recycle')
# (20, 9, 1)
# (' -> ', 'Sd_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Td')
# (20, 9, 1)
# (' -> ', 'Td+')
# (20, 9, 1)
# (' -> ', 'Te')
# (20, 9, 1)
# (' -> ', 'Vd+')
# (20, 9, 1)
# (' -> ', 'Ve')
# (20, 9, 1)
# (' -> ', 'ddt(NVd)')
# (20, 9, 1)
# (' -> ', 'ddt(NVd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pe)')
# (20, 9, 1)
# (' -> ', 'kappa_par_d+')
# (20, 9, 1)
# (' -> ', 'kappa_par_e')
# (20, 9, 1)
# ('/ssd_scratch/hcases/xpoint_heat/xph1-base_master/BOUT.dmp.3.nc', ' -> ', '/ssd_scratch/hcases/xpoint_heat/xph1-base_master_restart/BOUT.restart.3.nc')
# ('hist_hi = ', 100)
# ('tt = ', 4299850.0)
# ('NXPE = ', BoutArray(1, dtype=int32), ' NYPE = ', BoutArray(10, dtype=int32))
# (' -> ', 'Dnnd')
# (20, 9, 1)
# (' -> ', 'Ed+_iz')
# (20, 9, 1)
# (' -> ', 'Ed+_rec')
# (20, 9, 1)
# (' -> ', 'Ed_pump')
# (20, 9, 1)
# (' -> ', 'Ed_target_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_target_refl')
# (20, 9, 1)
# (' -> ', 'Ed_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_wall_refl')
# (20, 9, 1)
# (' -> ', 'Edd+_cx')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_ylow')
# (20, 9, 1)
# (' -> ', 'Fd+_iz')
# (20, 9, 1)
# (' -> ', 'Fd+_rec')
# (20, 9, 1)
# (' -> ', 'Fdd+_cx')
# (20, 9, 1)
# (' -> ', 'Kd+d+_coll')
# (20, 9, 1)
# (' -> ', 'Kd+e_coll')
# (20, 9, 1)
# (' -> ', 'Kdd+_cx')
# (20, 9, 1)
# (' -> ', 'Ked+_coll')
# (20, 9, 1)
# (' -> ', 'Kee_coll')
# (20, 9, 1)
# (' -> ', 'MomentumFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'NVd')
# (20, 9, 1)
# (' -> ', 'NVd+')
# (20, 9, 1)
# (' -> ', 'Nd')
# (20, 9, 1)
# (' -> ', 'Nd+')
# (20, 9, 1)
# (' -> ', 'Ne')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'Pd')
# (20, 9, 1)
# (' -> ', 'Pd+')
# (20, 9, 1)
# (' -> ', 'Pd+_src')
# (20, 9, 1)
# (' -> ', 'Pd_src')
# (20, 9, 1)
# (' -> ', 'Pe')
# (20, 9, 1)
# (' -> ', 'Pe_src')
# (20, 9, 1)
# (' -> ', 'Rd+_ex')
# (20, 9, 1)
# (' -> ', 'Rd+_rec')
# (20, 9, 1)
# (' -> ', 'SNVd')
# (20, 9, 1)
# (' -> ', 'SNVd+')
# (20, 9, 1)
# (' -> ', 'SNd')
# (20, 9, 1)
# (' -> ', 'SNd+')
# (20, 9, 1)
# (' -> ', 'SPd')
# (20, 9, 1)
# (' -> ', 'SPd+')
# (20, 9, 1)
# (' -> ', 'SPe')
# (20, 9, 1)
# (' -> ', 'Sd+_iz')
# (20, 9, 1)
# (' -> ', 'Sd+_rec')
# (20, 9, 1)
# (' -> ', 'Sd+_src')
# (20, 9, 1)
# (' -> ', 'Sd_pump')
# (20, 9, 1)
# (' -> ', 'Sd_src')
# (20, 9, 1)
# (' -> ', 'Sd_target_recycle')
# (20, 9, 1)
# (' -> ', 'Sd_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Td')
# (20, 9, 1)
# (' -> ', 'Td+')
# (20, 9, 1)
# (' -> ', 'Te')
# (20, 9, 1)
# (' -> ', 'Vd+')
# (20, 9, 1)
# (' -> ', 'Ve')
# (20, 9, 1)
# (' -> ', 'ddt(NVd)')
# (20, 9, 1)
# (' -> ', 'ddt(NVd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pe)')
# (20, 9, 1)
# (' -> ', 'kappa_par_d+')
# (20, 9, 1)
# (' -> ', 'kappa_par_e')
# (20, 9, 1)
# ('/ssd_scratch/hcases/xpoint_heat/xph1-base_master/BOUT.dmp.4.nc', ' -> ', '/ssd_scratch/hcases/xpoint_heat/xph1-base_master_restart/BOUT.restart.4.nc')
# ('hist_hi = ', 100)
# ('tt = ', 4299850.0)
# ('NXPE = ', BoutArray(1, dtype=int32), ' NYPE = ', BoutArray(10, dtype=int32))
# (' -> ', 'Dnnd')
# (20, 9, 1)
# (' -> ', 'Ed+_iz')
# (20, 9, 1)
# (' -> ', 'Ed+_rec')
# (20, 9, 1)
# (' -> ', 'Ed_pump')
# (20, 9, 1)
# (' -> ', 'Ed_target_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_target_refl')
# (20, 9, 1)
# (' -> ', 'Ed_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_wall_refl')
# (20, 9, 1)
# (' -> ', 'Edd+_cx')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_ylow')
# (20, 9, 1)
# (' -> ', 'Fd+_iz')
# (20, 9, 1)
# (' -> ', 'Fd+_rec')
# (20, 9, 1)
# (' -> ', 'Fdd+_cx')
# (20, 9, 1)
# (' -> ', 'Kd+d+_coll')
# (20, 9, 1)
# (' -> ', 'Kd+e_coll')
# (20, 9, 1)
# (' -> ', 'Kdd+_cx')
# (20, 9, 1)
# (' -> ', 'Ked+_coll')
# (20, 9, 1)
# (' -> ', 'Kee_coll')
# (20, 9, 1)
# (' -> ', 'MomentumFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'NVd')
# (20, 9, 1)
# (' -> ', 'NVd+')
# (20, 9, 1)
# (' -> ', 'Nd')
# (20, 9, 1)
# (' -> ', 'Nd+')
# (20, 9, 1)
# (' -> ', 'Ne')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'Pd')
# (20, 9, 1)
# (' -> ', 'Pd+')
# (20, 9, 1)
# (' -> ', 'Pd+_src')
# (20, 9, 1)
# (' -> ', 'Pd_src')
# (20, 9, 1)
# (' -> ', 'Pe')
# (20, 9, 1)
# (' -> ', 'Pe_src')
# (20, 9, 1)
# (' -> ', 'Rd+_ex')
# (20, 9, 1)
# (' -> ', 'Rd+_rec')
# (20, 9, 1)
# (' -> ', 'SNVd')
# (20, 9, 1)
# (' -> ', 'SNVd+')
# (20, 9, 1)
# (' -> ', 'SNd')
# (20, 9, 1)
# (' -> ', 'SNd+')
# (20, 9, 1)
# (' -> ', 'SPd')
# (20, 9, 1)
# (' -> ', 'SPd+')
# (20, 9, 1)
# (' -> ', 'SPe')
# (20, 9, 1)
# (' -> ', 'Sd+_iz')
# (20, 9, 1)
# (' -> ', 'Sd+_rec')
# (20, 9, 1)
# (' -> ', 'Sd+_src')
# (20, 9, 1)
# (' -> ', 'Sd_pump')
# (20, 9, 1)
# (' -> ', 'Sd_src')
# (20, 9, 1)
# (' -> ', 'Sd_target_recycle')
# (20, 9, 1)
# (' -> ', 'Sd_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Td')
# (20, 9, 1)
# (' -> ', 'Td+')
# (20, 9, 1)
# (' -> ', 'Te')
# (20, 9, 1)
# (' -> ', 'Vd+')
# (20, 9, 1)
# (' -> ', 'Ve')
# (20, 9, 1)
# (' -> ', 'ddt(NVd)')
# (20, 9, 1)
# (' -> ', 'ddt(NVd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pe)')
# (20, 9, 1)
# (' -> ', 'kappa_par_d+')
# (20, 9, 1)
# (' -> ', 'kappa_par_e')
# (20, 9, 1)
# ('/ssd_scratch/hcases/xpoint_heat/xph1-base_master/BOUT.dmp.5.nc', ' -> ', '/ssd_scratch/hcases/xpoint_heat/xph1-base_master_restart/BOUT.restart.5.nc')
# ('hist_hi = ', 100)
# ('tt = ', 4299850.0)
# ('NXPE = ', BoutArray(1, dtype=int32), ' NYPE = ', BoutArray(10, dtype=int32))
# (' -> ', 'Dnnd')
# (20, 9, 1)
# (' -> ', 'Ed+_iz')
# (20, 9, 1)
# (' -> ', 'Ed+_rec')
# (20, 9, 1)
# (' -> ', 'Ed_pump')
# (20, 9, 1)
# (' -> ', 'Ed_target_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_target_refl')
# (20, 9, 1)
# (' -> ', 'Ed_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_wall_refl')
# (20, 9, 1)
# (' -> ', 'Edd+_cx')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_ylow')
# (20, 9, 1)
# (' -> ', 'Fd+_iz')
# (20, 9, 1)
# (' -> ', 'Fd+_rec')
# (20, 9, 1)
# (' -> ', 'Fdd+_cx')
# (20, 9, 1)
# (' -> ', 'Kd+d+_coll')
# (20, 9, 1)
# (' -> ', 'Kd+e_coll')
# (20, 9, 1)
# (' -> ', 'Kdd+_cx')
# (20, 9, 1)
# (' -> ', 'Ked+_coll')
# (20, 9, 1)
# (' -> ', 'Kee_coll')
# (20, 9, 1)
# (' -> ', 'MomentumFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'NVd')
# (20, 9, 1)
# (' -> ', 'NVd+')
# (20, 9, 1)
# (' -> ', 'Nd')
# (20, 9, 1)
# (' -> ', 'Nd+')
# (20, 9, 1)
# (' -> ', 'Ne')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'Pd')
# (20, 9, 1)
# (' -> ', 'Pd+')
# (20, 9, 1)
# (' -> ', 'Pd+_src')
# (20, 9, 1)
# (' -> ', 'Pd_src')
# (20, 9, 1)
# (' -> ', 'Pe')
# (20, 9, 1)
# (' -> ', 'Pe_src')
# (20, 9, 1)
# (' -> ', 'Rd+_ex')
# (20, 9, 1)
# (' -> ', 'Rd+_rec')
# (20, 9, 1)
# (' -> ', 'SNVd')
# (20, 9, 1)
# (' -> ', 'SNVd+')
# (20, 9, 1)
# (' -> ', 'SNd')
# (20, 9, 1)
# (' -> ', 'SNd+')
# (20, 9, 1)
# (' -> ', 'SPd')
# (20, 9, 1)
# (' -> ', 'SPd+')
# (20, 9, 1)
# (' -> ', 'SPe')
# (20, 9, 1)
# (' -> ', 'Sd+_iz')
# (20, 9, 1)
# (' -> ', 'Sd+_rec')
# (20, 9, 1)
# (' -> ', 'Sd+_src')
# (20, 9, 1)
# (' -> ', 'Sd_pump')
# (20, 9, 1)
# (' -> ', 'Sd_src')
# (20, 9, 1)
# (' -> ', 'Sd_target_recycle')
# (20, 9, 1)
# (' -> ', 'Sd_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Td')
# (20, 9, 1)
# (' -> ', 'Td+')
# (20, 9, 1)
# (' -> ', 'Te')
# (20, 9, 1)
# (' -> ', 'Vd+')
# (20, 9, 1)
# (' -> ', 'Ve')
# (20, 9, 1)
# (' -> ', 'ddt(NVd)')
# (20, 9, 1)
# (' -> ', 'ddt(NVd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pe)')
# (20, 9, 1)
# (' -> ', 'kappa_par_d+')
# (20, 9, 1)
# (' -> ', 'kappa_par_e')
# (20, 9, 1)
# ('/ssd_scratch/hcases/xpoint_heat/xph1-base_master/BOUT.dmp.6.nc', ' -> ', '/ssd_scratch/hcases/xpoint_heat/xph1-base_master_restart/BOUT.restart.6.nc')
# ('hist_hi = ', 100)
# ('tt = ', 4299850.0)
# ('NXPE = ', BoutArray(1, dtype=int32), ' NYPE = ', BoutArray(10, dtype=int32))
# (' -> ', 'Dnnd')
# (20, 9, 1)
# (' -> ', 'Ed+_iz')
# (20, 9, 1)
# (' -> ', 'Ed+_rec')
# (20, 9, 1)
# (' -> ', 'Ed_pump')
# (20, 9, 1)
# (' -> ', 'Ed_target_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_target_refl')
# (20, 9, 1)
# (' -> ', 'Ed_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_wall_refl')
# (20, 9, 1)
# (' -> ', 'Edd+_cx')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_ylow')
# (20, 9, 1)
# (' -> ', 'Fd+_iz')
# (20, 9, 1)
# (' -> ', 'Fd+_rec')
# (20, 9, 1)
# (' -> ', 'Fdd+_cx')
# (20, 9, 1)
# (' -> ', 'Kd+d+_coll')
# (20, 9, 1)
# (' -> ', 'Kd+e_coll')
# (20, 9, 1)
# (' -> ', 'Kdd+_cx')
# (20, 9, 1)
# (' -> ', 'Ked+_coll')
# (20, 9, 1)
# (' -> ', 'Kee_coll')
# (20, 9, 1)
# (' -> ', 'MomentumFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'NVd')
# (20, 9, 1)
# (' -> ', 'NVd+')
# (20, 9, 1)
# (' -> ', 'Nd')
# (20, 9, 1)
# (' -> ', 'Nd+')
# (20, 9, 1)
# (' -> ', 'Ne')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'Pd')
# (20, 9, 1)
# (' -> ', 'Pd+')
# (20, 9, 1)
# (' -> ', 'Pd+_src')
# (20, 9, 1)
# (' -> ', 'Pd_src')
# (20, 9, 1)
# (' -> ', 'Pe')
# (20, 9, 1)
# (' -> ', 'Pe_src')
# (20, 9, 1)
# (' -> ', 'Rd+_ex')
# (20, 9, 1)
# (' -> ', 'Rd+_rec')
# (20, 9, 1)
# (' -> ', 'SNVd')
# (20, 9, 1)
# (' -> ', 'SNVd+')
# (20, 9, 1)
# (' -> ', 'SNd')
# (20, 9, 1)
# (' -> ', 'SNd+')
# (20, 9, 1)
# (' -> ', 'SPd')
# (20, 9, 1)
# (' -> ', 'SPd+')
# (20, 9, 1)
# (' -> ', 'SPe')
# (20, 9, 1)
# (' -> ', 'Sd+_iz')
# (20, 9, 1)
# (' -> ', 'Sd+_rec')
# (20, 9, 1)
# (' -> ', 'Sd+_src')
# (20, 9, 1)
# (' -> ', 'Sd_pump')
# (20, 9, 1)
# (' -> ', 'Sd_src')
# (20, 9, 1)
# (' -> ', 'Sd_target_recycle')
# (20, 9, 1)
# (' -> ', 'Sd_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Td')
# (20, 9, 1)
# (' -> ', 'Td+')
# (20, 9, 1)
# (' -> ', 'Te')
# (20, 9, 1)
# (' -> ', 'Vd+')
# (20, 9, 1)
# (' -> ', 'Ve')
# (20, 9, 1)
# (' -> ', 'ddt(NVd)')
# (20, 9, 1)
# (' -> ', 'ddt(NVd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pe)')
# (20, 9, 1)
# (' -> ', 'kappa_par_d+')
# (20, 9, 1)
# (' -> ', 'kappa_par_e')
# (20, 9, 1)
# ('/ssd_scratch/hcases/xpoint_heat/xph1-base_master/BOUT.dmp.7.nc', ' -> ', '/ssd_scratch/hcases/xpoint_heat/xph1-base_master_restart/BOUT.restart.7.nc')
# ('hist_hi = ', 100)
# ('tt = ', 4299850.0)
# ('NXPE = ', BoutArray(1, dtype=int32), ' NYPE = ', BoutArray(10, dtype=int32))
# (' -> ', 'Dnnd')
# (20, 9, 1)
# (' -> ', 'Ed+_iz')
# (20, 9, 1)
# (' -> ', 'Ed+_rec')
# (20, 9, 1)
# (' -> ', 'Ed_pump')
# (20, 9, 1)
# (' -> ', 'Ed_target_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_target_refl')
# (20, 9, 1)
# (' -> ', 'Ed_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_wall_refl')
# (20, 9, 1)
# (' -> ', 'Edd+_cx')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_ylow')
# (20, 9, 1)
# (' -> ', 'Fd+_iz')
# (20, 9, 1)
# (' -> ', 'Fd+_rec')
# (20, 9, 1)
# (' -> ', 'Fdd+_cx')
# (20, 9, 1)
# (' -> ', 'Kd+d+_coll')
# (20, 9, 1)
# (' -> ', 'Kd+e_coll')
# (20, 9, 1)
# (' -> ', 'Kdd+_cx')
# (20, 9, 1)
# (' -> ', 'Ked+_coll')
# (20, 9, 1)
# (' -> ', 'Kee_coll')
# (20, 9, 1)
# (' -> ', 'MomentumFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'NVd')
# (20, 9, 1)
# (' -> ', 'NVd+')
# (20, 9, 1)
# (' -> ', 'Nd')
# (20, 9, 1)
# (' -> ', 'Nd+')
# (20, 9, 1)
# (' -> ', 'Ne')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'Pd')
# (20, 9, 1)
# (' -> ', 'Pd+')
# (20, 9, 1)
# (' -> ', 'Pd+_src')
# (20, 9, 1)
# (' -> ', 'Pd_src')
# (20, 9, 1)
# (' -> ', 'Pe')
# (20, 9, 1)
# (' -> ', 'Pe_src')
# (20, 9, 1)
# (' -> ', 'Rd+_ex')
# (20, 9, 1)
# (' -> ', 'Rd+_rec')
# (20, 9, 1)
# (' -> ', 'SNVd')
# (20, 9, 1)
# (' -> ', 'SNVd+')
# (20, 9, 1)
# (' -> ', 'SNd')
# (20, 9, 1)
# (' -> ', 'SNd+')
# (20, 9, 1)
# (' -> ', 'SPd')
# (20, 9, 1)
# (' -> ', 'SPd+')
# (20, 9, 1)
# (' -> ', 'SPe')
# (20, 9, 1)
# (' -> ', 'Sd+_iz')
# (20, 9, 1)
# (' -> ', 'Sd+_rec')
# (20, 9, 1)
# (' -> ', 'Sd+_src')
# (20, 9, 1)
# (' -> ', 'Sd_pump')
# (20, 9, 1)
# (' -> ', 'Sd_src')
# (20, 9, 1)
# (' -> ', 'Sd_target_recycle')
# (20, 9, 1)
# (' -> ', 'Sd_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Td')
# (20, 9, 1)
# (' -> ', 'Td+')
# (20, 9, 1)
# (' -> ', 'Te')
# (20, 9, 1)
# (' -> ', 'Vd+')
# (20, 9, 1)
# (' -> ', 'Ve')
# (20, 9, 1)
# (' -> ', 'ddt(NVd)')
# (20, 9, 1)
# (' -> ', 'ddt(NVd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pe)')
# (20, 9, 1)
# (' -> ', 'kappa_par_d+')
# (20, 9, 1)
# (' -> ', 'kappa_par_e')
# (20, 9, 1)
# ('/ssd_scratch/hcases/xpoint_heat/xph1-base_master/BOUT.dmp.8.nc', ' -> ', '/ssd_scratch/hcases/xpoint_heat/xph1-base_master_restart/BOUT.restart.8.nc')
# ('hist_hi = ', 100)
# ('tt = ', 4299850.0)
# ('NXPE = ', BoutArray(1, dtype=int32), ' NYPE = ', BoutArray(10, dtype=int32))
# (' -> ', 'Dnnd')
# (20, 9, 1)
# (' -> ', 'Ed+_iz')
# (20, 9, 1)
# (' -> ', 'Ed+_rec')
# (20, 9, 1)
# (' -> ', 'Ed_pump')
# (20, 9, 1)
# (' -> ', 'Ed_target_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_target_refl')
# (20, 9, 1)
# (' -> ', 'Ed_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_wall_refl')
# (20, 9, 1)
# (' -> ', 'Edd+_cx')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_ylow')
# (20, 9, 1)
# (' -> ', 'Fd+_iz')
# (20, 9, 1)
# (' -> ', 'Fd+_rec')
# (20, 9, 1)
# (' -> ', 'Fdd+_cx')
# (20, 9, 1)
# (' -> ', 'Kd+d+_coll')
# (20, 9, 1)
# (' -> ', 'Kd+e_coll')
# (20, 9, 1)
# (' -> ', 'Kdd+_cx')
# (20, 9, 1)
# (' -> ', 'Ked+_coll')
# (20, 9, 1)
# (' -> ', 'Kee_coll')
# (20, 9, 1)
# (' -> ', 'MomentumFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'NVd')
# (20, 9, 1)
# (' -> ', 'NVd+')
# (20, 9, 1)
# (' -> ', 'Nd')
# (20, 9, 1)
# (' -> ', 'Nd+')
# (20, 9, 1)
# (' -> ', 'Ne')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'Pd')
# (20, 9, 1)
# (' -> ', 'Pd+')
# (20, 9, 1)
# (' -> ', 'Pd+_src')
# (20, 9, 1)
# (' -> ', 'Pd_src')
# (20, 9, 1)
# (' -> ', 'Pe')
# (20, 9, 1)
# (' -> ', 'Pe_src')
# (20, 9, 1)
# (' -> ', 'Rd+_ex')
# (20, 9, 1)
# (' -> ', 'Rd+_rec')
# (20, 9, 1)
# (' -> ', 'SNVd')
# (20, 9, 1)
# (' -> ', 'SNVd+')
# (20, 9, 1)
# (' -> ', 'SNd')
# (20, 9, 1)
# (' -> ', 'SNd+')
# (20, 9, 1)
# (' -> ', 'SPd')
# (20, 9, 1)
# (' -> ', 'SPd+')
# (20, 9, 1)
# (' -> ', 'SPe')
# (20, 9, 1)
# (' -> ', 'Sd+_iz')
# (20, 9, 1)
# (' -> ', 'Sd+_rec')
# (20, 9, 1)
# (' -> ', 'Sd+_src')
# (20, 9, 1)
# (' -> ', 'Sd_pump')
# (20, 9, 1)
# (' -> ', 'Sd_src')
# (20, 9, 1)
# (' -> ', 'Sd_target_recycle')
# (20, 9, 1)
# (' -> ', 'Sd_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Td')
# (20, 9, 1)
# (' -> ', 'Td+')
# (20, 9, 1)
# (' -> ', 'Te')
# (20, 9, 1)
# (' -> ', 'Vd+')
# (20, 9, 1)
# (' -> ', 'Ve')
# (20, 9, 1)
# (' -> ', 'ddt(NVd)')
# (20, 9, 1)
# (' -> ', 'ddt(NVd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pe)')
# (20, 9, 1)
# (' -> ', 'kappa_par_d+')
# (20, 9, 1)
# (' -> ', 'kappa_par_e')
# (20, 9, 1)
# ('/ssd_scratch/hcases/xpoint_heat/xph1-base_master/BOUT.dmp.9.nc', ' -> ', '/ssd_scratch/hcases/xpoint_heat/xph1-base_master_restart/BOUT.restart.9.nc')
# ('hist_hi = ', 100)
# ('tt = ', 4299850.0)
# ('NXPE = ', BoutArray(1, dtype=int32), ' NYPE = ', BoutArray(10, dtype=int32))
# (' -> ', 'Dnnd')
# (20, 9, 1)
# (' -> ', 'Ed+_iz')
# (20, 9, 1)
# (' -> ', 'Ed+_rec')
# (20, 9, 1)
# (' -> ', 'Ed_pump')
# (20, 9, 1)
# (' -> ', 'Ed_target_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_target_refl')
# (20, 9, 1)
# (' -> ', 'Ed_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Ed_wall_refl')
# (20, 9, 1)
# (' -> ', 'Edd+_cx')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_xlow')
# (20, 9, 1)
# (' -> ', 'EnergyFlow_e_ylow')
# (20, 9, 1)
# (' -> ', 'Fd+_iz')
# (20, 9, 1)
# (' -> ', 'Fd+_rec')
# (20, 9, 1)
# (' -> ', 'Fdd+_cx')
# (20, 9, 1)
# (' -> ', 'Kd+d+_coll')
# (20, 9, 1)
# (' -> ', 'Kd+e_coll')
# (20, 9, 1)
# (' -> ', 'Kdd+_cx')
# (20, 9, 1)
# (' -> ', 'Ked+_coll')
# (20, 9, 1)
# (' -> ', 'Kee_coll')
# (20, 9, 1)
# (' -> ', 'MomentumFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'NVd')
# (20, 9, 1)
# (' -> ', 'NVd+')
# (20, 9, 1)
# (' -> ', 'Nd')
# (20, 9, 1)
# (' -> ', 'Nd+')
# (20, 9, 1)
# (' -> ', 'Ne')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_xlow')
# (20, 9, 1)
# (' -> ', 'ParticleFlow_d+_ylow')
# (20, 9, 1)
# (' -> ', 'Pd')
# (20, 9, 1)
# (' -> ', 'Pd+')
# (20, 9, 1)
# (' -> ', 'Pd+_src')
# (20, 9, 1)
# (' -> ', 'Pd_src')
# (20, 9, 1)
# (' -> ', 'Pe')
# (20, 9, 1)
# (' -> ', 'Pe_src')
# (20, 9, 1)
# (' -> ', 'Rd+_ex')
# (20, 9, 1)
# (' -> ', 'Rd+_rec')
# (20, 9, 1)
# (' -> ', 'SNVd')
# (20, 9, 1)
# (' -> ', 'SNVd+')
# (20, 9, 1)
# (' -> ', 'SNd')
# (20, 9, 1)
# (' -> ', 'SNd+')
# (20, 9, 1)
# (' -> ', 'SPd')
# (20, 9, 1)
# (' -> ', 'SPd+')
# (20, 9, 1)
# (' -> ', 'SPe')
# (20, 9, 1)
# (' -> ', 'Sd+_iz')
# (20, 9, 1)
# (' -> ', 'Sd+_rec')
# (20, 9, 1)
# (' -> ', 'Sd+_src')
# (20, 9, 1)
# (' -> ', 'Sd_pump')
# (20, 9, 1)
# (' -> ', 'Sd_src')
# (20, 9, 1)
# (' -> ', 'Sd_target_recycle')
# (20, 9, 1)
# (' -> ', 'Sd_wall_recycle')
# (20, 9, 1)
# (' -> ', 'Td')
# (20, 9, 1)
# (' -> ', 'Td+')
# (20, 9, 1)
# (' -> ', 'Te')
# (20, 9, 1)
# (' -> ', 'Vd+')
# (20, 9, 1)
# (' -> ', 'Ve')
# (20, 9, 1)
# (' -> ', 'ddt(NVd)')
# (20, 9, 1)
# (' -> ', 'ddt(NVd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd)')
# (20, 9, 1)
# (' -> ', 'ddt(Nd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd)')
# (20, 9, 1)
# (' -> ', 'ddt(Pd+)')
# (20, 9, 1)
# (' -> ', 'ddt(Pe)')
# (20, 9, 1)
# (' -> ', 'kappa_par_d+')
# (20, 9, 1)
# (' -> ', 'kappa_par_e')
# (20, 9, 1)
