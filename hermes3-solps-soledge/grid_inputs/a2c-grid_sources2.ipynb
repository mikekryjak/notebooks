# %%
onedrive = r"C:\Users\mikek\OneDrive"

from boututils.datafile import DataFile
from boutdata.collect import collect
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys, pathlib
import platform
import traceback
import xarray as xr
import xbout
from pathlib import Path

import shutil

sys.path.append(os.path.join(onedrive,r"Project\python-packages\sdtools"))

from hermes3.case_db import *
from hermes3.load import *
from hermes3.named_selections import *
from hermes3.plotting import *
from hermes3.grid_fields import *
from hermes3.accessors import *
from hermes3.utils import *

# %load_ext autoreload
# %autoreload 2


print("Done")
# Out:
# Done

# %% [markdown]
# # Add core sources and transport barrier

# %%
# close_mesh()
old_grid_path = r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4b-fine_nonorth_xpoint_guards.nc"
new_grid_path = r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc"
impose_fields(
    old_grid_path,
    new_grid_path,
    Ni_src_core = 3e20,    # s-1
    Pi_src_core = 1e6 * 2/3,   # W converted to pressure
    Pe_src_core = 0.76e6 * 2/3,   # W converted to pressure
    D_core = 0.3,
    chi_core = 0.45,
    D_sol = 1,
    chi_sol = 3,
)
# Out:
# WARNING: Puff is suppressed
# Defining dimension z of size 1
# >>> Field Nd+_src already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc, it will be overwritten
# -> Wrote field Nd+_src to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc
# >>> Field Pd+_src already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc, it will be overwritten
# -> Wrote field Pd+_src to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc
# >>> Field Pe_src already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc, it will be overwritten
# -> Wrote field Pe_src to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc
# >>> Field D_d+ already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc, it will be overwritten
# -> Wrote field D_d+ to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc
# >>> Field D_e already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc, it will be overwritten
# -> Wrote field D_e to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc
# >>> Field chi_d+ already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc, it will be overwritten
# -> Wrote field chi_d+ to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc
# >>> Field chi_e already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc, it will be overwritten
# -> Wrote field chi_e to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc
# Mesh file C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc closed

# %% [markdown]
# # Manually add puff and pump

# %%
plt.close("all")
mesh = Mesh(new_grid_path)
self = mesh

midplane_a = int((self.j2_2g - self.j1_2g) / 2) + self.j1_2g
midplane_b = int((self.j2_2g - self.j1_2g) / 2) + self.j1_2g + 1


# puff_indices = [2, 5, 8]   # fine grid
puff_indices = [1, 2, 5]   # SOLEDGE puff, coarse grid

selection =  (-self.MXG-1, 
            np.r_[
                [midplane_a-x for x in puff_indices],
                [midplane_b+x for x in puff_indices]
                ])
            
# puff_region = mesh.slices("symmetric_puff")(width=3, center_half_gap=1)
puff_region = selection

mesh.mesh["dv"] = mesh.mesh["dy"] * mesh.mesh["dx"] * mesh.mesh["J"] * 2*np.pi
volume = mesh.mesh["dv"][puff_region]

total_flow = 1.2e21   # atoms per second

total_flow_per_volume = total_flow * (volume/volume.sum()) / volume  # first find how much per cell, then per volume
print(f"Total flow: {total_flow} [s-1]")
print(f"Total flow per volume: {total_flow_per_volume.sum():.2e} [s-1 m-3]")

heat_source = 1.2e21 * 3 * constants("q_e")  #  3eV per particle (assume dissociated molecules)
heat_source_per_volume = heat_source * (volume/volume.sum()) / volume 
print(f"Total heat source: {heat_source:.2e} [W]")
print(f"Total heat source per volume: {heat_source_per_volume.sum():.2e} [W m-3]")

pump_region = (-self.MXG-1, 
            np.r_[
                slice(mesh.ny_inner+mesh.MYG*3, mesh.j1_2g+1),
                slice(mesh.j2_2g, mesh.nyg-mesh.MYG*1)
                ])

Pd_src = Field("Pd_src", mesh)
Nd_src = Field("Nd_src", mesh)
is_pump = Field("is_pump", mesh)

print()

Nd_src.data[puff_region] = total_flow_per_volume
Pd_src.data[puff_region] = heat_source_per_volume
mesh.write_field(Nd_src)
mesh.write_field(Pd_src)

is_pump.data[pump_region] = 1
Nd_src.plot(dpi = 200)
is_pump.plot(dpi = 200)

mesh.write_field(is_pump, dtype = "Field2D")

try:
    mesh.close()
    del mesh
except:
    pass
# Out:
# Total flow: 1.2e+21 [s-1]
# Total flow per volume: 5.23e+23 [s-1 m-3]
# Total heat source: 5.77e+02 [W]
# Total heat source per volume: 2.51e+05 [W m-3]
#
# >>> Field Nd_src already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc, it will be overwritten
# -> Wrote field Nd_src to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc
# >>> Field Pd_src already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc, it will be overwritten
# -> Wrote field Pd_src to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc
# >>> Field is_pump already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc, it will be overwritten
# -> Wrote field is_pump to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc
# Mesh file C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc closed

# %%
mesh = Mesh(r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc")
print(np.unique(mesh.mesh["is_pump"]))
mesh2.close()
# Out:
# [0. 1.]
# Mesh file C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4bf1-fine_nonorth_xpoint_guards_allfields.nc closed

# %%
mesh1 = Mesh(old_grid_path)
mesh2 = Mesh(new_grid_path)

for field in ["is_pump", "Nd+_src", "Pd+_src", "Pe_src", "D_d+", "D_e", "chi_d+", "chi_e"]:
    print("\n")
    print(field, (mesh1.mesh[field] == mesh2.mesh[field]).all())

    print(np.mean(mesh1.mesh[field]))
    print(np.mean(mesh2.mesh[field]))
    
mesh1.close()
mesh2.close()

try:
    del mesh1
except:
    pass
try:
    del mesh2
except:
    pass
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 6
#       4 for field in ["is_pump", "Nd+_src", "Pd+_src", "Pe_src", "D_d+", "D_e", "chi_d+", "chi_e"]:
#       5     print("\n")
# ----> 6     print(field, (mesh1.mesh[field] == mesh2.mesh[field]).all())
#       8     print(np.mean(mesh1.mesh[field]))
#       9     print(np.mean(mesh2.mesh[field]))
#
# File c:\Users\mikek\OneDrive\Project\pyenvs\fusion-a-310\lib\site-packages\boututils\datafile.py:327, in DataFile.__getitem__(self, name)
#     326 def __getitem__(self, name):
# --> 327     return self.impl.__getitem__(name)
#
# File c:\Users\mikek\OneDrive\Project\pyenvs\fusion-a-310\lib\site-packages\boututils\datafile.py:445, in DataFile_netCDF.__getitem__(self, name)
#     443 var = self.read(name)
#     444 if var is None:
# --> 445     raise KeyError("No variable found: " + name)
#     446 return var
#
# KeyError: 'No variable found: is_pump'

# %%
try:
    mesh.close()
    del mesh
except:
    pass

mesh = Mesh(r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c2-fine_xpoint_fields.nc")

pressure_source_per_volume = mesh.mesh["Pd_src"].squeeze()
density_source_per_volume = mesh.mesh["Nd_src"].squeeze()

dv = mesh.mesh["dy"] * mesh.mesh["dx"] * mesh.mesh["J"] * 2*np.pi

pressure_source = (pressure_source_per_volume * dv).sum()
density_source = (density_source_per_volume * dv).sum()

print(f"Total pressure source: {pressure_source:.2e} [W]")
print(f"Pressure source per volume: {pressure_source_per_volume.sum():.2e} [W m-3]")
print(f"Total density source: {density_source:.2e} [s-1]")
print(f"Density source per volume: {density_source_per_volume.sum():.2e} [s-1 m-3]")

try:
    mesh.close()
    del mesh
except:
    pass
# Out:
# Total pressure source: 5.77e+02 [W]
# Pressure source per volume: 3.87e+05 [W m-3]
# Total density source: 1.20e+21 [s-1]
# Density source per volume: 8.06e+23 [s-1 m-3]
# Mesh file C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c2-fine_xpoint_fields.nc closed

# %%
mesh = Mesh(r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4a-fine_nonorth_xpoint.nc")


for x in mesh.mesh.keys():
    
    data = mesh.mesh[x]
    print(f"{x}: {type(data)}   {data.shape}")



mesh.close()
# Out:
# nx: <class 'boututils.boutarray.BoutArray'>   ()
# ny: <class 'boututils.boutarray.BoutArray'>   ()
# y_boundary_guards: <class 'boututils.boutarray.BoutArray'>   ()
# curvature_type: <class 'boututils.boutarray.BoutArray'>   ()
# Bt_axis: <class 'boututils.boutarray.BoutArray'>   ()
# psi_axis: <class 'boututils.boutarray.BoutArray'>   ()
# psi_bdry: <class 'boututils.boutarray.BoutArray'>   ()
# psi_axis_gfile: <class 'boututils.boutarray.BoutArray'>   ()
# psi_bdry_gfile: <class 'boututils.boutarray.BoutArray'>   ()
# closed_wall_R: <class 'boututils.boutarray.BoutArray'>   (39,)
# closed_wall_Z: <class 'boututils.boutarray.BoutArray'>   (39,)
# Rxy: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Rxy_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Rxy_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Zxy: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Zxy_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Zxy_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# psixy: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# psixy_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# psixy_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# dx: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# dx_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# dx_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# dy: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# dy_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# dy_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# poloidal_distance: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# poloidal_distance_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# poloidal_distance_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Brxy: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Brxy_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Brxy_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Bzxy: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Bzxy_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Bzxy_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Bpxy: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Bpxy_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Bpxy_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Btxy: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Btxy_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Btxy_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Bxy: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Bxy_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Bxy_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# hy: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# hy_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# hy_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# dphidy: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# dphidy_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# dphidy_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# ShiftTorsion: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# ShiftTorsion_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# ShiftTorsion_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# zShift: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# zShift_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# zShift_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g11: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g11_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g11_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g22: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g22_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g22_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g33: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g33_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g33_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g12: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g12_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g12_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g13: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g13_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g13_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g23: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g23_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g23_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# J: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# J_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# J_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_11: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_11_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_11_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_22: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_22_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_22_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_33: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_33_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_33_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_12: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_12_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_12_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_13: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_13_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_13_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_23: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_23_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# g_23_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# curl_bOverB_x: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# curl_bOverB_x_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# curl_bOverB_x_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# curl_bOverB_y: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# curl_bOverB_y_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# curl_bOverB_y_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# curl_bOverB_z: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# curl_bOverB_z_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# curl_bOverB_z_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# bxcvx: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# bxcvx_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# bxcvx_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# bxcvy: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# bxcvy_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# bxcvy_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# bxcvz: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# bxcvz_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# bxcvz_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# pressure: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# pressure_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# pressure_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# penalty_mask: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Rxy_corners: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Rxy_lower_right_corners: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Rxy_upper_right_corners: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Rxy_upper_left_corners: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Zxy_corners: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Zxy_lower_right_corners: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Zxy_upper_right_corners: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# Zxy_upper_left_corners: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# total_poloidal_distance: <class 'boututils.boutarray.BoutArray'>   (40,)
# ShiftAngle: <class 'boututils.boutarray.BoutArray'>   (40,)
# ixseps1: <class 'boututils.boutarray.BoutArray'>   ()
# ixseps2: <class 'boututils.boutarray.BoutArray'>   ()
# jyseps1_1: <class 'boututils.boutarray.BoutArray'>   ()
# jyseps2_1: <class 'boututils.boutarray.BoutArray'>   ()
# ny_inner: <class 'boututils.boutarray.BoutArray'>   ()
# jyseps1_2: <class 'boututils.boutarray.BoutArray'>   ()
# jyseps2_2: <class 'boututils.boutarray.BoutArray'>   ()
# y-coord: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# y-coord_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# y-coord_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# theta: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# theta_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# theta_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# chi: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# chi_xlow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# chi_ylow: <class 'boututils.boutarray.BoutArray'>   (40, 100)
# hypnotoad_inputs: <class 'boututils.boutarray.BoutArray'>   ()
# hypnotoad_inputs_yaml: <class 'boututils.boutarray.BoutArray'>   ()
# hypnotoad_input_geqdsk_file_contents: <class 'boututils.boutarray.BoutArray'>   ()
# Python_version: <class 'boututils.boutarray.BoutArray'>   ()
# module_versions: <class 'boututils.boutarray.BoutArray'>   ()
# Mesh file C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g4a-fine_nonorth_xpoint.nc closed
