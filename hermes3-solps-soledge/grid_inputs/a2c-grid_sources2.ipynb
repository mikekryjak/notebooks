# %%
onedrive = r"C:\Users\mikek\OneDrive"

from boututils.datafile import DataFile
from boutdata.collect import collect
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys, pathlib
import platform
import traceback
import xarray as xr
import xbout
from pathlib import Path

import shutil

sys.path.append(os.path.join(onedrive,r"Project\python-packages\sdtools"))

from hermes3.case_db import *
from hermes3.load import *
from hermes3.named_selections import *
from hermes3.plotting import *
from hermes3.grid_fields import *
from hermes3.accessors import *
from hermes3.utils import *

# %load_ext autoreload
# %autoreload 2


print("Done")
# Out:
# Done

# %% [markdown]
# # Add core sources and transport barrier

# %%
# close_mesh()
old_grid_path = r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3c-radial_fine_xpoint3.nc"
new_grid_path = r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc"
impose_fields(
    old_grid_path,
    new_grid_path,
    Ni_src_core = 3e20,    # s-1
    Pi_src_core = 1e6 * 2/3,   # W converted to pressure
    Pe_src_core = 0.76e6 * 2/3,   # W converted to pressure
    D_core = 0.3,
    chi_core = 0.45,
    D_sol = 1,
    chi_sol = 3,
)
# Out:
# WARNING: Puff is suppressed
# Defining dimension z of size 1
# >>> Field Nd+_src already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc, it will be overwritten
# -> Wrote field Nd+_src to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc
# >>> Field Pd+_src already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc, it will be overwritten
# -> Wrote field Pd+_src to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc
# >>> Field Pe_src already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc, it will be overwritten
# -> Wrote field Pe_src to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc
# >>> Field D_d+ already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc, it will be overwritten
# -> Wrote field D_d+ to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc
# >>> Field D_e already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc, it will be overwritten
# -> Wrote field D_e to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc
# >>> Field chi_d+ already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc, it will be overwritten
# -> Wrote field chi_d+ to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc
# >>> Field chi_e already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc, it will be overwritten
# -> Wrote field chi_e to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc
# Mesh file C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc closed

# %% [markdown]
# # Manually add puff and pump

# %%
plt.close("all")
mesh = Mesh(new_grid_path)
self = mesh

midplane_a = int((self.j2_2g - self.j1_2g) / 2) + self.j1_2g
midplane_b = int((self.j2_2g - self.j1_2g) / 2) + self.j1_2g + 1


# puff_indices = [2, 5, 8]   # fine grid
puff_indices = [1, 2, 5]   # SOLEDGE puff, coarse grid

selection =  (-self.MXG-1, 
            np.r_[
                [midplane_a-x for x in puff_indices],
                [midplane_b+x for x in puff_indices]
                ])
            
# puff_region = mesh.slices("symmetric_puff")(width=3, center_half_gap=1)
puff_region = selection

mesh.mesh["dv"] = mesh.mesh["dy"] * mesh.mesh["dx"] * mesh.mesh["J"] * 2*np.pi
volume = mesh.mesh["dv"][puff_region]

total_flow = 1.2e21   # atoms per second

total_flow_per_volume = total_flow * (volume/volume.sum()) / volume  # first find how much per cell, then per volume
print(f"Total flow: {total_flow} [s-1]")
print(f"Total flow per volume: {total_flow_per_volume.sum():.2e} [s-1 m-3]")

heat_source = 1.2e21 * 3 * constants("q_e")  #  3eV per particle (assume dissociated molecules)
heat_source_per_volume = heat_source * (volume/volume.sum()) / volume 
print(f"Total heat source: {heat_source:.2e} [W]")
print(f"Total heat source per volume: {heat_source_per_volume.sum():.2e} [W m-3]")

pump_region = (-self.MXG-1, 
            np.r_[
                slice(mesh.ny_inner+mesh.MYG*3, mesh.j1_2g+1),
                slice(mesh.j2_2g, mesh.nyg-mesh.MYG*1)
                ])

Pd_src = Field("Pd_src", mesh)
Nd_src = Field("Nd_src", mesh)
is_pump = Field("is_pump", mesh)

print()

Nd_src.data[puff_region] = total_flow_per_volume
Pd_src.data[puff_region] = heat_source_per_volume
mesh.write_field(Nd_src)
mesh.write_field(Pd_src)

is_pump.data[pump_region] = 1
Nd_src.plot(dpi = 200)
is_pump.plot(dpi = 200)

mesh.write_field(is_pump)

try:
    mesh.close()
    del mesh
except:
    pass
# Out:
# Total flow: 1.2e+21 [s-1]
# Total flow per volume: 4.00e+23 [s-1 m-3]
# Total heat source: 5.77e+02 [W]
# Total heat source per volume: 1.92e+05 [W m-3]
#
# >>> Field Nd_src already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc, it will be overwritten
# -> Wrote field Nd_src to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc
# >>> Field Pd_src already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc, it will be overwritten
# -> Wrote field Pd_src to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc
# >>> Field is_pump already exists in C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc, it will be overwritten
# -> Wrote field is_pump to C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc
# Mesh file C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c3cf1-radial_fine_xpoint3_fields.nc closed

# %%
mesh1 = Mesh(r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3b2f7-soledge_puff.nc")
mesh2 = Mesh(r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c2bb-step1_fields.nc")

for field in ["Nd+_src", "Pd+_src", "Pe_src", "D_d+", "D_e", "chi_d+", "chi_e"]:
    print("\n")
    print(field, (mesh1.mesh[field] == mesh2.mesh[field]).all())

    print(np.mean(mesh1.mesh[field]))
    print(np.mean(mesh2.mesh[field]))
    
mesh1.close()
mesh2.close()

try:
    del mesh1
except:
    pass
try:
    del mesh2
except:
    pass
# Out:
# Nd+_src False
# 3.2230174365030646e+19
# 3.2223840657859256e+19
#
#
# Pd+_src False
# 71622.6097000681
# 71608.5347952428
#
#
# Pe_src False
# 54433.18337205177
# 54422.48644438452
#
#
# D_d+ True
# 0.8703703703703703
# 0.8703703703703703
#
#
# D_e True
# 0.8703703703703703
# 0.8703703703703703
#
#
# chi_d+ True
# 2.5277777777777777
# 2.5277777777777777
#
#
# chi_e True
# 2.5277777777777777
# 2.5277777777777777
# Mesh file C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3b2f7-soledge_puff.nc closed
# Mesh file C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c2bb-step1_fields.nc closed

# %%
try:
    mesh.close()
    del mesh
except:
    pass

mesh = Mesh(r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c2-fine_xpoint_fields.nc")

pressure_source_per_volume = mesh.mesh["Pd_src"].squeeze()
density_source_per_volume = mesh.mesh["Nd_src"].squeeze()

dv = mesh.mesh["dy"] * mesh.mesh["dx"] * mesh.mesh["J"] * 2*np.pi

pressure_source = (pressure_source_per_volume * dv).sum()
density_source = (density_source_per_volume * dv).sum()

print(f"Total pressure source: {pressure_source:.2e} [W]")
print(f"Pressure source per volume: {pressure_source_per_volume.sum():.2e} [W m-3]")
print(f"Total density source: {density_source:.2e} [s-1]")
print(f"Density source per volume: {density_source_per_volume.sum():.2e} [s-1 m-3]")

try:
    mesh.close()
    del mesh
except:
    pass
# Out:
# Total pressure source: 5.77e+02 [W]
# Pressure source per volume: 3.87e+05 [W m-3]
# Total density source: 1.20e+21 [s-1]
# Density source per volume: 8.06e+23 [s-1 m-3]
# Mesh file C:\Users\mikek\OneDrive\Project\collab\tech\grid\ST40\matteo-mod\g3c2-fine_xpoint_fields.nc closed
