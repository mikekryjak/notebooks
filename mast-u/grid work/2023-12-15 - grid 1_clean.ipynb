# %%
import sys, os
import yaml
from hypnotoad import tokamak
from hypnotoad.core.mesh import BoutMesh
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

onedrive_path = onedrive_path = str(os.getcwd()).split("OneDrive")[0] + "OneDrive"
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages\sdtools"))
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages\soledge"))
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages"))

from hermes3.grid_fields import Mesh as hermesmesh

# %matplotlib qt
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %% [markdown]
# # Generate grid

# %%
## Read input file and set grid path
gridname = "mastu-superx-g1_MHexample"
path = r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\MAST-U\for_MH"

path_yaml = os.path.join(path, f"{gridname}.yml")
path_grid = os.path.join(path, f"{gridname}.nc")

with open(path_yaml) as f:
    options = yaml.safe_load(f)

## Read equilibrium
with open(r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\MAST-U\for_MH\qian_exp45460_new_MHexample.eqdsk", "rt") as fh:
    eq = tokamak.read_geqdsk(fh, settings=options, nonorthogonal_settings=options)

## Create mesh object
mesh = BoutMesh(eq, options)
# mesh.redistributePoints(options)

mesh.calculateRZ()

## Pkot
fig, ax = plt.subplots(figsize = (5,7), dpi = 140)
# eq.plotPotential(ncontours=200, axis = ax, linewidths = 0.5)
eq.plotWall(axis = ax)
ax.plot(*eq.x_points[0], "rx",)
mesh.plotPoints(xlow=False, ylow=False, corners=False, ax = ax, s = 2)
eq.plotWall(axis = ax)

ax.grid()
ax.legend('', frameon=False)
ax.set_xlim([0.3, 2]); ax.set_ylim([-2.2,0.05])     # Both lower divertors
# ax.set_xlim([0.20, 0.45]); ax.set_ylim([0.6,0.8])     # Inner upper leg
# ax.set_xlim([0.62, 0.800]); ax.set_ylim([-0.08,0])     # OMP
# ax.set_xlim([0.12, 0.300]); ax.set_ylim([-0.15,0.05])     # IMP

ax.set_xlabel("R")
ax.set_ylabel("Z")
ax.set_aspect(1)

## Save figure
# fig.save(os.path.join(
#     r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\MAST-U\D moulton super X",
#     gridname + ".png"))
# Out:
#   nx = 257, ny = 257
# 318
#
# Options
# =======
# Name                                              |  Value
# ================================================================================
# N_norm_prefactor                                  |  1.0             (default)
# extrapolate_profiles                              |  False           (default)
# finecontour_Nfine                                 |  100             (default)
# finecontour_atol                                  |  1e-12           (default)
# finecontour_diagnose                              |  False           (default)
# finecontour_extend_prefactor                      |  2.0             (default)
# finecontour_maxits                                |  200             (default)
# finecontour_overdamping_factor                    |  0.8             (default)
# leg_refine_atol                                   |  1e-05           (default)
# leg_refine_maxits                                 |  1000            (default)
# leg_trace_atol                                    |  2e-10           (default)
# nx_core                                           |  20
# nx_inter_sep                                      |  0               (default)
# nx_pf                                             |  20              (default)
# nx_sol                                            |  20
# nx_sol_inner                                      |  20              (default)
# nx_sol_outer                                      |  20              (default)
# ny_inner_divertor                                 |  10
# ny_inner_lower_divertor                           |  10              (default)
# ny_inner_sol                                      |  20
# ny_inner_upper_divertor                           |  10              (default)
# ny_outer_divertor                                 |  20
# ny_outer_lower_divertor                           |  20              (default)
# ny_outer_sol                                      |  20
# ny_outer_upper_divertor                           |  20              (default)
# ny_sol                                            |  8               (default)
# orthogonal                                        |  True
# poloidal_spacing_delta_psi                        |  None            (default)
# poloidal_spacing_method                           |  sqrt            (default)
# poloidalfunction_diagnose                         |  False           (default)
# psi_core                                          |  None            (default)
# psi_divide_twopi                                  |  False           (default)
# psi_interpolation_method                          |  spline          (default)
# psi_pf_lower                                      |  None            (default)
# psi_pf_upper                                      |  None            (default)
# psi_sol                                           |  None            (default)
# psi_sol_inner                                     |  None            (default)
# psi_spacing_separatrix_multiplier                 |  1.0             (default)
# psinorm_core                                      |  0.9             (default)
# psinorm_pf                                        |  0.98
# psinorm_pf_lower                                  |  0.98            (default)
# psinorm_pf_upper                                  |  0.98            (default)
# psinorm_sol                                       |  1.08
# psinorm_sol_inner                                 |  1.03
# refine_atol                                       |  2e-08           (default)
# refine_methods                                    |  ['integrate+newton', 'integrate'] (default)
# refine_timeout                                    |  10.0            (default)
# refine_width                                      |  1e-05           (default)
# reverse_Bt                                        |  False           (default)
# reverse_current                                   |  False           (default)
# sfunc_checktol                                    |  1e-13           (default)
# start_at_upper_outer                              |  False           (default)
# target_all_poloidal_spacing_length                |  None            (default)
# target_inner_lower_poloidal_spacing_length        |  None            (default)
# target_inner_upper_poloidal_spacing_length        |  None            (default)
# target_outer_lower_poloidal_spacing_length        |  None            (default)
# target_outer_upper_poloidal_spacing_length        |  None            (default)
# xpoint_offset                                     |  0.1             (default)
# xpoint_poloidal_spacing_length                    |  0.05            (default)
# xpoint_refine_atol                                |  1e-06           (default)
# xpoint_refine_maxits                              |  1000            (default)
# y_boundary_guards                                 |  0
#
# Found X-point at psi = 0.00012574502000000002, psi_norm = 1.0
# Found X-point at psi = 0.00012574502000000002, psi_norm = 1.0
# c:\Users\mikek\OneDrive\Project\pyenvs\fusion-a-310\lib\site-packages\scipy\integrate\_ivp\common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:269: RuntimeWarning: invalid value encountered in divide
#   thisR1_b[:, 0] + thisdR1 / thisdZ1 * (Z2 - dZ2 / dR2 * R2 - thisZ1_b[:, 0])
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:270: RuntimeWarning: invalid value encountered in divide
#   ) / (1.0 - thisdR1 / thisdZ1 * dZ2 / dR2)
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:331: RuntimeWarning: invalid value encountered in divide
#   - (thisR1_b[:, 1] - thisR1_b[:, 0]) / (thisZ1_b[:, 1] - thisZ1_b[:, 0])
# Generating a connected double null
#
# Options
# =======
# Name                                              |  Value
# ================================================================================
# N_norm_prefactor                                  |  1.0             (default)
# cap_Bp_ylow_xpoint                                |  False           (default)
# curvature_smoothing                               |  None            (default)
# curvature_type                                    |  curl(b/B)       (default)
# finecontour_Nfine                                 |  100             (default)
# finecontour_atol                                  |  1e-12           (default)
# finecontour_diagnose                              |  False           (default)
# finecontour_extend_prefactor                      |  2.0             (default)
# finecontour_maxits                                |  200             (default)
# finecontour_overdamping_factor                    |  0.8             (default)
# follow_perpendicular_atol                         |  1e-08           (default)
# follow_perpendicular_maxits                       |  10000           (default)
# follow_perpendicular_recover                      |  False           (default)
# follow_perpendicular_rtol                         |  2e-08           (default)
# geometry_rtol                                     |  1e-10           (default)
# number_of_processors                              |  1               (default)
# orthogonal                                        |  True
# poloidal_spacing_delta_psi                        |  None            (default)
# poloidal_spacing_method                           |  sqrt            (default)
# poloidalfunction_diagnose                         |  False           (default)
# psi_interpolation_method                          |  spline          (default)
# psi_spacing_separatrix_multiplier                 |  1.0             (default)
# refine_atol                                       |  2e-08           (default)
# refine_methods                                    |  ['integrate+newton', 'integrate'] (default)
# refine_timeout                                    |  10.0            (default)
# refine_width                                      |  1e-05           (default)
# sfunc_checktol                                    |  1e-13           (default)
# shiftedmetric                                     |  True            (default)
# target_all_poloidal_spacing_length                |  None            (default)
# target_inner_lower_poloidal_spacing_length        |  None            (default)
# target_inner_upper_poloidal_spacing_length        |  None            (default)
# target_outer_lower_poloidal_spacing_length        |  None            (default)
# target_outer_upper_poloidal_spacing_length        |  None            (default)
# wall_point_exclude_radius                         |  0.001           (default)
# xpoint_poloidal_spacing_length                    |  0.05            (default)
# y_boundary_guards                                 |  0
#
# creating region 0 - inner_lower_divertor(0)
# creating region 1 - inner_lower_divertor(1)
# creating region 2 - inner_core(0)
# creating region 3 - inner_core(1)
# creating region 4 - inner_upper_divertor(0)
# creating region 5 - inner_upper_divertor(1)
# creating region 6 - outer_upper_divertor(0)
# creating region 7 - outer_upper_divertor(1)
# creating region 8 - outer_core(0)
# creating region 9 - outer_core(1)
# creating region 10 - outer_lower_divertor(0)
# creating region 11 - outer_lower_divertor(1)
# Get RZ valuespendicular: 41

# %% [markdown]
# # Read grid file into sdtools plotter

# %%
m = hermesmesh(r"C:\Users\mikek\OneDrive\Project\collab\tech\grid\MAST-U\mu1a-from_lowres_modified.nc")

# %% [markdown]
# ## Plot just the grid in RZ space

# %%
fig, ax =plt.subplots(dpi = 200)
m.plot_rz_grid(ax = ax)
ax.set_ylim(-2, -0.4)
# Out:
# (-2.0, -0.4)

# %% [markdown]
# ## Plot grid in XY space
# - Sorry - still just scatter.

# %%
fig, ax =plt.subplots(dpi = 150)
m.plot_xy_grid(ax = ax)

# %% [markdown]
# # equilibrium plot + grid plot

# %%
fig, ax = plt.subplots(figsize = (4,8), dpi = 120)

# Plot equilibrium (from Hypnotoad)
eq.plotPotential(ncontours=50, axis = ax, linewidths = 0.5, alpha = 0.8)
eq.plotWall(axis = ax)

# Plot grid (from  my tools)
m.plot_rz_grid(ax = ax)
ax.set_ylim(-2, -0.4)

ax.set_aspect("equal")

# %% [markdown]
# # Write grid to file

# %%
mesh.geometry()
mesh.writeGridfile(path_grid)
# Out:
# Calculate geometry
# Distances inner_lower_divertor(0)
# Distances inner_lower_divertor(1)
# Distances inner_core(0)tances: 41
# Distances inner_core(1)tances: 41
# Distances inner_upper_divertor(0)
# Distances inner_upper_divertor(1)
# Distances outer_upper_divertor(0)
# Calculating contour distances: 1
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:1473: RuntimeWarning: divide by zero encountered in scalar divide
#   norm = 1.0 / (dpsidr**2 + dpsidz**2)  # Common factor
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:1474: RuntimeWarning: invalid value encountered in scalar multiply
#   return [dpsidr * norm, dpsidz * norm]
# PsiContour distance [0.0, 0.07031335918171885, 0.13867080043051905, 0.20460576796517066, 0.26802274914519925, 0.3290142145118084, 0.38773906942114, 0.4443645804867337, 0.49900961689550777, 0.5517141081100351, 0.6031108173963493, 0.652072769815135, 0.6996089190428613, 0.7454358965825998, 0.7895441884066183, 0.8320461890690912, 0.8729582205618297, 0.9122789656219046, 0.9499945381631157, 0.9860290208654274, 1.0203349400053316, 1.0529187225045067, 1.0837034953773028, 1.1127045830101903, 1.139900014248135, 1.1652275267994812, 1.188592687653363, 1.2098709751577852, 1.2288675637574105, 1.2453824230244475, 1.2592965677856396, 1.2706062362099555, 1.279463665354829, 1.2861565385628349, 1.2910553787434174, 1.2987618031799313, 1.2963788507260834, 1.2963045787027376, 1.2962951791218784, 1.2962918498826745, 1.5816470847415052]
#
# FineContour distance [0.         0.01597623 0.03195247 0.0479287  0.06390493 0.07988116
#  0.0958574  0.11183363 0.12780986 0.1437861  0.15976233 0.17573856
#  0.1917148  0.20769103 0.22366726 0.23964349 0.25561973 0.27159596
#  0.28757219 0.30354843 0.31952466 0.33550089 0.35147713 0.36745336
#  0.38342959 0.39940582 0.41538206 0.43135829 0.44733452 0.46331076
#  0.47928699 0.49526322 0.51123945 0.52721569 0.54319192 0.55916815
#  0.57514439 0.59112062 0.60709685 0.62307309 0.63904932 0.65502555
#  0.67100178 0.68697802 0.70295425 0.71893048 0.73490672 0.75088295
#  0.76685918 0.78283542 0.79881165 0.81478788 0.83076411 0.84674035
#  0.86271658 0.87869281 0.89466905 0.91064528 0.92662151 0.94259774
#  0.95857398 0.97455021 0.99052644 1.00650268 1.02247891 1.03845514
#  1.05443138 1.07040761 1.08638384 1.10236007 1.11833631 1.13431254
#  1.15028877 1.16626501 1.18224124 1.19821747 1.21419371 1.23016994
#  1.24614617 1.2621224  1.27809864 1.29407487 1.29479255 1.29501895
#  1.29545257 1.29601494 1.29653342 1.29669163 1.29864771 1.29902666
#  1.57263785 1.57702089 1.57743804 1.57823987 1.57859849 1.57890567
#  1.57937342 1.58004571 1.58094027 1.58164708]
#
# PsiContour points [Point2D(1.4478542780368,2.003139448242), Point2D(1.3783824063376304,2.013367173938522), Point2D(1.3101229158526009,2.011482294828171), Point2D(1.2452853363775418,1.9997774548810103), Point2D(1.184817772285653,1.9807696987303824), Point2D(1.1288677797513467,1.956542272536468), Point2D(1.0772144856668282,1.9286340487045015), Point2D(1.029518626073559,1.8981314488607368), Point2D(0.9854839140013638,1.865786892428364), Point2D(0.9447598339269548,1.8323381955345048), Point2D(0.907052970285002,1.7974264837426954), Point2D(0.8731445185607548,1.7621102314107593), Point2D(0.8415492623809528,1.7265993512263282), Point2D(0.8128469605113806,1.69087871098198), Point2D(0.786781548033465,1.6552995933773142), Point2D(0.76312571792647,1.6199928218240043), Point2D(0.7419211493126403,1.5850081777437925), Point2D(0.7230483855641483,1.5505156198982764), Point2D(0.7062867115935592,1.5167313223912398), Point2D(0.6913278313083717,1.4839493320704604), Point2D(0.677634881839597,1.4524947478598957), Point2D(0.6647710251153318,1.4225577474199893), Point2D(0.6523728289955768,1.394380210056417), Point2D(0.6401332055802044,1.3680891286701276), Point2D(0.6278877346254746,1.343807763968687), Point2D(0.6155616112870786,1.321683482309058), Point2D(0.6031484627227783,1.301890536420093), Point2D(0.5907149587451561,1.2846248073756854), Point2D(0.5784829528498829,1.2700924211858908), Point2D(0.5668153093557389,1.258405034071748), Point2D(0.556147388105925,1.249468845553285), Point2D(0.5468858799962287,1.2429732047517787), Point2D(0.5392681249080207,1.2384482293697419), Point2D(0.5333098589568782,1.2353894782338364), Point2D(0.5288470370664305,1.2333589192052918), Point2D(0.5256327426731212,1.232028438487433), Point2D(0.5234094558448088,1.2311706605595105), Point2D(0.5219368048753874,1.2306299549828907), Point2D(0.5210042953733584,1.2302987051989112), Point2D(0.5204347945891286,1.230100607305455), Point2D(0.6288002274617459,0.9786957666210557)]
# C:\Users\mikek\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:738: UserWarning: FineContour: maximum iterations (200) exceeded with ds_error 0.25763495765208794
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mesh.geometry()
#       2 mesh.writeGridfile(path_grid)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:3555, in BoutMesh.geometry(self)
#    3553 def geometry(self):
#    3554     # Call geometry() method of base class
# -> 3555     super().geometry()
#    3557     def addFromRegions(name, *, all_corners=False):
#    3558         # Collect a 2d field from the regions
#    3559         self.fields_to_output.append(name)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:2823, in Mesh.geometry(self)
#    2821 for region in self.regions.values():
#    2822     print("Distances", region.name, flush=True)
# -> 2823     region.calcDistances()
#    2824 for region in self.regions.values():
#    2825     print("1", region.name, flush=True)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:842, in MeshRegion.calcDistances(self)
#     837 """
#     838 Calculate the distances for all PsiContours in the region
#     839 """
#     840 if self.user_options.orthogonal:
#     841     # Distances already calculated in non-orthogonal case
# --> 842     self.contours = self.parallel_map(
#     843         _calc_contour_distance, enumerate(self.contours)
#     844     )
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\utils\parallel_map.py:79, in ParallelMap.__call__(self, function, args_list, **kwargs)
#      77 def __call__(self, function, args_list, **kwargs):
#      78     if self.workers is None:
# ---> 79         return [
#      80             function(
#      81                 *args,
#      82                 equilibrium=self.equilibrium,
#      83                 psi=self.psi,
#      84                 f_R=self.f_R,
#      85                 f_Z=self.f_Z,
#      86                 **kwargs,
#      87             )
#      88             for args in args_list
#      89         ]
#      91     args_list = tuple(args_list)
#      92     n_tasks = len(args_list)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\utils\parallel_map.py:80, in <listcomp>(.0)
#      77 def __call__(self, function, args_list, **kwargs):
#      78     if self.workers is None:
#      79         return [
# ---> 80             function(
#      81                 *args,
#      82                 equilibrium=self.equilibrium,
#      83                 psi=self.psi,
#      84                 f_R=self.f_R,
#      85                 f_Z=self.f_Z,
#      86                 **kwargs,
#      87             )
#      88             for args in args_list
#      89         ]
#      91     args_list = tuple(args_list)
#      92     n_tasks = len(args_list)
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\mesh.py:2331, in _calc_contour_distance(i, c, psi, **kwargs)
#    2325 def _calc_contour_distance(i, c, *, psi, **kwargs):
#    2326     print(
#    2327         f"Calculating contour distances: {i + 1}",
#    2328         end="\r",
#    2329         flush=True,
#    2330     )
# -> 2331     c.get_distance(psi=psi)
#    2332     return c
#
# File ~\OneDrive\Project\python-packages\Hypnotoad\hypnotoad\core\equilibrium.py:1189, in PsiContour.get_distance(self, psi)
#    1185         fine_contour.plot(marker="x", color="r")
#    1187         plt.show()
# -> 1189         raise ValueError(
#    1190             f"Distance not monotonically increasing for this contour. "
#    1191             f"distance={self._distance}"
#    1192         )
#    1193 return self._distance
#
# ValueError: Distance not monotonically increasing for this contour. distance=[0.0, 0.07031335918171885, 0.13867080043051905, 0.20460576796517066, 0.26802274914519925, 0.3290142145118084, 0.38773906942114, 0.4443645804867337, 0.49900961689550777, 0.5517141081100351, 0.6031108173963493, 0.652072769815135, 0.6996089190428613, 0.7454358965825998, 0.7895441884066183, 0.8320461890690912, 0.8729582205618297, 0.9122789656219046, 0.9499945381631157, 0.9860290208654274, 1.0203349400053316, 1.0529187225045067, 1.0837034953773028, 1.1127045830101903, 1.139900014248135, 1.1652275267994812, 1.188592687653363, 1.2098709751577852, 1.2288675637574105, 1.2453824230244475, 1.2592965677856396, 1.2706062362099555, 1.279463665354829, 1.2861565385628349, 1.2910553787434174, 1.2987618031799313, 1.2963788507260834, 1.2963045787027376, 1.2962951791218784, 1.2962918498826745, 1.5816470847415052]
