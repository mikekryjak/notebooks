# %%
from boututils.datafile import DataFile
from boutdata.collect import collect
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys, pathlib
import platform
import traceback
import xarray
import xbout
import xhermes
import scipy
import re

onedrive_path = onedrive_path = str(os.getcwd()).split("OneDrive")[0] + "OneDrive"
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages\sdtools"))
sys.path.append(os.path.join(onedrive_path, r"Project\python-packages"))

from hermes3.utils import *


from hermes3.fluxes import *
from hermes3.case_db import *
from hermes3.load import *
from hermes3.named_selections import *
from hermes3.plotting import *
from hermes3.grid_fields import *
from hermes3.accessors import *
from sd1d.analysis import Case


# %load_ext autoreload
# %autoreload 2

plt.close("all")
# %matplotlib inline

print("Done")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Done

# %%
db = CaseDB()

toload = {
    "base" : "sc7cd-no_perpdiff_no_parcond",
}

cs = dict()   # casestore

for name in toload:
    print(f"Loading {toload[name]}")
    cs[name] = Load.case_1D(db.casepaths[toload[name]], guard_replace = False, use_squash = True)

ds = cs["base"].ds
# Out:
# Loading sc7cd-no_perpdiff_no_parcond
# - Looking for squash file
# - Squash file found. squash date 05/22/2024, 18:35:25, dmp file date 05/22/2024, 14:44:21
# Unnormalising with xHermes

# %%
ana = Case(str(db.casepaths["sc7cd-no_perpdiff_no_parcond"]))

# %%
ana.mass_balance_hermes()
# Out:
# >>> System mass balance
# - Total in ---------------
# - Input ion source = 0.000E+00 [s-1]
# - Input neutral source = 0.000E+00 [s-1]
# - Ionisation source = 1.834E+23 [s-1]
# - Intended recycling source = 1.834E+23 [s-1]
# - Total = 1.834E+23 [s-1]
#
# - Total out ---------------
# - Sheath ion flux = 0.000E+00 [s-1]
# - Sheath neutral flux = 0.000E+00 [s-1]
# - Recombination source = -2.740E+19 [s-1]
# - Total = 2.740E+19 [s-1]
#
# - Difference:
# ---> 1.834E+23 [s-1] (99.985%)

# %%
# ds = cs["noneut"].ds
ds = cs["base"].ds

if ds.metadata["guard_replaced"] is True:
    raise Exception("Balances must be done without guard replacement")

mp = constants("mass_p")
me = constants("mass_e")
qe = constants("q_e")
Zi = 1
AA = 2
sheath_ion_polytropic = 1

gamma_e = ds.options["sheath_boundary_simple"]["gamma_e"]
gamma_i = ds.options["sheath_boundary_simple"]["gamma_i"]

last = ds.isel(pos = -3)
guard = ds.isel(pos = -2)

def target(da):
    return (da.isel(pos = -2) + da.isel(pos = -3)) / 2

nesheath = target(ds["Ne"])
tesheath = target(ds["Te"])
tisheath = target(ds["Td+"])
vsheath = target(ds["Vd+"])

# Ion flow speed
C_i = np.sqrt((sheath_ion_polytropic * qe * tisheath + Zi * qe * tesheath) / (AA * mp))

# Parallel heat flux in W/m^2.
# Note: Corrected for 5/2Pe convective thermal flux, and small electron kinetic energy flux
# so gamma_e is the total *energy* flux coefficient.
q_e = ((gamma_e - 2.5) * qe * tesheath - 0.5 * me * vsheath**2) * nesheath * vsheath
q_i = gamma_i * qe * tisheath * nesheath * vsheath

dasheath = (last.dx * last.dz * (last.J + guard.J) / (np.sqrt(last.g_22 + guard.g_22)))

hfe = q_e * dasheath
hfi = q_i * dasheath
pf = vsheath * nesheath * dasheath

ds["hfe_sheath"] = hfe
ds["hfd+_sheath"] = hfi
ds["pfd+_sheath"] = pf

ds["hfe_sheath"].attrs.update(standard_name = "heat flux", units = "W", source = "xHermes", long_name = "sheath heat flux")
ds["hfd+_sheath"].attrs.update(standard_name = "heat flux", units = "W", source = "xHermes", long_name = "sheath heat flux")
ds["pfd+_sheath"].attrs.update(standard_name = "heat flux", units = "s^-1", source = "xHermes", long_name = "sheath particle flux")

# %%
da1 = (last.dx * last.dz * (last.J + guard.J) / (np.sqrt(last.g_22 + guard.g_22))).values
da2 = ((last.da + guard.da) / 2).values
print(da1)
print(da2)
# Out:
# 8.885765876316732
# 6.283185307179586

# %%
last = ds.isel(pos = -3)
dom = ds.isel(pos = slice(2,-2))

pf_iz = (dom["Sd+_iz"] * dom["dv"]).sum("pos")
pf_rec = (dom["Sd+_rec"] * dom["dv"]).sum("pos")
pf_recycle = (dom["Sd_target_recycle"] * dom["dv"]).sum("pos")

pf_iz.plot(label = "iz")
pf_recycle.plot(label = "recycle")
ds["pfd+_sheath"].plot(label = "ions out")

plt.legend()
plt.ylabel("Particle flow [s^-1]")
# Out:
# Text(0, 0.5, 'Particle flow [s^-1]')

# %%
pflast = last["Ne"] * last["Vd+"] * last["da"]
ds["pfd+_sheath"].plot(label = "Sheath flux")
(last["Sd_target_recycle"] * last["dv"]).plot(label = "Recycle source")
pflast.plot(label = "last")
plt.legend()
# Out:
# Data variables:
#     Bxy                 (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     Ed+_iz              (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Ed+_rec             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Ed_target_recycle   (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Ed_target_refl      (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Edd+_cx             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     EnergyFlow_d+_ylow  (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     EnergyFlow_e_ylow   (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Fd+_iz              (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Fd+_rec             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Fdd+_cx             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     G1                  (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     G2                  (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     G3                  (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     J                   (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     Kd+_cond            (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Kd+d+_coll          (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Kd+d_coll           (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Kd+e_coll           (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Kdd+_coll           (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Kdd+_cx             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Kdd_coll            (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Kde_coll            (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Ke_cond             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Ked+_coll           (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Ked_coll            (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Kee_coll            (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     NVd                 (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     NVd+                (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Nd                  (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Nd+                 (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Ne                  (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Pd                  (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Pd+                 (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Pd+_src             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Pd_src              (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Pe                  (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Pe_src              (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Rd+_ex              (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Rd+_rec             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     SNVd                (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     SNVd+               (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     SNd                 (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     SNd+                (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     SPd                 (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     SPd+                (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     SPe                 (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Sd+_iz              (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Sd+_rec             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Sd+_src             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Sd_src              (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Sd_target_recycle   (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Td                  (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Td+                 (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Te                  (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Vd                  (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Vd+                 (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     Ve                  (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     cvode_last_order    (t) int32 dask.array<chunksize=(30,), meta=np.ndarray>
#     cvode_last_step     (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     cvode_nfevals       (t) int32 dask.array<chunksize=(30,), meta=np.ndarray>
#     cvode_nliters       (t) int32 dask.array<chunksize=(30,), meta=np.ndarray>
#     cvode_nniters       (t) int32 dask.array<chunksize=(30,), meta=np.ndarray>
#     cvode_nonlin_fails  (t) int32 dask.array<chunksize=(30,), meta=np.ndarray>
#     cvode_npevals       (t) int32 dask.array<chunksize=(30,), meta=np.ndarray>
#     cvode_nsteps        (t) int32 dask.array<chunksize=(30,), meta=np.ndarray>
#     cvode_num_fails     (t) int32 dask.array<chunksize=(30,), meta=np.ndarray>
#     cvode_stab_lims     (t) int32 dask.array<chunksize=(30,), meta=np.ndarray>
#     ddt(NVd)            (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     ddt(NVd+)           (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     ddt(Nd)             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     ddt(Nd+)            (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     ddt(Pd)             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     ddt(Pd+)            (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     ddt(Pe)             (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     g11                 (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     g12                 (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     g13                 (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     g22                 (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     g23                 (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     g33                 (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     g_11                (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     g_12                (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     g_13                (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     g_22                (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     g_23                (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     g_33                (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     kappa_par_d+        (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     kappa_par_e         (t, pos) float64 dask.array<chunksize=(30, 516), meta=np.ndarray>
#     ncalls              (t) int32 dask.array<chunksize=(30,), meta=np.ndarray>
#     ncalls_e            (t) int32 dask.array<chunksize=(30,), meta=np.ndarray>
#     ncalls_i            (t) int32 dask.array<chunksize=(30,), meta=np.ndarray>
#     wall_time           (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     wtime               (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     wtime_comms         (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     wtime_invert        (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     wtime_io            (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     wtime_per_rhs       (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     wtime_per_rhs_e     (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     wtime_per_rhs_i     (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     wtime_rhs           (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     t_array             (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     da                  (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     dv                  (pos) float64 dask.array<chunksize=(516,), meta=np.ndarray>
#     hfe_sheath          (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     hfd+_sheath         (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
#     pfd+_sheath         (t) float64 dask.array<chunksize=(30,), meta=np.ndarray>
